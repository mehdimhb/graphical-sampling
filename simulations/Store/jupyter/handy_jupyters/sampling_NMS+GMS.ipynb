# %% [markdown]
# ### Import and reading data

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# import os
# import ctypes

# # Force the dynamic linker to find libR.so before rpy2 tries to load
# try:
#     ctypes.CDLL('/usr/lib/R/lib/libR.so', mode=ctypes.RTLD_GLOBAL)
# except Exception as e:
#     print(f"Manual link failed: {e}")

# os.environ['R_HOME'] = '/usr/lib/R'
# os.environ['LD_LIBRARY_PATH'] = '/usr/lib/R/lib'

# %%
from itertools import product
import numpy as np
import graphical_sampling as gs
from tqdm import tqdm
from package_sampling.utils import inclusion_probabilities
import numpy as np
import pandas as pd

# %%
import os
os.getcwd()
# os.chdir("/home/bardia/graphical-sampling")
# os.chdir("/home/bardia/graphical-sampling/simulations")
# os.chdir('/config/ws/graphical-sampling/simulations')
# os.chdir('/Users/Apc/graphical-sampling/simulations')
# os.chdir('/home/dell/projects/graphical-sampling/simulations')
os.chdir('/home/bardia/projects/graphical-sampling/simulations')

# %%
# ============================================================
# DESIGN SEARCH FUNCTION
# ============================================================

def search_best_design(

    pop,
    n,

    # ========================================================
    # CRITERION
    # ========================================================

    criterion='MI',

    # ========================================================
    # MULTI-OBJECTIVE WEIGHTS
    # ========================================================

    w1=0.5,
    w2=0.5,

    moran_scale=0.05,
    var_scale=1000,

    # ========================================================
    # SEARCH SPACE
    # ========================================================

    point_strategies=[

        'None',

        'lexico_xy',
        'lexico_yx',

        'projection',
        'dist_from_origin',

        'angle',
        'spiral',

        'hilbert',

        'snake',

        'knight_move',

        'random',
    ],

    zone_strategies=[

        'None',

        'lexico_xy',
        'lexico_yx',

        'projection',
        'dist_from_origin',

        'angle',
        'spiral',

        'hilbert',

        'snake',

        'knight_move',

        'random',
    ],

    zone_modes=[
        'sweep_xy',
        'sweep_yx'
    ],

    num_splits=[1],

    shift_jumps=[1],

    num_zones_cluster=[100],

    num_zones_sweep=[(5, 5)],

    # ========================================================
    # CLUSTERING
    # ========================================================

    centroid_grid_x=10,

    r_sample_per_cluster=1,

    # ========================================================
    # ORDER OPTIONS
    # ========================================================

    topological=False,

    shuffle=False,
):

    # ========================================================
    # CRITERION NAMES
    # ========================================================

    criterion_name_map = {

        'MI': 'Moran',

        'VAR': 'Variance',

        'MI_VAR': 'Moran + Variance',

        'VI': 'Voronoi',

        'DI': 'Density',

        'BI': 'Balance',
    }

    criterion_name = criterion_name_map[criterion]

    # ========================================================
    # STORAGE
    # ========================================================

    track = []

    best_val = float('inf')

    best_design = None

    # ========================================================
    # TOTAL ITERATIONS
    # ========================================================

    num_designs = (

        len(point_strategies)

        * len(zone_strategies)

        * len(zone_modes)

        * len(num_splits)

        * len(shift_jumps)
    )

    # ========================================================
    # PROGRESS BAR
    # ========================================================

    pbar = tqdm(

        product(

            point_strategies,

            zone_strategies,

            zone_modes,

            num_splits,

            shift_jumps
        ),

        total=num_designs
    )

    # ========================================================
    # SEARCH LOOP
    # ========================================================

    for (

        point_strategy,

        zone_strategy,

        zone_mode,

        num_split,

        shift_jump

    ) in pbar:

        # ----------------------------------------------------
        # ZONE CONFIGURATIONS
        # ----------------------------------------------------

        list_of_num_zones = (

            num_zones_cluster

            if zone_mode == 'cluster'

            else num_zones_sweep
        )

        for num_zones in list_of_num_zones:

            # =================================================
            # CLUSTERING
            # =================================================

            fbn = gs.clustering.FIPBalancedNMeans(

                n=n,

                centroid_grid_x=centroid_grid_x,

                r_sample_per_cluster=r_sample_per_cluster,

                init_clust_method='expanded',

                split_size=.001
            )

            fbn.fit(pop)

            fbn.fit_zones(

                num_zones=num_zones,

                mode=zone_mode
            )

            try:

                # =============================================
                # BUILD ORDER
                # =============================================

                order = gs.Order.from_clusters(

                    pop,

                    fbn.clusters,

                    zone_strategy=zone_strategy,

                    point_strategy=point_strategy,

                    num_splits=num_split,

                    topological=topological,

                    shift_jump=shift_jump,

                    shuffle=shuffle,

                    grid_dims=(
                        num_zones
                        if isinstance(num_zones, tuple)
                        else None
                    ),
                )

                # =============================================
                # CREATE DESIGN
                # =============================================

                design = gs.Design.from_order(pop, order)

                # =============================================
                # CRITERIA
                # =============================================

                moran_val = design.moran[0]

                design._nht_variance = None

                var_val = design.nht_variance

                # =============================================
                # OBJECTIVE FUNCTION
                # =============================================

                match criterion:

                    case 'MI':

                        val = moran_val

                    case 'VAR':

                        val = var_val

                    case 'MI_VAR':

                        standardized_moran = (
                            moran_val
                            / (moran_scale + 1e-12)
                        )

                        standardized_variance = (
                            var_val
                            / (var_scale + 1e-12)
                        )

                        val = (

                            w1 * standardized_moran

                            +

                            w2 * standardized_variance
                        )

                    case 'VI':

                        val = design.voronoi

                    case 'DI':

                        val = design.density_disparity

                    case 'BI':

                        val = design.local_balance

                    case _:

                        raise ValueError(
                            f"Unknown criterion: {criterion}"
                        )

                # =============================================
                # LABELS
                # =============================================

                combo = (
                    f"{zone_strategy}"
                    f" → "
                    f"{point_strategy}"
                )

                # =============================================
                # INITIAL BASELINE
                # =============================================

                if len(track) == 0:

                    best_val = val

                    print(

                        f"[INITIAL] "

                        f"{criterion_name}: {val:.6f} | "

                        f"{combo}"
                    )

                # =============================================
                # IMPROVEMENT
                # =============================================

                if val < best_val:

                    best_val = val

                    best_design = design

                    print(

                        f"[NEW BEST] "

                        f"Objective: {val:.6f} | "

                        f"MI: {moran_val:.6f} | "

                        f"VAR: {var_val:.2f} | "

                        f"{combo:<30} | "

                        f"Mode: {zone_mode:<8} | "

                        f"Zones: {num_zones} | "

                        f"Jump: {shift_jump}"
                    )
                # =============================================
                # PROGRESS BAR
                # =============================================

                pbar.set_postfix({

                    "Best": f"{best_val:.6f}",

                    "Combo": combo
                })

                # =============================================
                # STORE RESULTS
                # =============================================

                track.append({

                    'value': val,

                    'design': design,

                    'moran': moran_val,

                    'variance': var_val,

                    'zone_strategy': zone_strategy,

                    'point_strategy': point_strategy,

                    'combo': combo,

                    'zone_mode': zone_mode,

                    'num_zones': num_zones,

                    'shift_jump': shift_jump,
                })

            except Exception:

                continue

    # ========================================================
    # NO VALID DESIGNS
    # ========================================================

    if len(track) == 0:

        print("\n[ERROR] No valid designs generated.")

        return None

    # ========================================================
    # SORT RESULTS
    # ========================================================

    results = sorted(

        track,

        key=lambda x: x['value']
    )

    best = results[0]

    # ========================================================
    # FINAL OUTPUT
    # ========================================================

    print(f"\n{'='*60}")

    print(f"              OPTIMIZATION COMPLETE")

    print(f"{'='*60}")

    print(f"Criterion:       {criterion_name}")

    print(f"Best Objective:  {best['value']:.6f}")

    print(f"Moran:           {best['moran']:.6f}")

    print(f"Variance:        {best['variance']:.6f}")

    print(f"Combination:     {best['combo']}")

    print(f"Zone Mode:       {best['zone_mode']}")

    print(f"Num Zones:       {best['num_zones']}")

    print(f"Shift Jump:      {best['shift_jump']}")

    print(f"{'='*60}")

    # ========================================================
    # RETURN
    # ========================================================

    return {

        'best_design': best['design'],

        'best_value': best['value'],

        'criterion': criterion,

        'moran': best['moran'],

        'variance': best['variance'],

        'best_combo': best['combo'],

        'zone_strategy': best['zone_strategy'],

        'point_strategy': best['point_strategy'],

        'zone_mode': best['zone_mode'],

        'num_zones': best['num_zones'],

        'shift_jump': best['shift_jump'],

        'results': results,

        'track': track,
    }

# %%
def robertson_variables(x1, x2, positive_shift=True):

    corrugated = (
        3 * (x1 + x2)
        +
        np.sin(6 * (x1 + x2))
    )

    peak = (
        (
            3 * (4 - 6*x1)**2
            *
            np.exp(
                -(6*x1 - 3)**2
                -
                (6*x2 - 2)**2
            )
            -
            10
            *
            (
                0.2*(6*x1 - 3)
                -
                (6*x1 - 3)**3
                -
                (6*x2 - 3)**5
            )
            *
            np.exp(
                -(6*x1 - 3)**2
                -
                (6*x2 - 3)**2
            )
            -
            (1/3)
            *
            np.exp(
                -(6*x1 - 2)**2
                -
                (6*x2 - 3)**2
            )
        )
    )

    bird = (
        1/20
        *
        (
            (12*x1 - 12*x2)**2
            +
            np.exp(
                (1 - np.sin(12*x1 - 6))**2
            )
            *
            np.cos(12*x2 - 6)
            +
            np.exp(
                (1 - np.cos(12*x2 - 6))**2
            )
            *
            np.sin(12*x1 - 6)
        )
    )

    if positive_shift:

        peak = peak + 7

        bird = bird + 6

    return {

        "corrugated": corrugated,

        "plane": corrugated,

        "peak": peak,

        "bird": bird,
    }

# %%
# =========================================================
# LOAD POPULATIONS
# =========================================================

import os
import pandas as pd
import numpy as np

from package_sampling.utils import inclusion_probabilities

# =========================================================
# FILES
# =========================================================

files = [

    "meuse.csv",

    "swiss.csv",

    "AggregatedPop1000.csv",

    "RegularPop1000.csv"
]

# =========================================================
# POPULATION LOADER
# =========================================================

def popus(n, path="populations/real"):

    dfs = {}

    for f in files:

        full_path = os.path.join(path, f)

        # -------------------------------------------------
        # Check existence
        # -------------------------------------------------

        if not os.path.exists(full_path):

            print(f"Warning: {full_path} not found.")

            continue

        # -------------------------------------------------
        # Read file
        # -------------------------------------------------

        df = pd.read_csv(full_path)

        N_pop = len(df)

        name = f.replace(".csv", "")

        # -------------------------------------------------
        # Equal probabilities
        # -------------------------------------------------

        pik_ep = np.repeat(
            n / N_pop,
            N_pop
        )


        # =================================================
        # ROBERTSON POPULATIONS
        # =================================================

        # =================================================
# ROBERTSON POPULATIONS
# =================================================

        if f in ["AggregatedPop1000.csv", "RegularPop1000.csv"]:

            coords = df.to_numpy()

            x1 = coords[:, 0]
            x2 = coords[:, 1]

            vars_robertson = robertson_variables(x1, x2)

            plane = vars_robertson["plane"]

            def noisy_through_origin(x, rho, seed=None):

                rng = np.random.default_rng(seed)

                e = rng.normal(size=len(x))
                e = (e - e.mean()) / e.std()

                # noise level corresponding to target correlation
                noise_ratio = np.sqrt(1 / (rho**2) - 1)

                y = x + noise_ratio * x.std() * e

                return y

            dfs[f"df_{name}"] = pd.DataFrame({

                "coord_x" : x1,
                "coord_y" : x2,

                "pik_ep" : pik_ep,

                "z" : vars_robertson["corrugated"],

                "plane" : plane,
                "peak" : vars_robertson["peak"],
                "bird" : vars_robertson["bird"],

                "plane_rho_07" : noisy_through_origin(plane, 0.7, seed=701),
                "plane_rho_08" : noisy_through_origin(plane, 0.8, seed=801),
                "plane_rho_09" : noisy_through_origin(plane, 0.9, seed=901),
            })
            
        
        elif f == "meuse.csv":

            coords = df[["x", "y"]].to_numpy()

            # unequal probabilities
            pik_up = inclusion_probabilities(

                df["copper"].to_numpy().copy(),

                n
            )

            dfs[f"df_{name}"] = pd.DataFrame({

                "coord_x" : coords[:, 0],

                "coord_y" : coords[:, 1],

                "pik_ep" : pik_ep,

                "pik_up" : pik_up,

                "z" : df["cadmium"]
            })

        # =================================================
        # SWISS
        # =================================================

        elif f == "swiss.csv":

            coords = df[["x", "y"]].to_numpy()

            AREA = df["AREA"].to_numpy().clip(
                5,
                100
            )

            pik_up = inclusion_probabilities(

                AREA.copy(),

                n
            )

            dfs[f"df_{name}"] = pd.DataFrame({

                "coord_x" : coords[:, 0],

                "coord_y" : coords[:, 1],

                "pik_ep" : pik_ep,

                "pik_up" : pik_up,

                "z" : df["AREA_A"]
            })

    return dfs

# =========================================================
# LOAD MAIN POPULATIONS
# =========================================================

p50 = popus(50)

regular = p50["df_RegularPop1000"]

aggregated = p50["df_AggregatedPop1000"]

meuse = p50["df_meuse"]

swiss = p50["df_swiss"]

# =========================================================
# CHECK
# =========================================================

print("\n================================================")
print("POPULATIONS LOADED")
print("================================================\n")

print("regular:", regular.shape)

print("aggregated:", aggregated.shape)

print("meuse:", meuse.shape)

print("swiss:", swiss.shape)
# Out:
# ================================================
# POPULATIONS LOADED
# ================================================
#
# regular: (1000, 10)
# aggregated: (1000, 10)
# meuse: (155, 5)
# swiss: (959, 5)

# %%
# changing the angle of the population for testing the robustness of the sampling algorithms

import numpy as np
import pandas as pd

def rotate_population(df, alpha_degrees):
    # Convert angle to radians
    alpha_rad = np.radians(alpha_degrees)
    
    # Rotation Matrix components
    cos_a = np.cos(alpha_rad)
    sin_a = np.sin(alpha_rad)
    
    # Extract coordinates
    x = df['coord_x'].values
    y = df['coord_y'].values
    
    # Apply Rotation:
    # x' = x*cos(a) - y*sin(a)
    # y' = x*sin(a) + y*cos(a)
    df['coord_x'] = x * cos_a - y * sin_a
    df['coord_y'] = x * sin_a + y * cos_a
    
    return df

# Example use: Rotate 45 degrees
# df_rotated = rotate_population(df.copy(), 45)

# %%
# Diagnostic function to check inclusion probabilities and plot deviations

import numpy as np
import matplotlib.pyplot as plt

def check_inclusions(design, plot=True, title="FIP Deviation"):
    """
    Performs a statistical diagnostic on the design to ensure 
    Inclusion Probabilities (FIP) are perfectly preserved.
    """
    # 1. Extract Data
    empirical_fip = design.fip 
    target_fip = design.pop.inclusions
    diff = empirical_fip - target_fip
    max_dev = np.abs(diff).max()

    # 2. Print Summary
    print(f"--- Inclusion Probability Diagnostic ---")
    print(f"Total Design Mass: {empirical_fip.sum():.6f} (Target: {design.pop.n})")
    print(f"Max Absolute Deviation: {max_dev:.2e}")
    print(f"Mean Absolute Deviation: {np.abs(diff).mean():.2e}")

    # 3. Validation Logic
    if np.allclose(empirical_fip, target_fip, atol=1e-6):
        print("✅ SUCCESS: Inclusion probabilities are perfectly preserved!")
    else:
        fixed_count = len(design.order.fixed_ids)
        print(f"❌ WARNING: Significant deviation! Frozen units: {fixed_count}")

    # 4. Optional Plotting
    if plot:
        plt.figure(figsize=(10, 2))
        plt.plot(diff, color='red', lw=1, alpha=0.7)
        plt.title(f"{title} (Max Dev: {max_dev:.2e})")
        plt.axhline(0, color='black', lw=0.5, ls='--')
        plt.ylabel("Delta")
        plt.xlabel("Unit Index")
        plt.grid(True, alpha=0.2)
        plt.show()

# %%
# Function to save the full GBFS engine state, including the search frontier and best design
import os
import pickle
from datetime import datetime

def save_gbfs_state(engine, folder="best_designs"):
    """
    Saves the full GBFS engine state, including the search frontier and best design.
    """
    os.makedirs(folder, exist_ok=True)
    
    # Extract metadata for a clean filename
    pop_label = getattr(engine.best_design.pop, 'label', 'pop').replace(" ", "_")
    score = engine.best_criteria_value
    timestamp = datetime.now().strftime("%m%d_%H%M")
    
    # Detect current zone configuration from the best design
    # This helps identify if the file is a 40Z or 1Z version
    num_clusters = len(engine.best_design.order.clusters)
    num_zones = len(engine.best_design.order.clusters[0].zones) if num_clusters > 0 else 0
    
    filename = f"GRIZZLY_{pop_label}_C{num_clusters}Z{num_zones}_score{score:.4f}_pop_{popu}_{timestamp}.pkl"
    save_path = os.path.join(folder, filename)
    
    with open(save_path, 'wb') as f:
        pickle.dump(engine, f)
    
    print(f"✅ Full search state saved: {save_path}")
    print(f"Candidates waiting in Open Set: {len(engine.open_set)}")
    return save_path

# %%
# Function to Save Initila and Best Design, 
import os
import pickle
from datetime import datetime

def save_design(design, folder="best_designs", name_prefix="INITIAL"):
    """
    Save a single Design object.
    """
    os.makedirs(folder, exist_ok=True)

    # Population label
    pop_label = getattr(design.pop, 'label', 'pop').replace(" ", "_")

    # Structure info
    num_clusters = len(design.order.clusters) if design.order.clusters else 1
    num_zones = len(design.order.clusters[0].zones) if design.order.clusters else 1

    # Timestamp
    timestamp = datetime.now().strftime("%m%d_%H%M")

    filename = (
        f"{name_prefix}_{pop_label}"
        f"_C{num_clusters}Z{num_zones}"
        f"_pop_{popu}_{timestamp}.pkl"
    )

    save_path = os.path.join(folder, filename)

    with open(save_path, 'wb') as f:
        pickle.dump(design, f)

    print(f"✅ Design saved: {save_path}")

    return save_path

# %%
# Function to load a saved GBFS engine state from the best_designs folder

def load_gbfs_state(filename):
    """
    Loads a saved GBFS engine state from the best_designs folder.
    """
    # Ensure we look in the right folder if only a filename is provided
    if not os.path.exists(filename):
        filename = os.path.join("best_designs", filename)
        
    if os.path.exists(filename):
        with open(filename, 'rb') as f:
            loaded_engine = pickle.load(f)
        
        print(f"🚀 Grizzly Resumed!")
        print(f"Best Score Found: {loaded_engine.best_criteria_value:.6f}")
        print(f"Hierarchy State:  {len(loaded_engine.best_design.order.clusters)} Clusters")
        print(f"Frontier Size:    {len(loaded_engine.open_set)} candidates")
        return loaded_engine
    else:
        print(f"❌ File not found: {filename}")
        return None

# %%
# Fucntion to load One Design, Best or Initial
import pickle

def load_design(filename):
    with open(filename, "rb") as f:
        return pickle.load(f)

# %%
def release_full_grizzly(old_engine):
    """
    Takes a restricted engine (40 zones), flattens every single candidate 
    in its open_set, and returns a brand new 'Released' engine.
    """
    print(f"--- Global Release Initiated ---")
    print(f"Processing {len(old_engine.open_set)} candidates from the frontier...")
    
    # 1. First, flatten the absolute best design to use as the "seed"
    flat_best = old_engine.best_design.flatten()
    
    # 2. Create the fresh engine using that flat_best as the initial design
    # This prevents the ValueError: min() arg is empty
    new_engine = gs.search.GreedyBestFirstSearch(initial_designs=[flat_best], criteria=old_engine.criteria)
    
    # 3. Flatten the rest of the Open Set and add them
    flattened_count = 0
    import heapq
    for val, _, move_type, design in old_engine.open_set:
        try:
            # Flatten the candidate
            flat_candidate = design.flatten()
            
            # Avoid duplicating the best_design we already added
            if flat_candidate == flat_best:
                continue
                
            # Push into the new engine's open_set
            heapq.heappush(new_engine.open_set, (val, next(new_engine._counter), 'order_change', flat_candidate))
            flattened_count += 1
        except Exception:
            continue
            
    # 4. Ensure the engine starts with a clean closed_set
    new_engine.closed_set = set()
    
    print(f"✅ Success! New engine populated with {flattened_count + 1} global candidates.")
    print(f"Current Best Score: {new_engine.best_criteria_value:.6f}")
    
    return new_engine

# %%
# Debugging function to visualize the swap in the specific zone

from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt
import numpy as np
def audit_intelligent_swap(order_obj, coords, idx_i, idx_j, c_idx, z_idx):
    """
    Visualizes the specific zone where a swap is happening.
    """
    plt.figure(figsize=(6, 6))
    
    # 1. Get the specific zone data
    active_zone = order_obj.clusters[c_idx].zones[z_idx]
    zone_indices = active_zone.indices # Use the property to get sorted indices
    
    # 2. Plot all points in the background (faint)
    plt.scatter(coords[:, 0], coords[:, 1], c='gray', s=5, alpha=0.1, label='Population')
    
    # 3. Highlight all points in this SPECIFIC zone
    zone_coords = coords[zone_indices]
    plt.scatter(zone_coords[:, 0], zone_coords[:, 1], c='green', s=20, alpha=0.4, label=f'Zone {z_idx}')
    
    # 4. Draw the Convex Hull of the Zone (The "Green Box")
    if len(zone_coords) >= 3:
        hull = ConvexHull(zone_coords)
        for simplex in hull.simplices:
            plt.plot(zone_coords[simplex, 0], zone_coords[simplex, 1], 'g-', lw=2)
            
    # 5. Highlight the two units being swapped
    # Red = Unit i, Blue = Unit j
    plt.scatter(coords[idx_i, 0], coords[idx_i, 1], c='red', s=100, edgecolors='black', label='Unit I', zorder=5)
    plt.scatter(coords[idx_j, 0], coords[idx_j, 1], c='blue', s=100, edgecolors='black', label='Unit J', zorder=5)
    
    plt.title(f"Cluster {c_idx} | Zone {z_idx} | Swapping ID {idx_i} with {idx_j}")
    plt.legend()
    plt.show()

# %%
# srs_var = N**2 * (1-n/N) * np.var(variable)/n

# plain_flat = [
#     N,
#     n,
#     5000,
#     0,
#     np.sum(variable),
#     initial_design.nht_variance,
#     # srs_var / initial_design.nht_variance,
#     0,
#     0,
#     initial_design.density_disparity[0],
#     initial_design.density_disparity[1],
#     initial_design.voronoi[0],
#     initial_design.voronoi[1],
#     initial_design.moran[0],
#     initial_design.moran[1],
#     initial_design.local_balance[0],
#     initial_design.local_balance[1],
# ]

# print(", ".join(map(str, plain_flat)))

# %% [markdown]
# ### Parameters and Pre-Process

# %%
# --- Parameters ---
popu = "df_RegularPop1000"
ep_or_up = "pik_ep"
n = 20

df = popus(n)[popu]
df = rotate_population(df.copy(), 0)
N = len(df)

r_sample_per_cluster = 1
centroid_grid_x = 5
centroid_grid_x_zone = 9
num_zones_cluster = [100]
num_zones_sweep = [(2, 2)]
num_splits = [1]
topological = True
shift_jumps = [0]
shuffle = False

# --- Data Preparation ---
target_df = df

coords_data = target_df[["coord_x", "coord_y"]].to_numpy()
inclusions_data = target_df[ep_or_up].to_numpy()
# inclusions_data = inclusion_probabilities(np.random.uniform(0, 1, size=N),n)

# main target: final evaluation
y_main = target_df["plane"].to_numpy()

# auxiliary: optimization variable
y_aux = target_df["plane_rho_08"].to_numpy()

# --- Population uses auxiliary for optimization ---
pop = gs.Population(
    coords_data,
    inclusions_data,
    n=n,
    variable=y_aux
)

# --- Clustering ---
fbn = gs.clustering.FIPBalancedNMeans(
    n=n,
    centroid_grid_x=centroid_grid_x,
    r_sample_per_cluster=r_sample_per_cluster,
    init_clust_method="ot",
    split_size=.001
)

fbn.fit(pop)

fbn.fit_zones(
    num_zones=num_zones_sweep[0],
    mode="sweep_xy"
)

# --- Visualization ---
fbn.plot(mode="soft")
# Out:
# <Axes: title={'center': 'FIP-balanced 20-means clustering'}, xlabel='$X_1$', ylabel='$X_2$'>

# %%
# =========================================================
# INITIAL OPTIMIZATION
# =========================================================

y_main = target_df["plane"].to_numpy()
y_aux  = target_df["plane_rho_09"].to_numpy()

print("corr(aux, main) =", np.corrcoef(y_aux, y_main)[0, 1])

pop = gs.Population(
    coords_data,
    inclusions_data,
    n=n,
    variable=y_aux
)

out = search_best_design(
    pop=pop,
    n=n,

    r_sample_per_cluster=1,
    centroid_grid_x=4,
    num_zones_cluster=[100],
    num_zones_sweep=[(1, 1)],
    num_splits=[1],
    topological=True,
    shift_jumps=[0],
    shuffle=False,

    criterion="MI_VAR",

    w1=1,
    w2=0,

    moran_scale=0.05,
    var_scale=1000,
)

best_initial_design = out["best_design"]
design = best_initial_design
# Out:
# corr(aux, main) = 0.8966326394870973
#   0%|          | 0/242 [00:00<?, ?it/s]
#   0%|          | 1/242 [00:00<03:40,  1.09it/s, Best=-3.562448, Combo=None → None]
# [INITIAL] Moran + Variance: -3.562448 | None → None
#  28%|██▊       | 67/242 [00:43<01:39,  1.76it/s, Best=-4.121568, Combo=None → projection]
# [NEW BEST] Objective: -4.121568 | MI: -0.206078 | VAR: 103885.06 | None → projection              | Mode: sweep_xy | Zones: (1, 1) | Jump: 0
#  43%|████▎     | 104/242 [01:05<01:26,  1.59it/s, Best=-4.121568, Combo=hilbert → dist_from_origin]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 17
#      13     n=n,
#      14     variable=y_aux
#      15 )
#      16
# ---> 17 out = search_best_design(
#      18     pop=pop,
#      19     n=n,
#      20
#
# Cell In[61], line 426, in search_best_design(pop, n, criterion, w1, w2, moran_scale, var_scale, point_strategies, zone_strategies, zone_modes, num_splits, shift_jumps, num_zones_cluster, num_zones_sweep, centroid_grid_x, r_sample_per_cluster, topological, shuffle)
#     422
#     423                     'shift_jump': shift_jump,
#     424                 })
#     425
# --> 426             except Exception:
#     427
#     428                 continue
#     429
#
# File ~/projects/graphical-sampling/graphical_sampling/design.py:475, in Design.moran(self)
#     471     return self._moran_expected_and_variance
#     473 samples, _ = self.all_samples_and_probs
#     474 self._moran_expected_and_variance = self._expected_and_std(
# --> 475     Moran(self.pop).score(samples)
#     476 )
#     477 return self._moran_expected_and_variance
#
# File ~/projects/graphical-sampling/graphical_sampling/index/moran.py:166, in Moran.score(self, samples)
#     163 sample_size = samples.shape[1]
#     165 if self.method == "tille":
# --> 166     W = self._weights_tille(self.coords, self.inclusion_probs)
#     168 elif self.method == "raphael":
#     169     W = self._weights_raphael(self.coords, self.inclusion_probs)
#
# File ~/projects/graphical-sampling/graphical_sampling/index/moran.py:32, in Moran._weights_tille(coords, inclusion_probs)
#      29 k = int(np.floor(h))
#      30 frac = h - k
# ---> 32 order = np.argsort(D[i])
#      33 order = order[order != i]
#      35 if k > 0:
#
# File ~/projects/graphical-sampling/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:1213, in argsort(a, axis, kind, order, stable)
#    1100 @array_function_dispatch(_argsort_dispatcher)
#    1101 def argsort(a, axis=-1, kind=None, order=None, *, stable=None):
#    1102     """
#    1103     Returns the indices that would sort an array.
#    1104
#    (...)   1211
#    1212     """
# -> 1213     return _wrapfunc(
#    1214         a, 'argsort', axis=axis, kind=kind, order=order, stable=stable
#    1215     )
#
# File ~/projects/graphical-sampling/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      51     return _wrapit(obj, method, *args, **kwds)
#      53 try:
# ---> 54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
#      57     # class, but its signature is not identical to that of NumPy's. This
#    (...)     61     # Call _wrapit from within the except clause to ensure a potential
#      62     # exception has a traceback chain.
#      63     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
# =========================================================
# PLOT ONE SAMPLE FROM INITIAL DESIGN
# =========================================================
from graphical_sampling.criteria.multi_objective import nht_variance_for_variable
import matplotlib.pyplot as plt
from graphical_sampling.index import Moran

design = best_initial_design

fig, ax = plt.subplots(figsize=(10, 8))

fbn.clusters = design.order.clusters

fbn.plot(
    mode="soft",
    ax=ax,
    show_zone_labels=True
)

sample_2d = design.sample(1)
sample = sample_2d[0]

coords = design.pop.coords

ax.scatter(
    coords[sample, 0],
    coords[sample, 1],
    color="red",
    s=100,
    edgecolors="black",
    zorder=15
)

mi = Moran(
    design.pop,
    method="tille"
).score(sample_2d)[0]

ax.set_title(
    f"Expected MI = {design.moran[0]:.4f} | "
    f"Realized MI = {mi:.4f}"
)

plt.show()

print("Var aux  /10000:",
      nht_variance_for_variable(design, y_aux) / 10000)

print("Var main /10000:",
      nht_variance_for_variable(design, y_main) / 10000)
# Out:
# Var aux  /10000: 2.8998761417101786
# Var main /10000: 0.40289645361131254

# %%
raise KeyboardInterrupt("Execution stopped by user.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[277], line 1
# ----> 1 raise KeyboardInterrupt("Execution stopped by user.")
#
# KeyboardInterrupt: Execution stopped by user.

# %% [markdown]
# ### GRIZZLY alph MI + (1-alpha) Var

# %%
read_des = 1
save_des = 0

save_grz = 0
read_grz = 0

check_des = 0

flat_grz = 0


if save_des == 1:
    # save a design
    current_file = save_design(design)
    # current_file = save_design(gbfs.best_design)

if read_des == 1:
    # load a desin
    design = load_design("best_designs/robertson/best_design_C200Z1_pop_df_Regular1000.pkl")

if save_grz == 1:
    # save a grizzly
    current_file = save_gbfs_state(gbfs)

if read_grz == 1:
    # load a grizzly 
    gbfs2 = load_gbfs_state('GRIZZLY_pop_C1Z1_score0.0166_pop_df_AggregatedPop1000_0521_0210.pkl')

if check_des == 1:
    check_inclusions(gbfs.best_design)

if flat_grz == 1:
    gbfs = release_full_grizzly(gbfs)

# %%
design = best_initial_design
criteria = gs.criteria.MultiObjectiveCriteria(
    objectives=["MI", "VAR"],
    weights=[1, 0],
    scales={"MI": 0.05, "VAR": 15000},
    auxiliary=y_main,
)
gbfs = gs.search.GreedyBestFirstSearch([design], criteria)

# %%
# =========================================================
# RUN GRIZZLY
# =========================================================

gbfs.run(
    max_iterations=1000,
    max_open_set_size=2000,
    top_k=1,

    num_new_order_nodes=100,
    num_new_exchange_nodes=0,

    num_clusters_range=(1, 1),
    num_zones_range=(1, 1),
    num_changes_range=(1, 1),
    num_zone_changes=0,

    pull_strategy="random",
    exchange_coef=0.33,

    num_explore=1,
    window=50,

    n_jobs=-1,
    backtrack_depth=1,
    stagnation_limit=5000,

    y_main=y_main,
    y_aux=y_aux,
)

gbfs.initial_designs = [gbfs.best_design]

check_inclusions(
    gbfs.best_design,
    plot=False
)
# Out:
# Starting fresh: Initializing Open Set.
# --- Parallel GBFS: Batch Size=1, Workers=-1 ---
#     GAP USED: [30]
# ITR/SuccR    0/1.000 | OBJ -3.408286 | VAR_main 0.446796 | VAR_aux 2.894991 | MI -0.17041 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [15]
# ITR/SuccR    0/2.000 | OBJ -3.412706 | VAR_main 0.404394 | VAR_aux 2.991138 | MI -0.17064 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [17]
# ITR/SuccR    0/3.000 | OBJ -3.423034 | VAR_main 0.410763 | VAR_aux 2.911705 | MI -0.17115 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [2]
# ITR/SuccR    1/2.000 | OBJ -3.424335 | VAR_main 0.410191 | VAR_aux 2.920131 | MI -0.17122 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [27]
# ITR/SuccR    1/2.500 | OBJ -3.442152 | VAR_main 0.412325 | VAR_aux 2.888006 | MI -0.17211 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [23]
# ITR/SuccR    1/3.000 | OBJ -3.447884 | VAR_main 0.410777 | VAR_aux 2.894074 | MI -0.17239 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [26]
# ITR/SuccR    2/2.333 | OBJ -3.450569 | VAR_main 0.415308 | VAR_aux 2.871523 | MI -0.17253 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [32]
# ITR/SuccR    2/2.667 | OBJ -3.461007 | VAR_main 0.413996 | VAR_aux 2.913357 | MI -0.17305 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [12]
# ITR/SuccR    2/3.000 | OBJ -3.466145 | VAR_main 0.413666 | VAR_aux 2.894177 | MI -0.17331 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [25]
# ITR/SuccR    2/3.333 | OBJ -3.472282 | VAR_main 0.413074 | VAR_aux 2.913306 | MI -0.17361 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [17]
# ITR/SuccR    3/2.750 | OBJ -3.474829 | VAR_main 0.412773 | VAR_aux 3.026962 | MI -0.17374 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [27]
# ITR/SuccR    3/3.000 | OBJ -3.475927 | VAR_main 0.411880 | VAR_aux 2.907359 | MI -0.17380 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [31]
# ITR/SuccR    3/3.250 | OBJ -3.476867 | VAR_main 0.417836 | VAR_aux 2.959862 | MI -0.17384 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [7]
# ITR/SuccR    3/3.500 | OBJ -3.481001 | VAR_main 0.413944 | VAR_aux 2.950965 | MI -0.17405 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [26]
# ITR/SuccR    3/3.750 | OBJ -3.497727 | VAR_main 0.451181 | VAR_aux 3.134569 | MI -0.17489 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [3]
# ITR/SuccR    4/3.200 | OBJ -3.504608 | VAR_main 0.462962 | VAR_aux 3.121956 | MI -0.17523 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [11]
# ITR/SuccR    4/3.400 | OBJ -3.511379 | VAR_main 0.445821 | VAR_aux 3.084025 | MI -0.17557 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [33]
# ITR/SuccR    4/3.600 | OBJ -3.516527 | VAR_main 0.451388 | VAR_aux 3.151406 | MI -0.17583 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [7]
# ITR/SuccR    5/3.167 | OBJ -3.526005 | VAR_main 0.451385 | VAR_aux 3.214660 | MI -0.17630 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [12]
# ITR/SuccR    5/3.333 | OBJ -3.526119 | VAR_main 0.449455 | VAR_aux 3.151264 | MI -0.17631 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [27]
# ITR/SuccR    5/3.500 | OBJ -3.529451 | VAR_main 0.450341 | VAR_aux 3.158431 | MI -0.17647 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [9]
# ITR/SuccR    5/3.667 | OBJ -3.544283 | VAR_main 0.444364 | VAR_aux 3.109882 | MI -0.17721 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [4]
# ITR/SuccR    6/3.286 | OBJ -3.554917 | VAR_main 0.442288 | VAR_aux 3.119436 | MI -0.17775 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [27]
# ITR/SuccR    6/3.429 | OBJ -3.559884 | VAR_main 0.446417 | VAR_aux 3.139900 | MI -0.17799 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [27]
# ITR/SuccR    6/3.571 | OBJ -3.567836 | VAR_main 0.473824 | VAR_aux 3.119565 | MI -0.17839 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [3]
# ITR/SuccR    7/3.250 | OBJ -3.569076 | VAR_main 0.463059 | VAR_aux 3.109049 | MI -0.17845 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [28]
# ITR/SuccR    7/3.375 | OBJ -3.573374 | VAR_main 0.451648 | VAR_aux 3.180539 | MI -0.17867 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [17]
# ITR/SuccR    7/3.500 | OBJ -3.577255 | VAR_main 0.469557 | VAR_aux 3.146142 | MI -0.17886 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [30]
# ITR/SuccR    7/3.625 | OBJ -3.582088 | VAR_main 0.477959 | VAR_aux 3.153527 | MI -0.17910 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [11]
# ITR/SuccR    7/3.750 | OBJ -3.586131 | VAR_main 0.472736 | VAR_aux 3.139834 | MI -0.17931 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [7]
# ITR/SuccR    8/3.444 | OBJ -3.589285 | VAR_main 0.471764 | VAR_aux 3.114788 | MI -0.17946 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [31]
# ITR/SuccR    8/3.556 | OBJ -3.594324 | VAR_main 0.502847 | VAR_aux 3.162776 | MI -0.17972 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [5]
# ITR/SuccR    8/3.667 | OBJ -3.598865 | VAR_main 0.464785 | VAR_aux 3.104873 | MI -0.17994 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [16]
# ITR/SuccR    8/3.778 | OBJ -3.609679 | VAR_main 0.472703 | VAR_aux 3.158454 | MI -0.18048 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [39]
# ITR/SuccR    9/3.500 | OBJ -3.615017 | VAR_main 0.479775 | VAR_aux 3.164119 | MI -0.18075 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [8]
# ITR/SuccR    9/3.600 | OBJ -3.617917 | VAR_main 0.479174 | VAR_aux 3.437044 | MI -0.18090 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [24]
# ITR/SuccR    9/3.700 | OBJ -3.618664 | VAR_main 0.469774 | VAR_aux 3.244320 | MI -0.18093 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [24]
# ITR/SuccR    9/3.800 | OBJ -3.619894 | VAR_main 0.474373 | VAR_aux 3.171648 | MI -0.18099 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [16]
# ITR/SuccR   10/3.545 | OBJ -3.619960 | VAR_main 0.474354 | VAR_aux 3.169692 | MI -0.18100 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [13]
# ITR/SuccR   10/3.636 | OBJ -3.622173 | VAR_main 0.476709 | VAR_aux 3.141766 | MI -0.18111 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [40]
# ITR/SuccR   10/3.727 | OBJ -3.623227 | VAR_main 0.471607 | VAR_aux 3.159732 | MI -0.18116 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [13]
# ITR/SuccR   10/3.818 | OBJ -3.627676 | VAR_main 0.486506 | VAR_aux 3.150864 | MI -0.18138 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [15]
# ITR/SuccR   10/3.909 | OBJ -3.630382 | VAR_main 0.469584 | VAR_aux 3.146549 | MI -0.18152 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [29]
# ITR/SuccR   10/4.000 | OBJ -3.635366 | VAR_main 0.480295 | VAR_aux 3.192669 | MI -0.18177 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [16]
# ITR/SuccR   10/4.091 | OBJ -3.638214 | VAR_main 0.474665 | VAR_aux 3.232012 | MI -0.18191 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [26]
# ITR/SuccR   11/3.833 | OBJ -3.641813 | VAR_main 0.479100 | VAR_aux 3.249180 | MI -0.18209 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [31]
# ITR/SuccR   11/3.917 | OBJ -3.646511 | VAR_main 0.474963 | VAR_aux 3.248806 | MI -0.18233 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [16]
# ITR/SuccR   11/4.000 | OBJ -3.650679 | VAR_main 0.464338 | VAR_aux 3.275920 | MI -0.18253 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [22]
# ITR/SuccR   11/4.083 | OBJ -3.656738 | VAR_main 0.470752 | VAR_aux 3.237788 | MI -0.18284 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [14]
# ITR/SuccR   12/3.846 | OBJ -3.668177 | VAR_main 0.473130 | VAR_aux 3.265034 | MI -0.18341 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [6]
# ITR/SuccR   12/3.923 | OBJ -3.669508 | VAR_main 0.470443 | VAR_aux 3.340879 | MI -0.18348 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [9]
# ITR/SuccR   12/4.000 | OBJ -3.675683 | VAR_main 0.470192 | VAR_aux 3.242126 | MI -0.18378 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [6]
# ITR/SuccR   13/3.786 | OBJ -3.676064 | VAR_main 0.470631 | VAR_aux 3.233646 | MI -0.18380 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [16]
# ITR/SuccR   13/3.857 | OBJ -3.691425 | VAR_main 0.473861 | VAR_aux 3.217843 | MI -0.18457 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [3]
# ITR/SuccR   14/3.667 | OBJ -3.695061 | VAR_main 0.476631 | VAR_aux 3.166537 | MI -0.18475 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [21]
# ITR/SuccR   14/3.733 | OBJ -3.698812 | VAR_main 0.477658 | VAR_aux 3.261913 | MI -0.18494 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [10]
# ITR/SuccR   14/3.800 | OBJ -3.698920 | VAR_main 0.473399 | VAR_aux 3.120664 | MI -0.18495 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [21]
# ITR/SuccR   14/3.867 | OBJ -3.702277 | VAR_main 0.480758 | VAR_aux 3.159128 | MI -0.18511 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [19]
# ITR/SuccR   15/3.688 | OBJ -3.712629 | VAR_main 0.523179 | VAR_aux 3.156972 | MI -0.18563 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [47]
# ITR/SuccR   15/3.750 | OBJ -3.715924 | VAR_main 0.481065 | VAR_aux 3.166090 | MI -0.18580 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [20]
# ITR/SuccR   15/3.812 | OBJ -3.719004 | VAR_main 0.522169 | VAR_aux 3.196089 | MI -0.18595 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [17]
# ITR/SuccR   16/3.647 | OBJ -3.726975 | VAR_main 0.523214 | VAR_aux 3.200227 | MI -0.18635 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [4]
# ITR/SuccR   16/3.706 | OBJ -3.729551 | VAR_main 0.525149 | VAR_aux 3.237136 | MI -0.18648 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [14]
# ITR/SuccR   16/3.765 | OBJ -3.730797 | VAR_main 0.521871 | VAR_aux 3.346541 | MI -0.18654 |  5C x  1Z | SIZ  50 | ENT 3.9120
#     GAP USED: [12]
# ITR/SuccR   16/3.824 | OBJ -3.732518 | VAR_main 0.513909 | VAR_aux 3.187648 | MI -0.18663 |  5C x  1Z | SIZ  50 | ENT 3.9120
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 5
#       1 # =========================================================
#       2 # RUN GRIZZLY
#       3 # =========================================================
#       4
# ----> 5 gbfs.run(
#       6     max_iterations=1000,
#       7     max_open_set_size=2000,
#       8     top_k=1,
#
# File ~/projects/graphical-sampling/graphical_sampling/search/gbfs.py:227, in GreedyBestFirstSearch.run(self, max_iterations, max_open_set_size, top_k, num_new_order_nodes, num_new_exchange_nodes, num_clusters_range, num_zones_range, num_changes_range, num_zone_changes, pull_strategy, exchange_coef, num_explore, window, n_jobs, backtrack_depth, stagnation_limit, output_details, y_main, y_aux)
#     224 designs_to_eval = list(unique_neighbors.keys())
#     226 # 4. Parallel Evaluation
# --> 227 criteria_values = Parallel(n_jobs=n_jobs)(delayed(self.criteria)(d) for d in designs_to_eval)
#     229 # 5. Process Results
#     230 improved_this_iter = False
#
# File ~/projects/graphical-sampling/.venv/lib/python3.12/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/projects/graphical-sampling/.venv/lib/python3.12/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/projects/graphical-sampling/.venv/lib/python3.12/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# ###  Variance optimization with moran constrain!

# %%
class VarianceWithMoranConstraint:
    def __init__(self, mi_max=-0.49, rho=1e5, var_ref=None, moran_method="tille"):
        self.mi_max = mi_max
        self.rho = rho
        self.var_ref = var_ref
        self.moran_method = moran_method

    def __call__(self, design):
        # variance objective
        var = design.nht_variance

        # normalize variance so that penalty scale is meaningful
        if self.var_ref is None:
            var_part = var
        else:
            var_part = var / self.var_ref

        # expected Moran's I of the design
        mi = design.moran[0]

        # penalty only if Moran becomes worse than the allowed bound
        violation = max(0.0, mi - self.mi_max)

        return var_part + self.rho * violation**2



class VarHardMI:
    def __init__(self, mi_max=-0.595, bad=1e99):
        self.mi_max = mi_max
        self.bad = bad

    def __call__(self, design):
        mi = design.moran[0]
        if mi > self.mi_max:
            return self.bad
        return design.nht_variance

# %%
design = gbfs.best_design

# %%
# -----------------------------------------------
# Stage 1 result: your MI-optimized design
# -----------------------------------------------

design.pop._variable = y_main.astype(float)
design._nht_variance = None



# mi_design = gbfs.best_design          # the design that reached around -0.50
mi_value  = design.moran[0]
var_ref   = design.nht_variance
print(var_ref)
print("Starting MI:", mi_value)
print("Starting Var:", var_ref)

# -----------------------------------------------
# Stage 2: optimize variance while preserving MI
# -----------------------------------------------

criteria_var_given_mi = VarianceWithMoranConstraint(
    mi_max=-0.5955,
    rho=1e4,
    var_ref=var_ref
)

# criteria_var_given_mi = VarHardMI(
#     mi_max=-0.5955,
#     bad=1e99
# )

gbfs2 = gs.search.GreedyBestFirstSearch(
    [design],
    criteria_var_given_mi
)

gbfs2.run(
    max_iterations=2000,
    max_open_set_size=500,
    top_k=1,
    num_new_order_nodes=500,
    num_new_exchange_nodes=0,
    num_clusters_range=(1, 1),
    num_zones_range=(1, 1),
    num_changes_range=(1, 1),
    num_zone_changes=0,
    pull_strategy="default",
    exchange_coef=0.75,
    num_explore=1,
    window=None,
    n_jobs=-1,
    backtrack_depth=50,
    stagnation_limit=5000,
    output_details=False,
    # ADD THESE
    y_main=y_main,
    y_aux=y_aux
)

best_var_design = gbfs2.best_design

print("Final MI:", best_var_design.moran[0])
print("Final Var:", best_var_design.nht_variance)
print("Final criterion:", criteria_var_given_mi(best_var_design))
# Out:
# 3582.873157303173
# Starting MI: -0.6100110574530695
# Starting Var: 3582.873157303173
# Starting fresh: Initializing Open Set.
# --- Parallel GBFS: Batch Size=1, Workers=-1 ---
#     GAP USED: [457]
# ITR/SuccR    0/1.000 | OBJ 0.981550 | VAR_main 0.351677 | VAR_aux 1.666943 | MI -0.60018 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [83]
# ITR/SuccR    0/2.000 | OBJ 0.935646 | VAR_main 0.335230 | VAR_aux 1.623705 | MI -0.59996 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [411]
# ITR/SuccR    0/3.000 | OBJ 0.849266 | VAR_main 0.304281 | VAR_aux 1.542901 | MI -0.59745 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [239]
# ITR/SuccR    0/4.000 | OBJ 0.741062 | VAR_main 0.265513 | VAR_aux 1.491709 | MI -0.60099 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [21]
# ITR/SuccR    1/2.500 | OBJ 0.700593 | VAR_main 0.247414 | VAR_aux 1.416763 | MI -0.59450 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [432]
# ITR/SuccR    1/3.000 | OBJ 0.661762 | VAR_main 0.231139 | VAR_aux 1.599196 | MI -0.59421 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [476]
# ITR/SuccR    1/3.500 | OBJ 0.652509 | VAR_main 0.233384 | VAR_aux 1.516468 | MI -0.59517 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [36]
# ITR/SuccR    1/4.000 | OBJ 0.647746 | VAR_main 0.218279 | VAR_aux 1.482227 | MI -0.59354 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [862]
# ITR/SuccR    8/1.000 | OBJ 0.642551 | VAR_main 0.229338 | VAR_aux 1.585940 | MI -0.59500 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [312]
# ITR/SuccR    9/1.000 | OBJ 0.622729 | VAR_main 0.220179 | VAR_aux 1.563570 | MI -0.59459 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [49]
# ITR/SuccR   10/1.000 | OBJ 0.620162 | VAR_main 0.220993 | VAR_aux 1.577604 | MI -0.59492 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [225]
# ITR/SuccR   16/0.706 | OBJ 0.617677 | VAR_main 0.219323 | VAR_aux 1.573291 | MI -0.59476 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [806]
# ITR/SuccR   17/0.722 | OBJ 0.615548 | VAR_main 0.218204 | VAR_aux 1.574372 | MI -0.59469 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [561]
# ITR/SuccR   18/0.737 | OBJ 0.613231 | VAR_main 0.216102 | VAR_aux 1.570851 | MI -0.59450 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [198]
# ITR/SuccR   24/0.600 | OBJ 0.602267 | VAR_main 0.214247 | VAR_aux 1.559210 | MI -0.59484 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [154]
# ITR/SuccR   25/0.615 | OBJ 0.601915 | VAR_main 0.214121 | VAR_aux 1.509909 | MI -0.59484 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [455]
# ITR/SuccR   28/0.586 | OBJ 0.601797 | VAR_main 0.212528 | VAR_aux 1.505582 | MI -0.59457 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [63]
# ITR/SuccR   36/0.486 | OBJ 0.596898 | VAR_main 0.211878 | VAR_aux 1.458507 | MI -0.59476 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [616]
# ITR/SuccR   41/0.452 | OBJ 0.588540 | VAR_main 0.210853 | VAR_aux 1.476573 | MI -0.59544 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [749]
# ITR/SuccR   44/0.444 | OBJ 0.585000 | VAR_main 0.209084 | VAR_aux 1.487284 | MI -0.59512 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [48]
# ITR/SuccR   48/0.429 | OBJ 0.580458 | VAR_main 0.207305 | VAR_aux 1.572410 | MI -0.59507 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [82]
# ITR/SuccR   51/0.423 | OBJ 0.576904 | VAR_main 0.206204 | VAR_aux 1.596818 | MI -0.59513 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [234]
# ITR/SuccR   52/0.434 | OBJ 0.575741 | VAR_main 0.205787 | VAR_aux 1.611717 | MI -0.59513 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [228]
# ITR/SuccR   56/0.421 | OBJ 0.575633 | VAR_main 0.206077 | VAR_aux 1.596096 | MI -0.59529 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [285]
# ITR/SuccR   56/0.439 | OBJ 0.570701 | VAR_main 0.204239 | VAR_aux 1.601654 | MI -0.59524 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [866]
# ITR/SuccR   57/0.448 | OBJ 0.552821 | VAR_main 0.195178 | VAR_aux 1.560155 | MI -0.59460 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [234]
# ITR/SuccR   59/0.450 | OBJ 0.552481 | VAR_main 0.195056 | VAR_aux 1.665259 | MI -0.59460 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [138]
# ITR/SuccR   60/0.459 | OBJ 0.552107 | VAR_main 0.197349 | VAR_aux 1.673870 | MI -0.59514 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [782]
# ITR/SuccR   75/0.382 | OBJ 0.550611 | VAR_main 0.196512 | VAR_aux 1.610826 | MI -0.59504 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [181]
# ITR/SuccR   92/0.323 | OBJ 0.536363 | VAR_main 0.190789 | VAR_aux 1.591498 | MI -0.59488 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   95/0.323 | OBJ 0.535831 | VAR_main 0.191068 | VAR_aux 1.598218 | MI -0.59500 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [23]
# ITR/SuccR   96/0.330 | OBJ 0.533738 | VAR_main 0.190318 | VAR_aux 1.579301 | MI -0.59500 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [65]
# ITR/SuccR   97/0.337 | OBJ 0.531733 | VAR_main 0.189530 | VAR_aux 1.648081 | MI -0.59498 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [505]
# ITR/SuccR   98/0.343 | OBJ 0.528429 | VAR_main 0.185931 | VAR_aux 1.641471 | MI -0.59453 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   98/0.354 | OBJ 0.521704 | VAR_main 0.186920 | VAR_aux 1.607824 | MI -0.59595 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [26]
# ITR/SuccR   99/0.360 | OBJ 0.520690 | VAR_main 0.186557 | VAR_aux 1.680757 | MI -0.59560 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [118]
# ITR/SuccR   99/0.370 | OBJ 0.518417 | VAR_main 0.185677 | VAR_aux 1.597897 | MI -0.59537 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [289]
# ITR/SuccR  114/0.330 | OBJ 0.517673 | VAR_main 0.185022 | VAR_aux 1.444866 | MI -0.59514 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [106]
# ITR/SuccR  120/0.322 | OBJ 0.502522 | VAR_main 0.176680 | VAR_aux 1.503770 | MI -0.59453 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [254]
# ITR/SuccR  121/0.328 | OBJ 0.500117 | VAR_main 0.175818 | VAR_aux 1.551806 | MI -0.59453 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [203]
# ITR/SuccR  122/0.333 | OBJ 0.499780 | VAR_main 0.175880 | VAR_aux 1.557173 | MI -0.59456 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [167]
# ITR/SuccR  122/0.341 | OBJ 0.493795 | VAR_main 0.175766 | VAR_aux 1.528796 | MI -0.59493 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [211]
# ITR/SuccR  124/0.344 | OBJ 0.493794 | VAR_main 0.175765 | VAR_aux 1.529214 | MI -0.59493 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [454]
# ITR/SuccR  125/0.349 | OBJ 0.491930 | VAR_main 0.175756 | VAR_aux 1.456197 | MI -0.59513 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [574]
# ITR/SuccR  125/0.357 | OBJ 0.484576 | VAR_main 0.167380 | VAR_aux 1.598420 | MI -0.59418 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [384]
# ITR/SuccR  131/0.348 | OBJ 0.484531 | VAR_main 0.167446 | VAR_aux 1.601136 | MI -0.59419 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [88]
# ITR/SuccR  132/0.353 | OBJ 0.481748 | VAR_main 0.166450 | VAR_aux 1.603935 | MI -0.59419 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [68]
# ITR/SuccR  133/0.358 | OBJ 0.480941 | VAR_main 0.166263 | VAR_aux 1.558758 | MI -0.59420 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [222]
# ITR/SuccR  139/0.350 | OBJ 0.479804 | VAR_main 0.165657 | VAR_aux 1.632359 | MI -0.59418 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [154]
# ITR/SuccR  140/0.355 | OBJ 0.478031 | VAR_main 0.165684 | VAR_aux 1.663762 | MI -0.59425 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [454]
# ITR/SuccR  140/0.362 | OBJ 0.477735 | VAR_main 0.164915 | VAR_aux 1.631424 | MI -0.59418 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [13]
# ITR/SuccR  143/0.361 | OBJ 0.470639 | VAR_main 0.167217 | VAR_aux 1.640917 | MI -0.59487 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [231]
# ITR/SuccR  145/0.363 | OBJ 0.470583 | VAR_main 0.167196 | VAR_aux 1.642023 | MI -0.59487 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [547]
# ITR/SuccR  146/0.367 | OBJ 0.468137 | VAR_main 0.166316 | VAR_aux 1.695407 | MI -0.59487 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [107]
# ITR/SuccR  150/0.364 | OBJ 0.464680 | VAR_main 0.164112 | VAR_aux 1.634006 | MI -0.59469 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [90]
# ITR/SuccR  151/0.368 | OBJ 0.461678 | VAR_main 0.163531 | VAR_aux 1.637362 | MI -0.59478 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [17]
# ITR/SuccR  152/0.373 | OBJ 0.461628 | VAR_main 0.163513 | VAR_aux 1.663990 | MI -0.59478 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [685]
# ITR/SuccR  153/0.377 | OBJ 0.460524 | VAR_main 0.163922 | VAR_aux 1.640224 | MI -0.59495 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [616]
# ITR/SuccR  154/0.381 | OBJ 0.459041 | VAR_main 0.164093 | VAR_aux 1.639487 | MI -0.59518 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [110]
# ITR/SuccR  155/0.385 | OBJ 0.458520 | VAR_main 0.164083 | VAR_aux 1.696302 | MI -0.59526 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [189]
# ITR/SuccR  156/0.389 | OBJ 0.456035 | VAR_main 0.163198 | VAR_aux 1.697231 | MI -0.59527 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [230]
# ITR/SuccR  160/0.385 | OBJ 0.455573 | VAR_main 0.163226 | VAR_aux 1.710295 | MI -0.59759 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [75]
# ITR/SuccR  161/0.389 | OBJ 0.450581 | VAR_main 0.154281 | VAR_aux 1.608158 | MI -0.59409 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [768]
# ITR/SuccR  161/0.395 | OBJ 0.450270 | VAR_main 0.161326 | VAR_aux 1.651138 | MI -0.59648 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [361]
# ITR/SuccR  161/0.401 | OBJ 0.423797 | VAR_main 0.104111 | VAR_aux 1.412778 | MI -0.59185 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [142]
# ITR/SuccR  162/0.405 | OBJ 0.398655 | VAR_main 0.104165 | VAR_aux 1.413665 | MI -0.59221 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [32]
# ITR/SuccR  190/0.351 | OBJ 0.397777 | VAR_main 0.101546 | VAR_aux 1.408934 | MI -0.59212 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [777]
# ITR/SuccR  191/0.354 | OBJ 0.388176 | VAR_main 0.101924 | VAR_aux 1.418677 | MI -0.59228 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [556]
# ITR/SuccR  209/0.329 | OBJ 0.380101 | VAR_main 0.121870 | VAR_aux 1.546084 | MI -0.59350 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [118]
# ITR/SuccR  210/0.332 | OBJ 0.378700 | VAR_main 0.121878 | VAR_aux 1.534813 | MI -0.59354 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [453]
# ITR/SuccR  215/0.329 | OBJ 0.365521 | VAR_main 0.121752 | VAR_aux 1.317413 | MI -0.59390 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR  217/0.330 | OBJ 0.365182 | VAR_main 0.121631 | VAR_aux 1.351071 | MI -0.59390 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [671]
# ITR/SuccR  219/0.332 | OBJ 0.355715 | VAR_main 0.121489 | VAR_aux 1.375304 | MI -0.59421 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [222]
# ITR/SuccR  220/0.335 | OBJ 0.341093 | VAR_main 0.121421 | VAR_aux 1.376527 | MI -0.59503 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [178]
# ITR/SuccR  223/0.335 | OBJ 0.340765 | VAR_main 0.120842 | VAR_aux 1.445818 | MI -0.59491 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR  243/0.311 | OBJ 0.340625 | VAR_main 0.118404 | VAR_aux 1.307796 | MI -0.59449 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [192]
# ITR/SuccR  244/0.314 | OBJ 0.339426 | VAR_main 0.118138 | VAR_aux 1.300191 | MI -0.59452 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [175]
# ITR/SuccR  244/0.318 | OBJ 0.335990 | VAR_main 0.118596 | VAR_aux 1.321601 | MI -0.59479 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [30]
# ITR/SuccR  246/0.320 | OBJ 0.333644 | VAR_main 0.117984 | VAR_aux 1.316298 | MI -0.59484 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [559]
# ITR/SuccR  249/0.320 | OBJ 0.327771 | VAR_main 0.116471 | VAR_aux 1.297598 | MI -0.59498 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [59]
# ITR/SuccR  252/0.320 | OBJ 0.319414 | VAR_main 0.114442 | VAR_aux 1.281300 | MI -0.59552 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [617]
# ITR/SuccR  253/0.323 | OBJ 0.319189 | VAR_main 0.114361 | VAR_aux 1.303783 | MI -0.59552 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [559]
# ITR/SuccR  262/0.316 | OBJ 0.316207 | VAR_main 0.112826 | VAR_aux 1.354659 | MI -0.59514 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [365]
# ITR/SuccR  272/0.308 | OBJ 0.316200 | VAR_main 0.113183 | VAR_aux 1.280406 | MI -0.59533 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [27]
# ITR/SuccR  273/0.310 | OBJ 0.315085 | VAR_main 0.112882 | VAR_aux 1.298267 | MI -0.59545 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [542]
# ITR/SuccR  274/0.313 | OBJ 0.314883 | VAR_main 0.112504 | VAR_aux 1.298797 | MI -0.59520 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR  274/0.316 | OBJ 0.314512 | VAR_main 0.112677 | VAR_aux 1.298794 | MI -0.59545 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [41]
# ITR/SuccR  277/0.317 | OBJ 0.313917 | VAR_main 0.112302 | VAR_aux 1.230418 | MI -0.59528 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [77]
# ITR/SuccR  277/0.320 | OBJ 0.313190 | VAR_main 0.111473 | VAR_aux 1.298741 | MI -0.59505 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [707]
# ITR/SuccR  284/0.316 | OBJ 0.302154 | VAR_main 0.108169 | VAR_aux 1.051497 | MI -0.59534 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [157]
# ITR/SuccR  285/0.318 | OBJ 0.301823 | VAR_main 0.108139 | VAR_aux 1.015834 | MI -0.59554 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [856]
# ITR/SuccR  286/0.321 | OBJ 0.300832 | VAR_main 0.107784 | VAR_aux 0.955502 | MI -0.59554 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [93]
# ITR/SuccR  287/0.323 | OBJ 0.300506 | VAR_main 0.107649 | VAR_aux 0.975443 | MI -0.59543 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [565]
# ITR/SuccR  288/0.325 | OBJ 0.300120 | VAR_main 0.106471 | VAR_aux 0.967414 | MI -0.59496 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [624]
# ITR/SuccR  290/0.326 | OBJ 0.296239 | VAR_main 0.106128 | VAR_aux 0.983122 | MI -0.59545 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [436]
# ITR/SuccR  291/0.329 | OBJ 0.296189 | VAR_main 0.105504 | VAR_aux 0.962076 | MI -0.59508 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [635]
# ITR/SuccR  291/0.332 | OBJ 0.294715 | VAR_main 0.105260 | VAR_aux 0.943360 | MI -0.59520 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [318]
# ITR/SuccR  294/0.332 | OBJ 0.294210 | VAR_main 0.105401 | VAR_aux 0.963304 | MI -0.59545 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [552]
# ITR/SuccR  294/0.336 | OBJ 0.293999 | VAR_main 0.105003 | VAR_aux 0.986204 | MI -0.59520 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [305]
# ITR/SuccR  295/0.338 | OBJ 0.292774 | VAR_main 0.104414 | VAR_aux 0.999555 | MI -0.59513 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [33]
# ITR/SuccR  297/0.339 | OBJ 0.290696 | VAR_main 0.104153 | VAR_aux 1.023907 | MI -0.59556 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [95]
# ITR/SuccR  299/0.340 | OBJ 0.289162 | VAR_main 0.101226 | VAR_aux 1.018059 | MI -0.59469 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [817]
# ITR/SuccR  316/0.325 | OBJ 0.284370 | VAR_main 0.101463 | VAR_aux 1.055149 | MI -0.59516 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [718]
# ITR/SuccR  317/0.327 | OBJ 0.282261 | VAR_main 0.100875 | VAR_aux 1.067891 | MI -0.59523 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR  324/0.323 | OBJ 0.280393 | VAR_main 0.099656 | VAR_aux 1.074390 | MI -0.59503 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [77]
# ITR/SuccR  326/0.324 | OBJ 0.279801 | VAR_main 0.098943 | VAR_aux 1.073628 | MI -0.59490 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [638]
# ITR/SuccR  327/0.326 | OBJ 0.274338 | VAR_main 0.098268 | VAR_aux 1.081187 | MI -0.59542 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [67]
# ITR/SuccR  328/0.328 | OBJ 0.272024 | VAR_main 0.097463 | VAR_aux 1.097036 | MI -0.59570 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [726]
# ITR/SuccR  330/0.329 | OBJ 0.271678 | VAR_main 0.097339 | VAR_aux 1.099129 | MI -0.59570 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [663]
# ITR/SuccR  331/0.331 | OBJ 0.271645 | VAR_main 0.097326 | VAR_aux 1.075566 | MI -0.59548 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [604]
# ITR/SuccR  331/0.334 | OBJ 0.270235 | VAR_main 0.096558 | VAR_aux 1.089154 | MI -0.59523 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [721]
# ITR/SuccR  332/0.336 | OBJ 0.269606 | VAR_main 0.096332 | VAR_aux 1.091693 | MI -0.59523 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [625]
# ITR/SuccR  333/0.338 | OBJ 0.268157 | VAR_main 0.095911 | VAR_aux 1.108844 | MI -0.59528 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [154]
# ITR/SuccR  335/0.339 | OBJ 0.262395 | VAR_main 0.091348 | VAR_aux 1.100729 | MI -0.59464 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [865]
# ITR/SuccR  340/0.337 | OBJ 0.259405 | VAR_main 0.089802 | VAR_aux 1.193860 | MI -0.59456 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [575]
# ITR/SuccR  341/0.339 | OBJ 0.259030 | VAR_main 0.089668 | VAR_aux 1.194059 | MI -0.59456 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR  345/0.338 | OBJ 0.255156 | VAR_main 0.088243 | VAR_aux 1.251350 | MI -0.59456 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [367]
# ITR/SuccR  348/0.338 | OBJ 0.254938 | VAR_main 0.088428 | VAR_aux 1.300308 | MI -0.59460 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [13]
# ITR/SuccR  349/0.340 | OBJ 0.251460 | VAR_main 0.085106 | VAR_aux 1.329715 | MI -0.59432 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR  359/0.333 | OBJ 0.248940 | VAR_main 0.085996 | VAR_aux 1.241639 | MI -0.59456 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [442]
# ITR/SuccR  360/0.335 | OBJ 0.247472 | VAR_main 0.086000 | VAR_aux 1.214674 | MI -0.59464 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [74]
# ITR/SuccR  366/0.332 | OBJ 0.239177 | VAR_main 0.083821 | VAR_aux 1.300272 | MI -0.59478 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [324]
# ITR/SuccR  367/0.334 | OBJ 0.233002 | VAR_main 0.082222 | VAR_aux 1.296416 | MI -0.59491 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [618]
# ITR/SuccR  370/0.334 | OBJ 0.227189 | VAR_main 0.081399 | VAR_aux 1.277141 | MI -0.59573 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [34]
# ITR/SuccR  371/0.336 | OBJ 0.227042 | VAR_main 0.081346 | VAR_aux 1.272994 | MI -0.59558 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [55]
# ITR/SuccR  371/0.339 | OBJ 0.224772 | VAR_main 0.080533 | VAR_aux 1.334368 | MI -0.59551 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [669]
# ITR/SuccR  373/0.340 | OBJ 0.224724 | VAR_main 0.080516 | VAR_aux 1.333202 | MI -0.59573 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [664]
# ITR/SuccR  373/0.342 | OBJ 0.224052 | VAR_main 0.080275 | VAR_aux 1.338337 | MI -0.59565 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [69]
# ITR/SuccR  374/0.344 | OBJ 0.223875 | VAR_main 0.080123 | VAR_aux 1.315294 | MI -0.59534 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [741]
# ITR/SuccR  375/0.346 | OBJ 0.219395 | VAR_main 0.078112 | VAR_aux 1.311176 | MI -0.59513 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [211]
# ITR/SuccR  376/0.347 | OBJ 0.219318 | VAR_main 0.078084 | VAR_aux 1.312964 | MI -0.59513 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [557]
# ITR/SuccR  376/0.350 | OBJ 0.218596 | VAR_main 0.077826 | VAR_aux 1.318658 | MI -0.59513 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [33]
# ITR/SuccR  378/0.351 | OBJ 0.217097 | VAR_main 0.077287 | VAR_aux 1.394185 | MI -0.59513 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [669]
# ITR/SuccR  380/0.352 | OBJ 0.215951 | VAR_main 0.077275 | VAR_aux 1.393033 | MI -0.59533 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR  382/0.352 | OBJ 0.215927 | VAR_main 0.077266 | VAR_aux 1.388397 | MI -0.59533 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [734]
# ITR/SuccR  383/0.354 | OBJ 0.215321 | VAR_main 0.077049 | VAR_aux 1.381678 | MI -0.59533 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR  385/0.355 | OBJ 0.215049 | VAR_main 0.077049 | VAR_aux 1.380760 | MI -0.59565 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [177]
# ITR/SuccR  386/0.357 | OBJ 0.214859 | VAR_main 0.076975 | VAR_aux 1.349683 | MI -0.59546 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [369]
# ITR/SuccR  387/0.358 | OBJ 0.214022 | VAR_main 0.076675 | VAR_aux 1.350357 | MI -0.59546 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [134]
# ITR/SuccR  388/0.360 | OBJ 0.213281 | VAR_main 0.076244 | VAR_aux 1.354073 | MI -0.59528 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [267]
# ITR/SuccR  390/0.361 | OBJ 0.212722 | VAR_main 0.076216 | VAR_aux 1.360076 | MI -0.59628 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [153]
# ITR/SuccR  393/0.360 | OBJ 0.212224 | VAR_main 0.076037 | VAR_aux 1.396478 | MI -0.59569 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [86]
# ITR/SuccR  394/0.362 | OBJ 0.212183 | VAR_main 0.076022 | VAR_aux 1.389481 | MI -0.59569 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR  394/0.365 | OBJ 0.210492 | VAR_main 0.075417 | VAR_aux 1.384022 | MI -0.59559 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [663]
# ITR/SuccR  396/0.365 | OBJ 0.210123 | VAR_main 0.075193 | VAR_aux 1.383265 | MI -0.59534 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [467]
# ITR/SuccR  401/0.363 | OBJ 0.206186 | VAR_main 0.073874 | VAR_aux 1.527751 | MI -0.59555 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [238]
# ITR/SuccR  411/0.357 | OBJ 0.204612 | VAR_main 0.073304 | VAR_aux 1.339839 | MI -0.59546 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [453]
# ITR/SuccR  416/0.355 | OBJ 0.203370 | VAR_main 0.072859 | VAR_aux 1.389763 | MI -0.59546 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [134]
# ITR/SuccR  420/0.354 | OBJ 0.203297 | VAR_main 0.072693 | VAR_aux 1.370174 | MI -0.59530 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [862]
# ITR/SuccR  427/0.350 | OBJ 0.202917 | VAR_main 0.072274 | VAR_aux 1.351240 | MI -0.59515 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR  433/0.348 | OBJ 0.201710 | VAR_main 0.072270 | VAR_aux 1.338885 | MI -0.59572 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [252]
# ITR/SuccR  436/0.348 | OBJ 0.201596 | VAR_main 0.072229 | VAR_aux 1.376015 | MI -0.59549 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [796]
# ITR/SuccR  437/0.349 | OBJ 0.201107 | VAR_main 0.072025 | VAR_aux 1.360428 | MI -0.59541 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [389]
# ITR/SuccR  439/0.350 | OBJ 0.198817 | VAR_main 0.070991 | VAR_aux 1.333148 | MI -0.59524 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [93]
# ITR/SuccR  441/0.351 | OBJ 0.196526 | VAR_main 0.070087 | VAR_aux 1.350841 | MI -0.59520 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [145]
# ITR/SuccR  442/0.352 | OBJ 0.196525 | VAR_main 0.070086 | VAR_aux 1.323164 | MI -0.59520 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [886]
# ITR/SuccR  443/0.354 | OBJ 0.193655 | VAR_main 0.068976 | VAR_aux 1.328003 | MI -0.59516 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [7]
# ITR/SuccR  450/0.350 | OBJ 0.191425 | VAR_main 0.068279 | VAR_aux 1.355592 | MI -0.59521 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR  452/0.351 | OBJ 0.190864 | VAR_main 0.068078 | VAR_aux 1.332575 | MI -0.59521 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [681]
# ITR/SuccR  453/0.352 | OBJ 0.186979 | VAR_main 0.066713 | VAR_aux 1.296448 | MI -0.59522 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [487]
# ITR/SuccR  470/0.342 | OBJ 0.185600 | VAR_main 0.066477 | VAR_aux 1.262290 | MI -0.59542 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [659]
# ITR/SuccR  471/0.343 | OBJ 0.184650 | VAR_main 0.066158 | VAR_aux 1.293798 | MI -0.59562 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [118]
# ITR/SuccR  472/0.345 | OBJ 0.184450 | VAR_main 0.066074 | VAR_aux 1.300326 | MI -0.59544 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [471]
# ITR/SuccR  473/0.346 | OBJ 0.182183 | VAR_main 0.064713 | VAR_aux 1.279460 | MI -0.59510 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [146]
# ITR/SuccR  477/0.345 | OBJ 0.181909 | VAR_main 0.064923 | VAR_aux 1.355348 | MI -0.59523 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [24]
# ITR/SuccR  478/0.347 | OBJ 0.181857 | VAR_main 0.064736 | VAR_aux 1.329826 | MI -0.59516 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [9]
# ITR/SuccR  478/0.349 | OBJ 0.173766 | VAR_main 0.057324 | VAR_aux 1.348214 | MI -0.59433 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [54]
# ITR/SuccR  489/0.343 | OBJ 0.171443 | VAR_main 0.056056 | VAR_aux 1.262664 | MI -0.59428 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [524]
# ITR/SuccR  490/0.344 | OBJ 0.168998 | VAR_main 0.056068 | VAR_aux 1.267876 | MI -0.59438 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [485]
# ITR/SuccR  490/0.346 | OBJ 0.168233 | VAR_main 0.056979 | VAR_aux 1.255589 | MI -0.59454 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [261]
# ITR/SuccR  495/0.345 | OBJ 0.166472 | VAR_main 0.056335 | VAR_aux 1.303780 | MI -0.59454 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [102]
# ITR/SuccR  498/0.345 | OBJ 0.166112 | VAR_main 0.056682 | VAR_aux 1.305690 | MI -0.59461 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [725]
# ITR/SuccR  499/0.346 | OBJ 0.162656 | VAR_main 0.055689 | VAR_aux 1.315166 | MI -0.59465 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [47]
# ITR/SuccR  501/0.347 | OBJ 0.162229 | VAR_main 0.055536 | VAR_aux 1.310717 | MI -0.59465 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [201]
# ITR/SuccR  506/0.345 | OBJ 0.161058 | VAR_main 0.055653 | VAR_aux 1.347595 | MI -0.59474 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [261]
# ITR/SuccR  508/0.346 | OBJ 0.158155 | VAR_main 0.055964 | VAR_aux 1.318371 | MI -0.59506 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [51]
# ITR/SuccR  509/0.347 | OBJ 0.156363 | VAR_main 0.055973 | VAR_aux 1.319839 | MI -0.59538 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [34]
# ITR/SuccR  510/0.348 | OBJ 0.156280 | VAR_main 0.055934 | VAR_aux 1.299769 | MI -0.59537 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [86]
# ITR/SuccR  521/0.343 | OBJ 0.155145 | VAR_main 0.054841 | VAR_aux 1.318133 | MI -0.59504 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [52]
# ITR/SuccR  522/0.344 | OBJ 0.154387 | VAR_main 0.055313 | VAR_aux 1.318160 | MI -0.59548 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [473]
# ITR/SuccR  523/0.345 | OBJ 0.153758 | VAR_main 0.054822 | VAR_aux 1.312998 | MI -0.59523 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [215]
# ITR/SuccR  526/0.345 | OBJ 0.152027 | VAR_main 0.054126 | VAR_aux 1.303101 | MI -0.59519 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [457]
# ITR/SuccR  528/0.346 | OBJ 0.151399 | VAR_main 0.053804 | VAR_aux 1.322162 | MI -0.59515 |  1C x  1Z | SIZ  20 | ENT 2.9957
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 37
#      27 # criteria_var_given_mi = VarHardMI(
#      28 #     mi_max=-0.5955,
#      29 #     bad=1e99
#      30 # )
#      32 gbfs2 = gs.search.GreedyBestFirstSearch(
#      33     [design],
#      34     criteria_var_given_mi
#      35 )
# ---> 37 gbfs2.run(
#      38     max_iterations=2000,
#      39     max_open_set_size=500,
#      40     top_k=1,
#      41     num_new_order_nodes=500,
#      42     num_new_exchange_nodes=0,
#      43     num_clusters_range=(1, 1),
#      44     num_zones_range=(1, 1),
#      45     num_changes_range=(1, 1),
#      46     num_zone_changes=0,
#      47     pull_strategy="default",
#      48     exchange_coef=0.75,
#      49     num_explore=1,
#      50     window=None,
#      51     n_jobs=-1,
#      52     backtrack_depth=50,
#      53     stagnation_limit=5000,
#      54     output_details=False,
#      55     # ADD THESE
#      56     y_main=y_main,
#      57     y_aux=y_aux
#      58 )
#      60 best_var_design = gbfs2.best_design
#      62 print("Final MI:", best_var_design.moran[0])
#
# File ~/projects/graphical-sampling/graphical_sampling/search/gbfs.py:212, in GreedyBestFirstSearch.run(self, max_iterations, max_open_set_size, top_k, num_new_order_nodes, num_new_exchange_nodes, num_clusters_range, num_zones_range, num_changes_range, num_zone_changes, pull_strategy, exchange_coef, num_explore, window, n_jobs, backtrack_depth, stagnation_limit, output_details, y_main, y_aux)
#     206         order_neighbors = self._order_neighbors(
#     207             current_design, self._get(num_new_order_nodes, iteration),
#     208             num_clusters, num_zones, num_changes, self._get(num_zone_changes, iteration), current_window
#     209         )
#     210         neighbors = chain(neighbors, order_neighbors)
# --> 212     all_neighbors.extend(neighbors)
#     214 # 3. Deduplication
#     215 unique_neighbors = {}
#
# File ~/projects/graphical-sampling/graphical_sampling/search/gbfs.py:87, in GreedyBestFirstSearch._order_neighbors(self, design, num_new_nodes, num_clusters, num_zones, num_changes, num_zone_changes, window)
#      85 def _order_neighbors(self, design, num_new_nodes, num_clusters, num_zones, num_changes, num_zone_changes, window) -> Generator:
#      86     for _ in range(num_new_nodes):
# ---> 87         yield 'order_change', self._apply_order_change(design, num_clusters, num_zones, num_changes, num_zone_changes, window)
#
# File ~/projects/graphical-sampling/graphical_sampling/search/gbfs.py:80, in GreedyBestFirstSearch._apply_order_change(design, num_clusters, num_zones, num_changes, num_zone_changes, window)
#      72 new_order._last_swap_info = []
#      74 new_order.change(
#      75     num_clusters, num_zones, num_changes, num_zone_changes,
#      76     window=window,
#      77     debugger_func=swap_debugger
#      78 )
# ---> 80 new_design = design.from_order(design.pop, new_order)
#      81 new_design._swap_info = new_order._last_swap_info
#      83 return new_design
#
# File ~/projects/graphical-sampling/graphical_sampling/design.py:59, in Design.from_order(cls, population, order)
#      56 design._heaps = [_MaxHeap() for _ in range(order.num_zones)]
#      57 design._rng = np.random.default_rng()
# ---> 59 design._build()
#      60 cls._reset_stats(design)
#      62 return design
#
# File ~/projects/graphical-sampling/graphical_sampling/design.py:144, in Design._build(self)
#     142     z_idx = min(int(mid * self.num_partitions), self.num_partitions - 1)
#     143     self._push(z_idx, _Sample(point - last_point, frozenset(active)))
# --> 144 if event_type == "start": active.add(int(bar_index))
#     145 elif event_type == "end": active.discard(int(bar_index))
#     146 last_point = point
#
# KeyboardInterrupt:

# %% [markdown]
# ## Store

# %%
samples, probs = design.all_samples_and_probs

tx = y_aux[samples].sum(axis=1) / design.pop.inclusions[samples].mean()
ty = y_main[samples].sum(axis=1) / design.pop.inclusions[samples].mean()

print(np.corrcoef(tx, ty)[0, 1])
# Out:
# 0.5342013368259646

# %%
N = design.pop.N
n = design.pop.n

tx = (N / n) * y_aux[samples].sum(axis=1)
ty = (N / n) * y_main[samples].sum(axis=1)

print("unit correlation:", np.corrcoef(y_aux, y_main)[0, 1])
print("estimator correlation:", np.corrcoef(tx, ty)[0, 1])
# Out:
# unit correlation: 0.9003918608888722
# estimator correlation: 0.5342013368259643

# %%
resid = y_main - np.polyval(np.polyfit(y_aux, y_main, 1), y_aux)

print("Var x:", np.var(y_aux))
print("Var residual:", np.var(resid))
print("Residual / main:", np.var(resid) / np.var(y_main))
# Out:
# Var x: 2.5424770546385873
# Var residual: 0.3883954371790588
# Residual / main: 0.1892944968450734

# %%
plt.scatter(tx,ty)

# %%
# =========================================================
# FULL DEBUG: NHT VARIANCE FOR A DESIGN
# =========================================================

import numpy as np
import pandas as pd

# choose variable
y = y_main          # or y_aux

# design object
d = design

# =========================================================
# 1. GET ALL SAMPLES AND PROBABILITIES
# =========================================================

samples, probs = d.all_samples_and_probs
pik = d.pop.inclusions

print("Support size:", len(samples))
print("Sum probs:", probs.sum())
print("Sample size check:", np.unique([len(s) for s in samples]))

# =========================================================
# 2. MANUAL NHT ESTIMATORS
# =========================================================

ht = []

for s in samples:

    ht_s = np.sum(y[s] / pik[s])

    ht.append(ht_s)

ht = np.array(ht)

true_total = y.sum()

# =========================================================
# 3. MANUAL VARIANCE BY LOOP
# =========================================================

var_loop = 0.0

for h, p in zip(ht, probs):

    var_loop += p * (h - true_total) ** 2

# =========================================================
# 4. MANUAL VARIANCE VECTORIZED
# =========================================================

var_vec = np.sum(
    probs * (ht - true_total) ** 2
)

# =========================================================
# 5. PACKAGE VARIANCE
# =========================================================

d.pop._variable = y
d._nht_variance = None

var_package = d.nht_variance

# =========================================================
# 6. YOUR HELPER FUNCTION
# =========================================================

var_function = nht_variance_for_variable(d, y)

# =========================================================
# 7. PRINT COMPARISON
# =========================================================

print("\n================================================")
print("VARIANCE CHECK")
print("================================================")

print("True total:", true_total)

print("Manual loop:      ", var_loop)
print("Manual vectorized: ", var_vec)
print("Package:          ", var_package)
print("Helper function:  ", var_function)

print("\n/10000:")
print("Manual loop:      ", var_loop / 10000)
print("Package:          ", var_package / 10000)
print("Helper function:  ", var_function / 10000)

# =========================================================
# 8. TABLE OF ALL NHT ESTIMATORS
# =========================================================

debug_df = pd.DataFrame({
    "prob": probs,
    "NHT": ht,
    "true_total": true_total,
    "deviation": ht - true_total,
    "weighted_sq_dev": probs * (ht - true_total) ** 2,
})

print("\n================================================")
print("NHT ESTIMATORS")
print("================================================")

display(debug_df)

print("\nSum weighted squared deviations:")
print(debug_df["weighted_sq_dev"].sum())

# %%
# =========================================================
# INITIAL DESIGN SUMMARY
# =========================================================


# =========================================================
# CHECK INITIAL DESIGN
# =========================================================
print(
    "NHT Var aux / 10000:",
    nht_variance_for_variable(best_initial_design, y_aux) / 10000
)

print(
    "NHT Var main / 10000:",
    nht_variance_for_variable(best_initial_design, y_main) / 10000
)

print("Var main:", np.var(y_main))
print("Var aux:", np.var(y_aux))

print(
    "Corr:",
    np.corrcoef(y_main, y_aux)[0, 1]
)




best_initial_design = out["best_design"]

best_value = out["best_value"]

print("Objective:", best_value)

print(
    "Number of support samples:",
    len(best_initial_design.all_samples_and_probs[0])
)

print(
    "Sum probs:",
    best_initial_design.all_samples_and_probs[1].sum()
)

print(
    "NHT Var aux / 10000:",
    nht_variance_for_variable(
        best_initial_design,
        y_aux
    ) / 10000
)

print(
    "NHT Var main / 10000:",
    nht_variance_for_variable(
        best_initial_design,
        y_main
    ) / 10000
)

print(
    "MI:",
    best_initial_design.moran[0]
)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_main, y_aux)

# %%
# =========================================================
# EXTRACT CURRENT BEST DESIGN AND CHECK VARIANCES
# =========================================================

best_design = gbfs.best_design

print("Objective:", gbfs.best_criteria_value)

print(
    "NHT Var aux / 10000:",
    nht_variance_for_variable(best_design, y_aux) / 10000
)

print(
    "NHT Var main / 10000:",
    nht_variance_for_variable(best_design, y_main) / 10000
)

print(
    "MI:",
    best_design.moran[0]
)

print(
    "Support size:",
    len(best_design.all_samples_and_probs[0])
)

print(
    "Sum probs:",
    best_design.all_samples_and_probs[1].sum()
)
# Out:
# Objective: -1.8862465928697292
# NHT Var aux / 10000: 0.0023546027666813928
# NHT Var main / 10000: 1.0893476168860177
# MI: -0.31712146871242564
# Support size: 20
# Sum probs: 1.0

# %%
# =========================================================
# ALL NHT ESTIMATORS FOR A DESIGN
# =========================================================

def nht_estimators(design, y):

    samples, probs = design.all_samples_and_probs
    pik = design.pop.inclusions

    ht = np.sum(
        y[samples] / pik[samples],
        axis=1
    )

    return ht, probs


# =========================================================
# AUXILIARY
# =========================================================

ht_aux, probs = nht_estimators(best_design, y_aux)

print("AUX true total:", y_aux.sum())
print("AUX NHT estimators:")
print(ht_aux)
print("AUX probs:")
print(probs)
print("AUX variance:", np.sum(probs * (ht_aux - y_aux.sum())**2) / 10000)


# =========================================================
# MAIN
# =========================================================

ht_main, probs = nht_estimators(best_design, y_main)

print("\nMAIN true total:", y_main.sum())
print("MAIN NHT estimators:")
print(ht_main)
print("MAIN probs:")
print(probs)
print("MAIN variance:", np.sum(probs * (ht_main - y_main.sum())**2) / 10000)
# Out:
# AUX true total: 3.268496584496461e-13
# AUX NHT estimators:
# [ 2.03530553  2.37601307 -0.5179482   6.31730308 -8.65401305  0.74610488
#  -4.74685086  3.00239327  0.82459463  8.07345512  3.37175407  0.65842596
#  -0.12249554 -7.24431464 -7.45601981  2.73507386  5.76736026 -1.36739929
#   2.96512805 -8.76387041]
# AUX probs:
# [0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05
#  0.05 0.05 0.05 0.05 0.05 0.05]
# AUX variance: 0.0023546027666813928
#
# MAIN true total: 2999.3156558692144
# MAIN NHT estimators:
# [2955.12335367 2899.18818226 2885.78012389 2827.24077049 2791.29277739
#  2932.8064523  3012.62201646 2987.03022266 3025.25670023 2851.06740206
#  3100.12312625 3082.7105932  3125.41942004 3164.11915002 3090.79133303
#  3119.09012093 3049.74028325 3016.05065813 2988.57223998 3082.28819116]
# MAIN probs:
# [0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05 0.05
#  0.05 0.05 0.05 0.05 0.05 0.05]
# MAIN variance: 1.0893476168860177

# %%
# Save a GRIZZLY
current_file = save_gbfs_state(gbfs)

# %%
best_design = gbfs.best_design
best_design.nht_variance
# Out:
# 66.38647984723404

# %% [markdown]
# ### Global Searching Flatten GRIZZLY!

# %%
# 1. Flatten the entire frontier

# 2. Grab the order from the NEW, flattened design
test_order = gbfs_global.best_design.order.copy()
# Out:
# --- Global Release Initiated ---
# Processing 9880 candidates from the frontier...
# ✅ Success! New engine populated with 9881 global candidates.
# Current Best Score: -0.430736

# %%
test_order.change(
    num_clusters=1, 
    num_zones=1, 
    num_changes=1, 
    num_zone_changes=0, 
    window=120, 
    coords=pop.coords, 
    debugger_func=audit_intelligent_swap
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 test_order.change(
#       2     num_clusters=1,
#       3     num_zones=1,
#       4     num_changes=1,
#
# File ~\graphical-sampling\graphical_sampling\order.py:636, in Order.change(self, num_clusters, num_zones, num_changes, num_zone_changes, window, coords, debugger_func)
#     633 real_id_j = zone._indices[zone.sort[j]]
#     635 if debugger_func is not None:
# --> 636     debugger_func(
#     637         order=self,
#     638         id_i=real_id_i,
#     639         id_j=real_id_j,
#     640         local_i=i,
#     641         local_j=j,
#     642         c_idx=c_idx,
#     643         z_idx=z_idx
#     644     )
#     646 # SWAP THE POINTERS
#     647 zone.sort[i], zone.sort[j] = zone.sort[j], zone.sort[i]
#
# TypeError: audit_intelligent_swap() got an unexpected keyword argument 'order'

# %%
# 1. Flatten / release Grizzly
gbfs_global = release_full_grizzly(gbfs)

# 2. Check flattened order
test_order = gbfs_global.best_design.order.copy()

# 3. Run global Grizzly
gbfs_global.run(
    max_iterations=1000,
    max_open_set_size=2000,
    top_k=1,

    num_new_order_nodes=80,
    num_new_exchange_nodes=0,

    num_clusters_range=(1, 1),
    num_zones_range=(1, 1),
    num_changes_range=(1, 1),
    num_zone_changes=0,

    pull_strategy="default",
    exchange_coef=0.005,

    num_explore=1,
    window=20,

    n_jobs=2,
    backtrack_depth=20,
    stagnation_limit=5000,
    output_details=False,

    y_main=y_main,
    y_aux=y_aux,
)
# Out:
# --- Global Release Initiated ---
# Processing 0 candidates from the frontier...
# ✅ Success! New engine populated with 1 global candidates.
# Current Best Score: 3.546750
# Starting fresh: Initializing Open Set.
# --- Parallel GBFS: Batch Size=1, Workers=2 ---
#     GAP USED: [10]
# ITR/SuccR    0/1.000 | OBJ 3.543277 | VAR_main 1.150082 | VAR_aux 0.841250 | MI -0.39091 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR    0/2.000 | OBJ 3.527368 | VAR_main 1.165339 | VAR_aux 0.838725 | MI -0.39062 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [9]
# ITR/SuccR    0/3.000 | OBJ 3.424826 | VAR_main 1.150016 | VAR_aux 0.824317 | MI -0.39090 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR    0/4.000 | OBJ 3.103155 | VAR_main 1.103734 | VAR_aux 0.777224 | MI -0.38957 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR    1/2.500 | OBJ 3.042141 | VAR_main 1.092814 | VAR_aux 0.766401 | MI -0.38711 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [19]
# ITR/SuccR    1/3.000 | OBJ 2.831427 | VAR_main 1.097352 | VAR_aux 0.735759 | MI -0.38648 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR    2/2.333 | OBJ 2.794132 | VAR_main 1.106087 | VAR_aux 0.730229 | MI -0.38625 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR    2/2.667 | OBJ 2.745620 | VAR_main 1.121019 | VAR_aux 0.720597 | MI -0.38309 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR    2/3.000 | OBJ 2.744833 | VAR_main 1.097350 | VAR_aux 0.722690 | MI -0.38567 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [13]
# ITR/SuccR    2/3.333 | OBJ 2.691361 | VAR_main 1.060078 | VAR_aux 0.715181 | MI -0.38582 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR    2/3.667 | OBJ 2.532217 | VAR_main 1.033905 | VAR_aux 0.690243 | MI -0.38325 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [16]
# ITR/SuccR    2/4.000 | OBJ 2.431295 | VAR_main 1.018388 | VAR_aux 0.676806 | MI -0.38439 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR    3/3.250 | OBJ 2.416283 | VAR_main 1.016829 | VAR_aux 0.671947 | MI -0.38122 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR    3/3.500 | OBJ 2.290218 | VAR_main 1.023444 | VAR_aux 0.656518 | MI -0.38423 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR    3/3.750 | OBJ 2.273009 | VAR_main 1.001040 | VAR_aux 0.651690 | MI -0.38147 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [17]
# ITR/SuccR    3/4.000 | OBJ 2.271573 | VAR_main 0.941337 | VAR_aux 0.650466 | MI -0.38028 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [11]
# ITR/SuccR    3/4.250 | OBJ 2.265155 | VAR_main 1.020020 | VAR_aux 0.652355 | MI -0.38356 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR    3/4.500 | OBJ 2.096832 | VAR_main 0.901384 | VAR_aux 0.626356 | MI -0.38128 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [7]
# ITR/SuccR    4/3.800 | OBJ 2.029746 | VAR_main 0.879872 | VAR_aux 0.616641 | MI -0.38112 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR    4/4.000 | OBJ 1.921468 | VAR_main 0.865072 | VAR_aux 0.599271 | MI -0.37891 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [17]
# ITR/SuccR    4/4.200 | OBJ 1.742867 | VAR_main 0.824569 | VAR_aux 0.572967 | MI -0.37798 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR    5/3.667 | OBJ 1.693229 | VAR_main 0.812394 | VAR_aux 0.565871 | MI -0.37798 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR    5/3.833 | OBJ 1.465623 | VAR_main 0.766896 | VAR_aux 0.530842 | MI -0.37504 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR    5/4.000 | OBJ 1.426478 | VAR_main 0.791283 | VAR_aux 0.527306 | MI -0.37744 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR    6/3.571 | OBJ 1.306621 | VAR_main 0.809689 | VAR_aux 0.507220 | MI -0.37399 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [12]
# ITR/SuccR    6/3.714 | OBJ 1.295695 | VAR_main 0.770588 | VAR_aux 0.507318 | MI -0.37592 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR    6/3.857 | OBJ 1.196682 | VAR_main 0.728265 | VAR_aux 0.492270 | MI -0.37487 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR    6/4.000 | OBJ 1.169482 | VAR_main 0.742563 | VAR_aux 0.489445 | MI -0.37611 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [17]
# ITR/SuccR    6/4.143 | OBJ 1.165726 | VAR_main 0.755820 | VAR_aux 0.487380 | MI -0.37432 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [18]
# ITR/SuccR    7/3.750 | OBJ 1.116482 | VAR_main 0.740827 | VAR_aux 0.478463 | MI -0.37213 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR    7/3.875 | OBJ 0.999993 | VAR_main 0.750159 | VAR_aux 0.462980 | MI -0.37348 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR    7/4.000 | OBJ 0.991398 | VAR_main 0.719931 | VAR_aux 0.461241 | MI -0.37288 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR    7/4.125 | OBJ 0.975624 | VAR_main 0.735578 | VAR_aux 0.459692 | MI -0.37370 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [7]
# ITR/SuccR    7/4.250 | OBJ 0.800913 | VAR_main 0.696793 | VAR_aux 0.433864 | MI -0.37269 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR    8/3.889 | OBJ 0.707815 | VAR_main 0.686496 | VAR_aux 0.420848 | MI -0.37302 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [8]
# ITR/SuccR    8/4.000 | OBJ 0.616824 | VAR_main 0.694954 | VAR_aux 0.406946 | MI -0.37197 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [17]
# ITR/SuccR    8/4.111 | OBJ 0.556417 | VAR_main 0.691721 | VAR_aux 0.396438 | MI -0.36978 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR    9/3.800 | OBJ 0.492930 | VAR_main 0.691327 | VAR_aux 0.387417 | MI -0.36983 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR    9/3.900 | OBJ 0.379811 | VAR_main 0.650830 | VAR_aux 0.369143 | MI -0.36736 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [12]
# ITR/SuccR   10/3.636 | OBJ 0.246665 | VAR_main 0.645144 | VAR_aux 0.347644 | MI -0.36447 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR   10/3.727 | OBJ 0.237318 | VAR_main 0.638674 | VAR_aux 0.347560 | MI -0.36593 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   11/3.500 | OBJ 0.232453 | VAR_main 0.651714 | VAR_aux 0.346153 | MI -0.36510 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   11/3.583 | OBJ 0.220664 | VAR_main 0.638506 | VAR_aux 0.345261 | MI -0.36603 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   11/3.667 | OBJ 0.219259 | VAR_main 0.635934 | VAR_aux 0.343782 | MI -0.36454 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   11/3.750 | OBJ 0.138380 | VAR_main 0.612527 | VAR_aux 0.330886 | MI -0.36297 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [18]
# ITR/SuccR   11/3.833 | OBJ 0.130463 | VAR_main 0.633937 | VAR_aux 0.330281 | MI -0.36358 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   11/3.917 | OBJ 0.108590 | VAR_main 0.616257 | VAR_aux 0.328338 | MI -0.36496 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [7]
# ITR/SuccR   11/4.000 | OBJ 0.107127 | VAR_main 0.609497 | VAR_aux 0.328051 | MI -0.36487 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   11/4.083 | OBJ 0.083333 | VAR_main 0.606809 | VAR_aux 0.323020 | MI -0.36297 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR   12/3.846 | OBJ 0.051629 | VAR_main 0.610704 | VAR_aux 0.316542 | MI -0.36069 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   12/3.923 | OBJ 0.018445 | VAR_main 0.588619 | VAR_aux 0.312748 | MI -0.36180 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   12/4.000 | OBJ -0.072212 | VAR_main 0.615109 | VAR_aux 0.300843 | MI -0.36302 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   12/4.077 | OBJ -0.154861 | VAR_main 0.566587 | VAR_aux 0.287778 | MI -0.36155 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   13/3.857 | OBJ -0.182782 | VAR_main 0.596964 | VAR_aux 0.283814 | MI -0.36158 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR   13/3.929 | OBJ -0.190816 | VAR_main 0.566424 | VAR_aux 0.281932 | MI -0.36072 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [18]
# ITR/SuccR   13/4.000 | OBJ -0.192808 | VAR_main 0.561636 | VAR_aux 0.280356 | MI -0.35922 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR   13/4.071 | OBJ -0.227123 | VAR_main 0.567150 | VAR_aux 0.277289 | MI -0.36136 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [7]
# ITR/SuccR   13/4.143 | OBJ -0.275622 | VAR_main 0.525218 | VAR_aux 0.267031 | MI -0.35747 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [16]
# ITR/SuccR   14/3.933 | OBJ -0.327148 | VAR_main 0.520481 | VAR_aux 0.257557 | MI -0.35501 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR   14/4.000 | OBJ -0.373103 | VAR_main 0.504293 | VAR_aux 0.250921 | MI -0.35493 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [11]
# ITR/SuccR   14/4.067 | OBJ -0.381368 | VAR_main 0.526484 | VAR_aux 0.251242 | MI -0.35668 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   14/4.133 | OBJ -0.408859 | VAR_main 0.524757 | VAR_aux 0.247957 | MI -0.35743 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR   14/4.200 | OBJ -0.448951 | VAR_main 0.527246 | VAR_aux 0.241347 | MI -0.35640 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   15/4.000 | OBJ -0.456244 | VAR_main 0.526675 | VAR_aux 0.240069 | MI -0.35612 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   15/4.062 | OBJ -0.532811 | VAR_main 0.495556 | VAR_aux 0.227204 | MI -0.35387 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [13]
# ITR/SuccR   15/4.125 | OBJ -0.579404 | VAR_main 0.482615 | VAR_aux 0.220339 | MI -0.35363 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [9]
# ITR/SuccR   16/3.941 | OBJ -0.638334 | VAR_main 0.481794 | VAR_aux 0.212026 | MI -0.35375 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [10]
# ITR/SuccR   16/4.000 | OBJ -0.659558 | VAR_main 0.486942 | VAR_aux 0.207479 | MI -0.35199 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [17]
# ITR/SuccR   17/3.833 | OBJ -0.702856 | VAR_main 0.489326 | VAR_aux 0.199383 | MI -0.34976 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [12]
# ITR/SuccR   17/3.889 | OBJ -0.746293 | VAR_main 0.498468 | VAR_aux 0.193970 | MI -0.35068 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   17/3.944 | OBJ -0.854744 | VAR_main 0.447520 | VAR_aux 0.177061 | MI -0.34903 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   18/3.789 | OBJ -0.890927 | VAR_main 0.446309 | VAR_aux 0.171888 | MI -0.34902 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   18/3.842 | OBJ -0.945573 | VAR_main 0.434383 | VAR_aux 0.162564 | MI -0.34725 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   18/3.895 | OBJ -0.963755 | VAR_main 0.447502 | VAR_aux 0.160770 | MI -0.34819 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [18]
# ITR/SuccR   19/3.750 | OBJ -0.992838 | VAR_main 0.447262 | VAR_aux 0.154675 | MI -0.34593 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   19/3.800 | OBJ -1.083252 | VAR_main 0.450484 | VAR_aux 0.142277 | MI -0.34653 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   20/3.667 | OBJ -1.083741 | VAR_main 0.451812 | VAR_aux 0.141359 | MI -0.34554 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [12]
# ITR/SuccR   20/3.714 | OBJ -1.118170 | VAR_main 0.450743 | VAR_aux 0.137091 | MI -0.34630 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   20/3.762 | OBJ -1.129922 | VAR_main 0.453376 | VAR_aux 0.135351 | MI -0.34623 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   20/3.810 | OBJ -1.187842 | VAR_main 0.432879 | VAR_aux 0.126973 | MI -0.34611 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR   21/3.682 | OBJ -1.193063 | VAR_main 0.425474 | VAR_aux 0.123902 | MI -0.34340 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [12]
# ITR/SuccR   21/3.727 | OBJ -1.257398 | VAR_main 0.431374 | VAR_aux 0.116001 | MI -0.34490 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR   22/3.609 | OBJ -1.279592 | VAR_main 0.446412 | VAR_aux 0.110363 | MI -0.34202 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   22/3.652 | OBJ -1.363598 | VAR_main 0.416637 | VAR_aux 0.099977 | MI -0.34391 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   22/3.696 | OBJ -1.397011 | VAR_main 0.407092 | VAR_aux 0.093070 | MI -0.34142 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   23/3.583 | OBJ -1.437774 | VAR_main 0.359704 | VAR_aux 0.085744 | MI -0.33966 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   23/3.625 | OBJ -1.465672 | VAR_main 0.402897 | VAR_aux 0.083222 | MI -0.34137 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [16]
# ITR/SuccR   23/3.667 | OBJ -1.512540 | VAR_main 0.408517 | VAR_aux 0.075751 | MI -0.34047 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   24/3.560 | OBJ -1.519741 | VAR_main 0.407535 | VAR_aux 0.074378 | MI -0.34006 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [17]
# ITR/SuccR   24/3.600 | OBJ -1.527442 | VAR_main 0.402176 | VAR_aux 0.071521 | MI -0.33801 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [17]
# ITR/SuccR   24/3.640 | OBJ -1.532150 | VAR_main 0.399224 | VAR_aux 0.070978 | MI -0.33817 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   24/3.680 | OBJ -1.537893 | VAR_main 0.372534 | VAR_aux 0.072059 | MI -0.34038 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   24/3.720 | OBJ -1.578599 | VAR_main 0.394501 | VAR_aux 0.065173 | MI -0.33914 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [16]
# ITR/SuccR   24/3.760 | OBJ -1.600960 | VAR_main 0.359049 | VAR_aux 0.062109 | MI -0.33929 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [10]
# ITR/SuccR   25/3.654 | OBJ -1.604064 | VAR_main 0.368846 | VAR_aux 0.061023 | MI -0.33854 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   25/3.692 | OBJ -1.615089 | VAR_main 0.330574 | VAR_aux 0.058006 | MI -0.33685 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   25/3.731 | OBJ -1.646928 | VAR_main 0.343842 | VAR_aux 0.055228 | MI -0.33892 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [10]
# ITR/SuccR   25/3.769 | OBJ -1.657940 | VAR_main 0.358479 | VAR_aux 0.052904 | MI -0.33805 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [7]
# ITR/SuccR   26/3.667 | OBJ -1.696169 | VAR_main 0.350667 | VAR_aux 0.047326 | MI -0.33791 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   27/3.571 | OBJ -1.721075 | VAR_main 0.351188 | VAR_aux 0.043554 | MI -0.33766 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   27/3.607 | OBJ -1.723687 | VAR_main 0.284132 | VAR_aux 0.041121 | MI -0.33526 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [17]
# ITR/SuccR   27/3.643 | OBJ -1.728796 | VAR_main 0.350485 | VAR_aux 0.040517 | MI -0.33540 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [17]
# ITR/SuccR   27/3.679 | OBJ -1.730178 | VAR_main 0.353038 | VAR_aux 0.041519 | MI -0.33680 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [18]
# ITR/SuccR   27/3.714 | OBJ -1.730210 | VAR_main 0.350413 | VAR_aux 0.040496 | MI -0.33561 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   28/3.621 | OBJ -1.734238 | VAR_main 0.350341 | VAR_aux 0.040167 | MI -0.33590 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [9]
# ITR/SuccR   28/3.655 | OBJ -1.749771 | VAR_main 0.350915 | VAR_aux 0.037375 | MI -0.33523 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   28/3.690 | OBJ -1.756245 | VAR_main 0.345589 | VAR_aux 0.036203 | MI -0.33494 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   28/3.724 | OBJ -1.763939 | VAR_main 0.333578 | VAR_aux 0.035388 | MI -0.33528 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR   28/3.759 | OBJ -1.764398 | VAR_main 0.356803 | VAR_aux 0.035314 | MI -0.33527 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   29/3.667 | OBJ -1.765904 | VAR_main 0.354563 | VAR_aux 0.034765 | MI -0.33488 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   29/3.700 | OBJ -1.782595 | VAR_main 0.356802 | VAR_aux 0.032755 | MI -0.33531 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   29/3.733 | OBJ -1.783652 | VAR_main 0.343894 | VAR_aux 0.031365 | MI -0.33387 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR   29/3.767 | OBJ -1.788907 | VAR_main 0.331297 | VAR_aux 0.029698 | MI -0.33280 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   30/3.677 | OBJ -1.793444 | VAR_main 0.331301 | VAR_aux 0.029057 | MI -0.33281 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   30/3.710 | OBJ -1.803595 | VAR_main 0.325220 | VAR_aux 0.024542 | MI -0.32923 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [14]
# ITR/SuccR   30/3.742 | OBJ -1.835315 | VAR_main 0.345025 | VAR_aux 0.021744 | MI -0.33125 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   31/3.656 | OBJ -1.836228 | VAR_main 0.351488 | VAR_aux 0.021447 | MI -0.33106 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   31/3.688 | OBJ -1.842165 | VAR_main 0.345626 | VAR_aux 0.020463 | MI -0.33090 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   31/3.719 | OBJ -1.859730 | VAR_main 0.345500 | VAR_aux 0.018126 | MI -0.33110 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [8]
# ITR/SuccR   32/3.636 | OBJ -1.871748 | VAR_main 0.347771 | VAR_aux 0.016334 | MI -0.33101 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   32/3.667 | OBJ -1.874930 | VAR_main 0.337871 | VAR_aux 0.015387 | MI -0.33044 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   32/3.697 | OBJ -1.875870 | VAR_main 0.345408 | VAR_aux 0.015785 | MI -0.33106 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   33/3.618 | OBJ -1.878415 | VAR_main 0.328334 | VAR_aux 0.012553 | MI -0.32771 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   33/3.647 | OBJ -1.883774 | VAR_main 0.346032 | VAR_aux 0.014460 | MI -0.33083 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   34/3.571 | OBJ -1.891904 | VAR_main 0.346042 | VAR_aux 0.013101 | MI -0.33060 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   34/3.600 | OBJ -1.905425 | VAR_main 0.322253 | VAR_aux 0.011145 | MI -0.33057 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [10]
# ITR/SuccR   35/3.528 | OBJ -1.905499 | VAR_main 0.321464 | VAR_aux 0.010524 | MI -0.32986 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [11]
# ITR/SuccR   35/3.556 | OBJ -1.906178 | VAR_main 0.319948 | VAR_aux 0.008865 | MI -0.32804 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   35/3.583 | OBJ -1.912109 | VAR_main 0.327207 | VAR_aux 0.010272 | MI -0.33067 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   36/3.514 | OBJ -1.915713 | VAR_main 0.325460 | VAR_aux 0.009839 | MI -0.33076 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   36/3.541 | OBJ -1.921815 | VAR_main 0.324354 | VAR_aux 0.008779 | MI -0.33054 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [11]
# ITR/SuccR   37/3.474 | OBJ -1.931225 | VAR_main 0.327834 | VAR_aux 0.008597 | MI -0.33190 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   38/3.410 | OBJ -1.931585 | VAR_main 0.327052 | VAR_aux 0.008381 | MI -0.33171 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   38/3.436 | OBJ -1.932323 | VAR_main 0.327382 | VAR_aux 0.008422 | MI -0.33188 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   39/3.375 | OBJ -1.932544 | VAR_main 0.326321 | VAR_aux 0.008441 | MI -0.33194 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [9]
# ITR/SuccR   39/3.400 | OBJ -1.935384 | VAR_main 0.332955 | VAR_aux 0.007429 | MI -0.33123 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [11]
# ITR/SuccR   39/3.425 | OBJ -1.936099 | VAR_main 0.325272 | VAR_aux 0.008433 | MI -0.33252 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [7]
# ITR/SuccR   39/3.450 | OBJ -1.942873 | VAR_main 0.305063 | VAR_aux 0.005671 | MI -0.33043 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR   40/3.390 | OBJ -1.947718 | VAR_main 0.317142 | VAR_aux 0.005641 | MI -0.33120 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   40/3.415 | OBJ -1.947989 | VAR_main 0.308304 | VAR_aux 0.005465 | MI -0.33104 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [8]
# ITR/SuccR   41/3.357 | OBJ -1.949805 | VAR_main 0.304631 | VAR_aux 0.005119 | MI -0.33094 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [8]
# ITR/SuccR   41/3.381 | OBJ -1.952525 | VAR_main 0.302985 | VAR_aux 0.005113 | MI -0.33139 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   42/3.326 | OBJ -1.952848 | VAR_main 0.302404 | VAR_aux 0.005309 | MI -0.33167 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   42/3.349 | OBJ -1.954270 | VAR_main 0.303714 | VAR_aux 0.005143 | MI -0.33171 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [9]
# ITR/SuccR   43/3.295 | OBJ -1.956943 | VAR_main 0.301550 | VAR_aux 0.003871 | MI -0.33067 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [10]
# ITR/SuccR   44/3.244 | OBJ -1.957145 | VAR_main 0.301739 | VAR_aux 0.003745 | MI -0.33056 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   45/3.196 | OBJ -1.957190 | VAR_main 0.301869 | VAR_aux 0.003738 | MI -0.33056 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   45/3.217 | OBJ -1.960883 | VAR_main 0.301758 | VAR_aux 0.003271 | MI -0.33063 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   46/3.170 | OBJ -1.962489 | VAR_main 0.306201 | VAR_aux 0.002698 | MI -0.33023 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [8]
# ITR/SuccR   48/3.061 | OBJ -1.966943 | VAR_main 0.307330 | VAR_aux 0.002617 | MI -0.33088 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   49/3.020 | OBJ -1.967563 | VAR_main 0.306563 | VAR_aux 0.002534 | MI -0.33088 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   50/2.980 | OBJ -1.968231 | VAR_main 0.307452 | VAR_aux 0.002133 | MI -0.33053 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [10]
# ITR/SuccR   51/2.942 | OBJ -1.977076 | VAR_main 0.303061 | VAR_aux 0.002264 | MI -0.33215 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   52/2.906 | OBJ -1.980394 | VAR_main 0.302041 | VAR_aux 0.001835 | MI -0.33221 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   53/2.870 | OBJ -1.980509 | VAR_main 0.301992 | VAR_aux 0.001840 | MI -0.33223 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [13]
# ITR/SuccR   53/2.889 | OBJ -1.983632 | VAR_main 0.302785 | VAR_aux 0.001267 | MI -0.33208 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [16]
# ITR/SuccR   54/2.855 | OBJ -1.987368 | VAR_main 0.304548 | VAR_aux 0.001443 | MI -0.33291 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [18]
# ITR/SuccR   56/2.772 | OBJ -1.989460 | VAR_main 0.299784 | VAR_aux 0.001787 | MI -0.33366 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   57/2.741 | OBJ -1.990433 | VAR_main 0.302445 | VAR_aux 0.001768 | MI -0.33380 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   58/2.712 | OBJ -1.990473 | VAR_main 0.301338 | VAR_aux 0.001751 | MI -0.33379 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   58/2.729 | OBJ -1.990495 | VAR_main 0.302313 | VAR_aux 0.001535 | MI -0.33354 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [19]
# ITR/SuccR   58/2.746 | OBJ -1.991615 | VAR_main 0.304145 | VAR_aux 0.001549 | MI -0.33374 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR   59/2.717 | OBJ -1.992897 | VAR_main 0.301501 | VAR_aux 0.001918 | MI -0.33439 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [7]
# ITR/SuccR   59/2.733 | OBJ -1.992964 | VAR_main 0.305120 | VAR_aux 0.001504 | MI -0.33392 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [8]
# ITR/SuccR   60/2.705 | OBJ -1.993356 | VAR_main 0.305672 | VAR_aux 0.001497 | MI -0.33397 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR   60/2.721 | OBJ -1.993869 | VAR_main 0.305272 | VAR_aux 0.001541 | MI -0.33411 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   60/2.738 | OBJ -1.993955 | VAR_main 0.302855 | VAR_aux 0.001110 | MI -0.33362 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR   60/2.754 | OBJ -1.994626 | VAR_main 0.298934 | VAR_aux 0.001085 | MI -0.33370 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   60/2.770 | OBJ -1.996476 | VAR_main 0.304271 | VAR_aux 0.001632 | MI -0.33465 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [16]
# ITR/SuccR   61/2.742 | OBJ -1.997864 | VAR_main 0.300940 | VAR_aux 0.001839 | MI -0.33512 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   61/2.758 | OBJ -1.998212 | VAR_main 0.300742 | VAR_aux 0.001449 | MI -0.33473 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   61/2.774 | OBJ -1.998258 | VAR_main 0.306248 | VAR_aux 0.001668 | MI -0.33499 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [16]
# ITR/SuccR   62/2.746 | OBJ -2.001814 | VAR_main 0.295784 | VAR_aux 0.001635 | MI -0.33554 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [8]
# ITR/SuccR   64/2.677 | OBJ -2.003282 | VAR_main 0.295960 | VAR_aux 0.001450 | MI -0.33557 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   64/2.692 | OBJ -2.004175 | VAR_main 0.299843 | VAR_aux 0.001478 | MI -0.33575 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [19]
# ITR/SuccR   65/2.667 | OBJ -2.006067 | VAR_main 0.306895 | VAR_aux 0.001439 | MI -0.33602 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [15]
# ITR/SuccR   65/2.682 | OBJ -2.008278 | VAR_main 0.300659 | VAR_aux 0.001672 | MI -0.33666 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   66/2.657 | OBJ -2.011397 | VAR_main 0.309819 | VAR_aux 0.001729 | MI -0.33725 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [4]
# ITR/SuccR   67/2.632 | OBJ -2.011438 | VAR_main 0.308238 | VAR_aux 0.001247 | MI -0.33669 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   67/2.647 | OBJ -2.011680 | VAR_main 0.309303 | VAR_aux 0.001587 | MI -0.33713 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   68/2.623 | OBJ -2.012261 | VAR_main 0.309393 | VAR_aux 0.001459 | MI -0.33708 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [13]
# ITR/SuccR   68/2.638 | OBJ -2.013401 | VAR_main 0.308893 | VAR_aux 0.001264 | MI -0.33704 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [18]
# ITR/SuccR   68/2.652 | OBJ -2.019666 | VAR_main 0.298880 | VAR_aux 0.001813 | MI -0.33873 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   69/2.629 | OBJ -2.020251 | VAR_main 0.300072 | VAR_aux 0.002035 | MI -0.33908 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [5]
# ITR/SuccR   69/2.643 | OBJ -2.027862 | VAR_main 0.295386 | VAR_aux 0.001208 | MI -0.33939 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   70/2.620 | OBJ -2.028339 | VAR_main 0.295638 | VAR_aux 0.001135 | MI -0.33938 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   70/2.634 | OBJ -2.028690 | VAR_main 0.295798 | VAR_aux 0.000992 | MI -0.33927 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   70/2.648 | OBJ -2.029795 | VAR_main 0.295007 | VAR_aux 0.001281 | MI -0.33979 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [11]
# ITR/SuccR   70/2.662 | OBJ -2.032111 | VAR_main 0.295427 | VAR_aux 0.001160 | MI -0.34004 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   71/2.639 | OBJ -2.032582 | VAR_main 0.298443 | VAR_aux 0.001199 | MI -0.34016 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   72/2.616 | OBJ -2.033504 | VAR_main 0.298779 | VAR_aux 0.001048 | MI -0.34014 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [6]
# ITR/SuccR   72/2.630 | OBJ -2.035362 | VAR_main 0.297771 | VAR_aux 0.001205 | MI -0.34063 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [7]
# ITR/SuccR   73/2.608 | OBJ -2.035553 | VAR_main 0.298577 | VAR_aux 0.001112 | MI -0.34056 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [12]
# ITR/SuccR   74/2.587 | OBJ -2.035705 | VAR_main 0.301478 | VAR_aux 0.001094 | MI -0.34056 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [1]
# ITR/SuccR   75/2.566 | OBJ -2.035940 | VAR_main 0.305871 | VAR_aux 0.001093 | MI -0.34060 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [2]
# ITR/SuccR   76/2.545 | OBJ -2.036999 | VAR_main 0.302935 | VAR_aux 0.001143 | MI -0.34083 |  1C x  1Z | SIZ  20 | ENT 2.9957
#     GAP USED: [3]
# ITR/SuccR   76/2.558 | OBJ -2.038948 | VAR_main 0.305664 | VAR_aux 0.001007 | MI -0.34100 |  1C x  1Z | SIZ  20 | ENT 2.9957
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 8
#       5 test_order = gbfs_global.best_design.order.copy()
#       7 # 3. Run global Grizzly
# ----> 8 gbfs_global.run(
#       9     max_iterations=1000,
#      10     max_open_set_size=2000,
#      11     top_k=1,
#      12
#      13     num_new_order_nodes=80,
#      14     num_new_exchange_nodes=0,
#      15
#      16     num_clusters_range=(1, 1),
#      17     num_zones_range=(1, 1),
#      18     num_changes_range=(1, 1),
#      19     num_zone_changes=0,
#      20
#      21     pull_strategy="default",
#      22     exchange_coef=0.005,
#      23
#      24     num_explore=1,
#      25     window=20,
#      26
#      27     n_jobs=2,
#      28     backtrack_depth=20,
#      29     stagnation_limit=5000,
#      30     output_details=False,
#      31
#      32     y_main=y_main,
#      33     y_aux=y_aux,
#      34 )
#
# File ~/projects/graphical-sampling/graphical_sampling/search/gbfs.py:226, in GreedyBestFirstSearch.run(self, max_iterations, max_open_set_size, top_k, num_new_order_nodes, num_new_exchange_nodes, num_clusters_range, num_zones_range, num_changes_range, num_zone_changes, pull_strategy, exchange_coef, num_explore, window, n_jobs, backtrack_depth, stagnation_limit, output_details, y_main, y_aux)
#     223 designs_to_eval = list(unique_neighbors.keys())
#     225 # 4. Parallel Evaluation
# --> 226 criteria_values = Parallel(n_jobs=n_jobs)(delayed(self.criteria)(d) for d in designs_to_eval)
#     228 # 5. Process Results
#     229 improved_this_iter = False
#
# File ~/projects/graphical-sampling/.venv/lib/python3.12/site-packages/joblib/parallel.py:2071, in Parallel.__call__(self, iterable)
#    2065 # The first item from the output is blank, but it makes the interpreter
#    2066 # progress until it enters the Try/Except block of the generator and
#    2067 # reaches the first `yield` statement. This starts the asynchronous
#    2068 # dispatch of the tasks to the workers.
#    2069 next(output)
# -> 2071 return output if self.return_generator else list(output)
#
# File ~/projects/graphical-sampling/.venv/lib/python3.12/site-packages/joblib/parallel.py:1681, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1678     yield
#    1680     with self._backend.retrieval_context():
# -> 1681         yield from self._retrieve()
#    1683 except GeneratorExit:
#    1684     # The generator has been garbage collected before being fully
#    1685     # consumed. This aborts the remaining tasks if possible and warn
#    1686     # the user if necessary.
#    1687     self._exception = True
#
# File ~/projects/graphical-sampling/.venv/lib/python3.12/site-packages/joblib/parallel.py:1799, in Parallel._retrieve(self)
#    1788 if self.return_ordered:
#    1789     # Case ordered: wait for completion (or error) of the next job
#    1790     # that have been dispatched and not retrieved yet. If no job
#    (...)   1794     # control only have to be done on the amount of time the next
#    1795     # dispatched job is pending.
#    1796     if (nb_jobs == 0) or (
#    1797         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1798     ):
# -> 1799         time.sleep(0.01)
#    1800         continue
#    1802 elif nb_jobs == 0:
#    1803     # Case unordered: jobs are added to the list of jobs to
#    1804     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1810     # timeouts before any other dispatched job has completed and
#    1811     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:
