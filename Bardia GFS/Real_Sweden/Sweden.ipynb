# %% [markdown]
# # Packages

# %%
# import matplotlib.pyplot as plt
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
import numpy as np
from rpy2.robjects import r, pandas2ri

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython

# %%
import sys
sys.path.append('/home/divar/projects/geometric-sampling')
import geometric_sampling

# %%
import geometric_sampling as gs
from geometric_sampling.search.astar import AStar
from geometric_sampling.design import Design
from geometric_sampling.criteria.var_nht import VarNHT

# %%
# %%R
# #install.packages("sampling")
# library(sampling)

# %% [markdown]
# # Parameters

# %%
# %%R
# n = 5

# %%
num_new_nodes          = 10

# %% [markdown]
# # Simu The best

# %% [markdown]
# ## R Popu

# %%
# %%R
# library(sampling)
#
# #MU284 Sweden
# data(MU284)
# print(length(MU284[,1]))
# print(cor(MU284$RMT85,MU284$CS82))
# print(cor(MU284$RMT85,MU284$SS82))
# MU284 = MU284[MU284$P85<200,]
#
# print(cor(MU284$RMT85,MU284$CS82))
# print(cor(MU284$RMT85,MU284$SS82))
# print(length(MU284[,1]))
# out <- file.path("Bardia GFS", "Real_Sweden", "MU284_filtered.csv")
# write.csv(MU284, out, row.names = FALSE)
# out
# print(length(MU284[,1]))
# set.seed(120)
# MU284 = MU284[sample(length(MU284[,1])),]
# #MU284 = MU284[order(-MU284$ME84),]
# y5 = MU284$RMT85
# x5 = MU284$P85/100
# g5 = MU284$P75/100
# v5 = MU284$S82/1000
# h5 = MU284$ME84/1000
# w5 = MU284$REV84/1000
#
#
# RMT85 = MU284$RMT85
# P85 = MU284$P85/sd(MU284$P85)
# P75 = MU284$P75/sd(MU284$P75)
# S82 = MU284$S82/sd(MU284$S82)
# CS82 = MU284$CS82/sd(MU284$CS82)
# SS82 = MU284$SS82/sd(MU284$SS82)
# ME84 = MU284$ME84/sd(MU284$ME84)
# REV84 = MU284$REV84/sd(MU284$REV84)
# REG = MU284$REG
#
# P85 = MU284$P85
# P75 = MU284$P75
# S82 = MU284$S82
# CS82 = MU284$CS82
# SS82 = MU284$SS82
# ME84 = MU284$ME84
# REV84 = MU284$REV84
# REG = MU284$REG
# RMT85 = MU284$RMT85
#
#
#
#
#
#
# N = length(REV84)
# r <- runif(N, .1, .8)
# e <- rep (1, N)
#
#
#
#
#
#
#  y <- RMT85; z <- CS82; p <- SS82
#
#
#
# N = length(y)
#
# print(n/N)
# pik <- inclusionprobabilities(p, n)
# ##########################
# ### Variance of Rivals ###
# ##########################
# pikl_sys = UPsystematicpi2(pik)
# pikl_max = UPmaxentropypi2(pik)
# pikl_mid = UPmidzunopi2(pik)
# pikl_til = UPtillepi2(pik)
#
# z_hat = z / pik
#
# var__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat
# var__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat
# var__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat
# var__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat
# var__srs <- (N**2)*(1-n/N)*(1/n)*var(z)
#
# y_hat = y/pik
#
# var__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat
# var__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat
# var__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat
# var__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat
# var__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)
#
#
#
#
# var_z = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z) = c('sysxy', 'maxxy', 'midxy', 'tilxy', 'srsxy')
# threshold_z = min(var_z[var_z>0])
#
# var_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )
# names(var_y) = c('sysy', 'maxy', 'midy', 'tily', 'srsy')
# threshold_y = min(var_y[var_y>0])
#
# print(c(var__srs_y,var__srs))
# Out:
# [1] 284
# [1] 0.5226861
# [1] 0.4007188
# [1] 0.6574759
# [1] 0.6506644
# [1] 281
# [1] 281
# Error in (function (expr, envir = parent.frame(), enclos = if (is.list(envir) ||  :
#   object 'n' not found
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/ws/graphical-sampling/.venv/lib/python3.14/site-packages/rpy2/ipython/rmagic.py:768, in RMagics.eval(self, code)
#     767     r_expr = ri.parse(code)
# --> 768     value, visible = ri.evalr_expr_with_visible(
#     769         r_expr
#     770     )
#     771 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     772     # Otherwise next return seems to have copy of error.
#
# File ~/ws/graphical-sampling/.venv/lib/python3.14/site-packages/rpy2/rinterface/__init__.py:205, in evalr_expr_with_visible(expr, envir)
#     204 if error_occured[0]:
# --> 205     raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     206 res = conversion._cdata_to_rinterface(r_res)
#
# RRuntimeError: Error in (function (expr, envir = parent.frame(), enclos = if (is.list(envir) ||  :
#   object 'n' not found
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', 'library(sampling)\n\n#MU284 Sweden\ndata(MU284)\nprint(length(MU284[,1]))\nprint(cor(MU284$RMT85,MU284$CS82))\nprint(cor(MU284$RMT85,MU284$SS82))\nMU284 = MU284[MU284$P85<200,]\n\nprint(cor(MU284$RMT85,MU284$CS82))\nprint(cor(MU284$RMT85,MU284$SS82))\nprint(length(MU284[,1]))\nout <- file.path("Bardia GFS", "Real_Sweden", "MU284_filtered.csv")\nwrite.csv(MU284, out, row.names = FALSE)\nout\nprint(length(MU284[,1]))\nset.seed(120)\nMU284 = MU284[sample(length(MU284[,1])),]\n#MU284 = MU284[order(-MU284$ME84),]\ny5 = MU284$RMT85\nx5 = MU284$P85/100\ng5 = MU284$P75/100\nv5 = MU284$S82/1000\nh5 = MU284$ME84/1000\nw5 = MU284$REV84/1000\n\n\nRMT85 = MU284$RMT85\nP85 = MU284$P85/sd(MU284$P85)\nP75 = MU284$P75/sd(MU284$P75)\nS82 = MU284$S82/sd(MU284$S82)\nCS82 = MU284$CS82/sd(MU284$CS82)\nSS82 = MU284$SS82/sd(MU284$SS82)\nME84 = MU284$ME84/sd(MU284$ME84)\nREV84 = MU284$REV84/sd(MU284$REV84)\nREG = MU284$REG\n\nP85 = MU284$P85\nP75 = MU284$P75\nS82 = MU284$S82\nCS82 = MU284$CS82\nSS82 = MU284$SS82\nME84 = MU284$ME84\nREV84 = MU284$REV84\nREG = MU284$REG\nRMT85 = MU284$RMT85\n\n\n\n\n\n\nN = length(REV84)\nr <- runif(N, .1, .8)\ne <- rep (1, N)\n\n\n\n\n\n\n y <- RMT85; z <- CS82; p <- SS82\n\n\n\nN = length(y)\n\nprint(n/N)\npik <- inclusionprobabilities(p, n)\n##########################\n### Variance of Rivals ###\n##########################\npikl_sys = UPsystematicpi2(pik)\npikl_max = UPmaxentropypi2(pik)\npikl_mid = UPmidzunopi2(pik)\npikl_til = UPtillepi2(pik)\n\nz_hat = z / pik\n\nvar__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat\nvar__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat\nvar__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat\nvar__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat\nvar__srs <- (N**2)*(1-n/N)*(1/n)*var(z)\n\ny_hat = y/pik\n\nvar__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat\nvar__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat\nvar__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat\nvar__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat\nvar__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)\n\n\n\n\nvar_z = c(var__sys, var__max, var__mid, var__til, var__srs)\nnames(var_z) = c(\'sysxy\', \'maxxy\', \'midxy\', \'tilxy\', \'srsxy\')\nthreshold_z = min(var_z[var_z>0])\n\nvar_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )\nnames(var_y) = c(\'sysy\', \'maxy\', \'midy\', \'tily\', \'srsy\')\nthreshold_y = min(var_y[var_y>0])\n\nprint(c(var__srs_y,var__srs))\n')
#
# File ~/ws/graphical-sampling/.venv/lib/python3.14/site-packages/IPython/core/interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
#    2577 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/ws/graphical-sampling/.venv/lib/python3.14/site-packages/rpy2/ipython/rmagic.py:1318, in RMagics.R(self, line, cell, local_ns)
#    1316     if not e.stdout.endswith(e.err):
#    1317         print(e.err)
# -> 1318     raise e
#    1319 finally:
#    1320     if isinstance(self.graphics_device, FileDevice):
#
# File ~/ws/graphical-sampling/.venv/lib/python3.14/site-packages/rpy2/ipython/rmagic.py:1283, in RMagics.R(self, line, cell, local_ns)
#    1281         return_output = False
#    1282 else:
# -> 1283     text_result, result, visible = self.eval(code)
#    1284     text_output += text_result
#    1285     if visible:
#
# File ~/ws/graphical-sampling/.venv/lib/python3.14/site-packages/rpy2/ipython/rmagic.py:774, in RMagics.eval(self, code)
#     771 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     772     # Otherwise next return seems to have copy of error.
#     773     warning_or_other_msg = self.flush()
# --> 774     raise RInterpreterError(code, str(exception),
#     775                             warning_or_other_msg)
#     776 finally:
#     777     ro._print_deferred_warnings()
#
# RInterpreterError: Failed to parse and evaluate line 'library(sampling)\n\n#MU284 Sweden\ndata(MU284)\nprint(length(MU284[,1]))\nprint(cor(MU284$RMT85,MU284$CS82))\nprint(cor(MU284$RMT85,MU284$SS82))\nMU284 = MU284[MU284$P85<200,]\n\nprint(cor(MU284$RMT85,MU284$CS82))\nprint(cor(MU284$RMT85,MU284$SS82))\nprint(length(MU284[,1]))\nout <- file.path("Bardia GFS", "Real_Sweden", "MU284_filtered.csv")\nwrite.csv(MU284, out, row.names = FALSE)\nout\nprint(length(MU284[,1]))\nset.seed(120)\nMU284 = MU284[sample(length(MU284[,1])),]\n#MU284 = MU284[order(-MU284$ME84),]\ny5 = MU284$RMT85\nx5 = MU284$P85/100\ng5 = MU284$P75/100\nv5 = MU284$S82/1000\nh5 = MU284$ME84/1000\nw5 = MU284$REV84/1000\n\n\nRMT85 = MU284$RMT85\nP85 = MU284$P85/sd(MU284$P85)\nP75 = MU284$P75/sd(MU284$P75)\nS82 = MU284$S82/sd(MU284$S82)\nCS82 = MU284$CS82/sd(MU284$CS82)\nSS82 = MU284$SS82/sd(MU284$SS82)\nME84 = MU284$ME84/sd(MU284$ME84)\nREV84 = MU284$REV84/sd(MU284$REV84)\nREG = MU284$REG\n\nP85 = MU284$P85\nP75 = MU284$P75\nS82 = MU284$S82\nCS82 = MU284$CS82\nSS82 = MU284$SS82\nME84 = MU284$ME84\nREV84 = MU284$REV84\nREG = MU284$REG\nRMT85 = MU284$RMT85\n\n\n\n\n\n\nN = length(REV84)\nr <- runif(N, .1, .8)\ne <- rep (1, N)\n\n\n\n\n\n\n y <- RMT85; z <- CS82; p <- SS82\n\n\n\nN = length(y)\n\nprint(n/N)\npik <- inclusionprobabilities(p, n)\n##########################\n### Variance of Rivals ###\n##########################\npikl_sys = UPsystematicpi2(pik)\npikl_max = UPmaxentropypi2(pik)\npikl_mid = UPmidzunopi2(pik)\npikl_til = UPtillepi2(pik)\n\nz_hat = z / pik\n\nvar__sys <- t(z_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% z_hat\nvar__max <- t(z_hat) %*% (pikl_max - (pik %*% t(pik))) %*% z_hat\nvar__mid <- t(z_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% z_hat\nvar__til <- t(z_hat) %*% (pikl_til - (pik %*% t(pik))) %*% z_hat\nvar__srs <- (N**2)*(1-n/N)*(1/n)*var(z)\n\ny_hat = y/pik\n\nvar__sys_y <- t(y_hat) %*% (pikl_sys - (pik %*% t(pik))) %*% y_hat\nvar__max_y <- t(y_hat) %*% (pikl_max - (pik %*% t(pik))) %*% y_hat\nvar__mid_y <- t(y_hat) %*% (pikl_mid - (pik %*% t(pik))) %*% y_hat\nvar__til_y <- t(y_hat) %*% (pikl_til - (pik %*% t(pik))) %*% y_hat\nvar__srs_y <- (N**2)*(1-n/N)*(1/n)*var(y)\n\n\n\n\nvar_z = c(var__sys, var__max, var__mid, var__til, var__srs)\nnames(var_z) = c(\'sysxy\', \'maxxy\', \'midxy\', \'tilxy\', \'srsxy\')\nthreshold_z = min(var_z[var_z>0])\n\nvar_y = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y )\nnames(var_y) = c(\'sysy\', \'maxy\', \'midy\', \'tily\', \'srsy\')\nthreshold_y = min(var_y[var_y>0])\n\nprint(c(var__srs_y,var__srs))\n'.
# R error message: "Error in (function (expr, envir = parent.frame(), enclos = if (is.list(envir) ||  : \n  object 'n' not found"

# %%
# %%R
# write.csv(MU284[MU284$P85 < 200, ],
#           "MU284_filtered.csv",
#           row.names = FALSE)
# getwd()
# Out:
# [1] "/config/ws/graphical-sampling/Bardia GFS/Real_Sweden"

# %%
# %%R
# # Sample data
# # y <- your_response_vector
# # z <- your_predictor_vector
#
# # 1. Fit up to cubic model (z, z^2, z^3)
# model <- lm(y ~ poly(z, 3, raw=TRUE))
#
# # 2. Check summary and retain only significant terms
# print(summary(model))
#
# print('adsfasdfasdf')
# # 3. Identify significant terms (p < 0.05)
# coefs <- summary(model)$coefficients
# sig_terms <- rownames(coefs)[which(coefs[,4] < 0.05)]
# sig_terms <- sig_terms[sig_terms != "(Intercept)"]
#
# # 4. Build formula for significant terms:
# terms <- c()
# if("poly(z, 3, raw = TRUE)1" %in% sig_terms) terms <- c(terms, "z")
# if("poly(z, 3, raw = TRUE)2" %in% sig_terms) terms <- c(terms, "I(z^2)")
# if("poly(z, 3, raw = TRUE)3" %in% sig_terms) terms <- c(terms, "I(z^3)")
#
# # 5. Fit reduced model
# if(length(terms) > 0){
#   formula_str <- paste("y ~", paste(terms, collapse = " + "))
#   final_model <- lm(as.formula(formula_str))
#   summary(final_model)
# } else {
#   cat("No significant terms found.\n")
# }
# Out:
# Call:
# lm(formula = y ~ poly(z, 3, raw = TRUE))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             195.15011   56.70775   3.441 0.000668 ***
# poly(z, 3, raw = TRUE)1 -58.69774   18.39547  -3.191 0.001582 **
# poly(z, 3, raw = TRUE)2   7.84073    1.74775   4.486 1.06e-05 ***
# poly(z, 3, raw = TRUE)3  -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -371.45  -68.53  -19.08   40.02  698.92
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 195.15011   56.70775   3.441 0.000668 ***
# z           -58.69774   18.39547  -3.191 0.001582 **
# I(z^2)        7.84073    1.74775   4.486 1.06e-05 ***
# I(z^3)       -0.19892    0.04832  -4.117 5.07e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 145.5 on 277 degrees of freedom
# Multiple R-squared:  0.4768,	Adjusted R-squared:  0.4711
# F-statistic: 84.13 on 3 and 277 DF,  p-value: < 2.2e-16
#  0.02671  0.31839
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)             -0.0135495  0.0197108  -0.687   0.4924
# poly(z, 3, raw = TRUE)1  0.1145654  0.0175117   6.542 2.92e-10 ***
# poly(z, 3, raw = TRUE)2 -0.0066922  0.0037594  -1.780   0.0762 .
# poly(z, 3, raw = TRUE)3  0.0004575  0.0002169   2.109   0.0358 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09749 on 277 degrees of freedom
# Multiple R-squared:  0.8379,	Adjusted R-squared:  0.8362
# F-statistic: 477.4 on 3 and 277 DF,  p-value: < 2.2e-16
#
# [1] "adsfasdfasdf"
#
# Call:
# lm(formula = as.formula(formula_str))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.76883 -0.01219  0.00415  0.02980  0.29691
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.531e-02  1.126e-02   1.360   0.1750
# z           8.453e-02  4.708e-03  17.955   <2e-16 ***
# I(z^3)      7.866e-05  4.195e-05   1.875   0.0618 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09787 on 278 degrees of freedom
# Multiple R-squared:  0.8361,	Adjusted R-squared:  0.8349
# F-statistic:   709 on 2 and 278 DF,  p-value: < 2.2e-16

# %%
# %%R
# models <- list(
#   lm(y ~ z),
#   lm(I(y/pik) ~ I(z/pik)),
#   lm(y ~ I(y/pik)),
#   lm(z ~ I(z/pik))
# )
# model_names <- c("y ~ z", "y/pik ~ z/pik", "y ~ y/pik", "z ~ z/pik")
#
# for(i in 1:4) {
#   sm <- summary(models[[i]])
#   cat(sprintf("Model %d (%s):\n", i, model_names[i]))
#   cat(sprintf("  alpha (Intercept): %.4f (p=%.4g)\n", sm$coefficients[1,1], sm$coefficients[1,4]))
#   cat(sprintf("  beta  (Slope)    : %.4f (p=%.4g)\n", sm$coefficients[2,1], sm$coefficients[2,4]))
#   cat("\n")
# }
#
# # 2x2 plot of all models
# par(mfrow = c(3,2))
# plot(z, y, main="y ~ z"); abline(models[[1]], col="blue")
# plot(z/pik, y/pik, main="y/pik ~ z/pik"); abline(models[[2]], col="blue")
# plot(y/pik, y, main="y ~ y/pik"); abline(models[[3]], col="blue")
# plot(z/pik, z, main="z ~ z/pik"); abline(models[[4]], col="blue")
# plot(y, p)
# plot(z, p)
# Out:
# Model 1 (y ~ z):
#   alpha (Intercept): -64.3714 (p=0.001146)
#   beta  (Slope)    : 28.4048 (p=3.64e-36)
#
# Model 2 (y/pik ~ z/pik):
#   alpha (Intercept): 4533.8417 (p=6.6e-10)
#   beta  (Slope)    : 9.3784 (p=1.903e-17)
#
# Model 3 (y ~ y/pik):
#   alpha (Intercept): -32.0473 (p=0.000327)
#   beta  (Slope)    : 0.0226 (p=6.505e-96)
#
# Model 4 (z ~ z/pik):
#   alpha (Intercept): 4.1630 (p=3.086e-30)
#   beta  (Slope)    : 0.0085 (p=3.403e-49)

# %%
# %%R
# Ppi <- function(Pi) {
#
#   N <- length(Pi)
#   #SOME ERROR MESSAGES
#   if (N < 2) {
#     rlang::abort("The sampling designs should be define on a set of more than one element. (length(Pi) > 1)")
#   }
#
#   for (k in 1:N) {
#     if (Pi[k] >= 1 | Pi[k] <= 0) {
#       rlang::abort("Pi is not a vector of probabilities (0 <= p < 1)")
#     }
#   }
#
#   if (as.integer(round( sum(Pi) , 9)) - round( sum(Pi) , 9) != 0) {
#     rlang::abort("The sum of the first order inclusion probabilities should be an integer")
#   }
#
#
#   s <- c()
#   c <- c()
#   kr <- c()
#   alpha <-c()
#   sum <-0
#   r<-1
#   r_prev<-0
#   n_<-sum(Pi)
#
#   for (k in 1:N) {
#     prev_sum<-sum
#     sum<-sum+Pi[k]
#     if (sum>=r)
#     {
#       kr[r] <- k
#       alpha[k] <-r-prev_sum
#
#       int <- sqrt( (1 - Pi[k]) / (1 - alpha[k]) )
#       s[k] <- round(int, 8)
#       r_prev<-r
#       r<-r+1
#     }
#
#     else {
#       inter <- sqrt( Pi[k] / (r_prev + 1 - prev_sum) )
#       s[k] <- round(inter, digits = 15)
#     }
#
#     c[k] <- sqrt(1 - s[k]^2)
#
#   }
#
#   # ce point n'est pas joli, mais je n'ai pas trouvé l'erreur. A retravailler..
#   #print(kr)
#   if(max(kr)!=length(Pi)){
#     kr<-cbind(kr,length(Pi))
#     r<-r+1
#     r_prev<-r_prev+1}
#   #print(kr)
#   V <- matrix(0, nrow = N , ncol = r_prev)
#   V[1, 1] = 1
#   if ((r_prev-1) != 0) {
#     for (r in 1:(r_prev-1)) {
#       V[kr[r] + 1, r + 1] = 1
#     }
#   }
#
#   for (k in 1:(N-1)) {
#     L <- V[k, ]
#     M <- V[k + 1,]
#     V[k, ] <- s[k] * L - c[k] * M
#     V[k + 1, ] <- c[k] * L + s[k] * M
#   }
#   return(V)
# }
#
#
#
#
# Drawing_Dsd <- function(v, s = 1, B = FALSE, seed = NULL){
#
#
#   if (is.numeric(v)) {
#     return(.dsd_sampling_mult(v, s, B, seed))
#   }
#   else{ return(.dsd_sampling_mult_complex(v, s, B, seed))}
# }
#
#
# .dsd_sampling_mult_complex <- function(v, s, B, seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C_complex(v, B, seed))
#   }
#
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C_complex(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
#
# .dsd_sampling_mult <- function(v = NULL, s, B,seed){
#
#   if (s == 1) {
#     return(.dsd_sampling_01_B_C(v, B, seed))
#   }
#   else{
#     echant <- replicate(s, .dsd_sampling_01_B_C(v, B, seed))
#     colnames(echant) <- paste("Sample", 1:s)
#     return(echant)
#   }
# }
#
# .dsd_sampling_01_B_C_complex <- function(v, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #Step 1: Sampling the first element
#   w <- v
#
#   total <- 0
#   i <- 0
#   pi1 <- Re( diag( v %*% t(Conj(v)) ) )
#
#   if (length(pi1[pi1 < 0]) != 0 | length(pi1[pi1 >= 1]) != 0) {
#     rlang::abort("The matrix v given as input doesn't suit to the input expected (See the functions pgd and periodic_dsd)")
#   }
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#   M <- v[i,]
#   e1 <- M / c(Re (sqrt (t(M) %*% Conj(M)) ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- v %*% Conj(e1)
#     pi1 <- pi1 - t(inter * Conj(inter))
#     pi2 <- Re( 1 / r*pi1 )
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#     w <- w - t( t(Conj(e1)) %*% t(w) ) %*% t(e1)
#     L <- w[i, ]
#     e1 <- L / c(Re(sqrt (t(L) %*% Conj(L) )))
#
#   }
#
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }
# .dsd_sampling_01_B_C <- function(v = NULL, B = TRUE, seed){
#
#   indices <- .data <- NULL
#
#   N <- nrow(v)
#   n <- ncol(v)
#   echant <- rep(0, N)
#
#   if (!is.null(seed)) {
#     set.seed(seed)
#   }
#   ref <- stats::runif(n)
#
#   #First step: Sampling the first element
#   w <- v
#
#
#   total <- 0
#   i <- 0
#   pi1 <- diag(v  %*% t(v))
#
#   while (total < ref[1]) {
#     i <- i + 1
#     total <- total + ( pi1[i] / n )
#   }
#   echant[i] <- 1
#
#
#   l <- v[i,]
#   e1 <- l / as.numeric( sqrt( t(l) %*% l ) )
#
#
#   #Step 2: Sampling the n-1 others elements
#   for (j in 1:(n-1)) {
#
#     r <- n-j
#     inter <- (v %*% e1)
#     pi1 <- pi1 - t( inter * inter )
#     pi2 <- 1 / r * pi1
#
#
#     total <- 0
#     i <- 0
#
#     while (total < ref[j+1]) {
#       i <- i + 1
#       total <- total + pi2[i]
#     }
#     echant[i] <- 1
#
#
#
#     w <- w - (w %*% e1) %*% t(e1)
#     L <- w[i,]
#     e1 <- L / as.numeric( sqrt( t(L) %*% L ))
#
#   }
#   if(B) {
#     return(echant)
#   }
#   else {
#     return((1:N)[echant==1])
#   }
#
# }

# %%
# %%R
# library(sampling)
#
#
#
# #pik <- inclusionprobabilities(p, n)
#
# sort_index <- order(z / pik, decreasing = TRUE)
# y <- y[sort_index]; z <- z[sort_index]; pik <- pik[sort_index]
# N <- length(y)
# print(cor(y,z))
# print(cor(y,p))
#
#
# Base <- Ppi(pik)
# Ppi_mat <- Base %*% t(Base)
#
# # Variance matrix formula
# Dpi_inv <- diag(1 / pik)
# I_N <- diag(N)
# A <- (I_N - Ppi_mat) * Ppi_mat
# var_ht_z <- as.numeric(t(z) %*% Dpi_inv %*% A %*% Dpi_inv %*% z)
# cat("Variance of HT estimator via DSD formula_z: ", var_ht_z, "\n")
#
# var_ht <- as.numeric(t(y) %*% Dpi_inv %*% A %*% Dpi_inv %*% y)
# cat("Variance of HT estimator via DSD formula: ", var_ht, "\n")
#
#
# # Monte Carlo
# # Number of repetitions
# m <- 2000
# ht_estimates_dsd_y <- numeric(m)
# ht_estimates_dsd_z <- numeric(m)
# ht_estimates_cube_y <- numeric(m)
# ht_estimates_cube_z <- numeric(m)
#
# for (i in 1:m) {
#   # --- Determinantal Sampling ---
#   samp <- Drawing_Dsd(Base, s = n, B = TRUE)
#   sel_idx <- which(samp[, 1] == 1)  # Adjust if needed
#   ht_estimates_dsd_y[i] <- sum(y[sel_idx] / pik[sel_idx])
#   ht_estimates_dsd_z[i] <- sum(z[sel_idx] / pik[sel_idx])
#
#   # --- Cube Method Sampling ---
#   # If you want to balance on z, make sure to use cube method with z in the auxiliary matrix
#   cube_sample <- samplecube(cbind(pik, z), pik, comment = FALSE)
#   sel_cube <- which(cube_sample == 1)
#   ht_estimates_cube_y[i] <- sum(y[sel_cube] / pik[sel_cube])
#   ht_estimates_cube_z[i] <- sum(z[sel_cube] / pik[sel_cube])
# }
# var_y_0 = c(var__sys_y, var__max_y, var__mid_y, var__til_y, var__srs_y)
# names(var_y_0) = c('syszy', 'maxzy', 'midzy', 'tilzy', 'srszy')
#
# var_z_0 = c(var__sys, var__max, var__mid, var__til, var__srs)
# names(var_z_0) = c('sysz', 'maxz', 'midz', 'tilz', 'srsz')
#
# threshold_z = min(var_z_0)
# threshold_y = min(var_y_0)
#
# # --- Variance and Mean calculations ---
# var_dsd_y   <- var(ht_estimates_dsd_y)
# var_cube_y  <- var(ht_estimates_cube_y)
# var_dsd_z   <- var(ht_estimates_dsd_z)
# var_cube_z  <- var(ht_estimates_cube_z)
# mean_dsd_y  <- mean(ht_estimates_dsd_y)
# mean_cube_y <- mean(ht_estimates_cube_y)
# mean_dsd_z  <- mean(ht_estimates_dsd_z)
# mean_cube_z <- mean(ht_estimates_cube_z)
#
# cat("Here is the Vincent Efficiency y:\n")
# eff_dsd_y <- min(var_y_0[var_y_0>0]) / var_ht
# eff_dsd_z <- min(var_z_0[var_z_0>0]) / var_ht_z
# cat(sprintf("  DSD_y:  %.5f\n  DSD_z: %.5f\n", eff_dsd_y, eff_dsd_z))
#
#
# cat("Monte Carlo variance of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_y, var_cube_y))
#
# eff_dsd_y <- min(var_y_0) / var_dsd_y
# eff_cube_y <- min(var_y_0) / var_cube_y
#
# cat("Monte Carlo efficiency of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_y, eff_cube_y))
#
# cat("Monte Carlo mean of HT estimator for y:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_y, mean_cube_y))
# cat(sprintf("  Actual total of y: %.5f\n", sum(y)))
#
# cat("\nMonte Carlo variance of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", var_dsd_z, var_cube_z))
#
# eff_dsd_z <- min(var_z_0) / var_dsd_z
# eff_cube_z <- min(var_z_0) / var_cube_z
#
# cat("Monte Carlo efficiency of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", eff_dsd_z, eff_cube_z))
#
# cat("Monte Carlo mean of HT estimator for z:\n")
# cat(sprintf("  DSD:  %.5f\n  Cube: %.5f\n", mean_dsd_z, mean_cube_z))
# cat(sprintf("  Actual total of z: %.5f\n", sum(z)))
# Out:
# [1] 0.6574759
# [1] 0.1130297
# Variance of HT estimator via DSD formula_z:  162900.1
# Variance of HT estimator via DSD formula:  272413389
# Here is the Vincent Efficiency y:
#   DSD_y:  1.19547
#   DSD_z: 2.04294
# Monte Carlo variance of HT estimator for y:
#   DSD:  272275770.55787
#   Cube: 290920025.40021
# Monte Carlo efficiency of HT estimator for y:
#   DSD:  1.19608
#   Cube: 1.11942
# Monte Carlo mean of HT estimator for y:
#   DSD:  53161.52019
#   Cube: 53278.89515
#   Actual total of y: 53151.00000
#
# Monte Carlo variance of HT estimator for z:
#   DSD:  175463.75804
#   Cube: 236720.78184
# Monte Carlo efficiency of HT estimator for z:
#   DSD:  1.89666
#   Cube: 1.40585
# Monte Carlo mean of HT estimator for z:
#   DSD:  2503.37940
#   Cube: 2523.39653
#   Actual total of z: 2508.00000

# %%
# %%R
# results = round(c(var__srs/min(var_z_0), var__srs/var_cube_z, var__srs/var_ht_z,  var__srs_y/min(var_y_0), var__srs_y/var_cube_y,var__srs_y/var_ht ),2)
# names(results) = c('eff_GFS_0_z','eff_cube_z', 'eff_dsd_z', 'eff_GFS_0_y' , 'eff_cube_y','eff_dsd_y')
# print(results)
# Out:
# eff_GFS_0_z  eff_cube_z   eff_dsd_z eff_GFS_0_y  eff_cube_y   eff_dsd_y
#        1.00        1.41        2.04        1.91        2.14        2.28

# %% [markdown]
# ## Astar

# %%
y = np.array(ro.r['y'])
z = np.array(ro.r['z'])
inclusions = np.array(ro.r['pik'])

print('cor(y, z)', np.corrcoef(y, z)[0, 1])
print('cor(y, inclusions)', np.corrcoef(y, inclusions)[0, 1])
n = np.array(ro.r['n'])
N = np.array(ro.r['N'])
print(N,n,'adsfa')
var_y_0 = np.array(ro.r['var_y_0'])
var_z_0 = np.array(ro.r['var_z_0'])
eff_dsd_z = float(ro.r['eff_dsd_z'][0])
eff_dsd_y = float(ro.r['eff_dsd_y'][0])
inclusions = np.array(ro.r['pik'])
threshold_z = float(ro.r['threshold_z'][0])
threshold_y = ro.r['threshold_y']
threshold_z = float(ro.r['var_ht_z'][0])
threshold_y = float(ro.r['var_ht'][0])


threshold_z_cube = float(ro.r['var_cube_z'][0])
threshold_y_cube = float(ro.r['var_cube_y'][0])


inclusions = np.array(inclusions)

import numpy as np


num_changes_lower      = 1
num_changes_upper      = 3
max_open_set_size      = 200000
switch_lower           = .7
switch_upper           = .9
max_iterations         = 4000
num_initial_nodes      = 1
initial_design_to_use  = 1
num_top_restart_nodes  = 10
stuck_fraction         = 0.99

swap_iterations        = int(np.round(.7 * num_initial_nodes))  # ensure integer!
swap_distance          = 3
swap_units             = int(N/5)







show_results           = 1
random_restart_period  = 10000   # how often to inject random designs
random_injection_count = 500     # how many random designs to inject
prune_fraction         = .9
var_percent_exected    = 0  # how much of the variance to expect in the best design



rng = np.random.default_rng()  # Recommended for controlled/stable random runs
print(max_iterations, num_new_nodes, max_open_set_size, switch_lower, switch_upper)

# You must define y, z, inclusions, threshold_z, threshold_y earlier in your notebook or script.

# Criterion must be set up per your class structure.
criterion = VarNHT(main_variable=y, auxiliary_variable=z, 
                   inclusion_probability=inclusions, balance_method='linear')

astar = AStar(
    inclusions              = inclusions,
    num_initial_nodes       = num_initial_nodes,
    initial_design_to_use   = initial_design_to_use,
    criteria                = criterion,
    z                       = z,
    y                       = y,
    threshold_z             = threshold_z,
    threshold_y             = threshold_y,
        threshold_z_cube             = threshold_z_cube,
    threshold_y_cube             = threshold_y_cube,
    switch_lower            = switch_lower,
    switch_upper            = switch_upper,
    num_changes_lower       = num_changes_lower,
    num_changes_upper       = num_changes_upper,
    show_results            = show_results,
    var_percent_exected     = var_percent_exected,
    swap_iterations         = swap_iterations,
    swap_distance           = swap_distance,
    swap_units              = swap_units,
    rng                     = rng,                
    # atomize                 = False,                        
    # delta                   = 0.01,                         
)

result = astar.run(
    max_iterations             = max_iterations,
    num_new_nodes              = num_new_nodes,
    max_open_set_size          = max_open_set_size,
    random_restart_period      = random_restart_period,
    random_injection_count     = random_injection_count,
    prune_fraction             = prune_fraction,
    num_top_restart_nodes      = num_top_restart_nodes,
    stuck_fraction             = stuck_fraction,

)

print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
print("Best criteria value:", astar.best_criteria_value)
print("Iterations run:", result)
# print(np.round(var_z_0, 1))
# print(np.round(var_y_0, 1))
astar.initial_design.show()
astar.best_design.show()
# Out:
# cor(y, z) 0.6574759317818598
# cor(y, inclusions) 0.6506643745639386
# [281] [5.] adsfa
# 4000 10 200000 0.7 0.9
# /tmp/ipykernel_852640/2965922855.py:43: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   swap_units             = int(N/5)
# Generating initial designs: 100%|█████████████████| 1/1 [00:00<00:00, 26.77it/s]
# Initial design 0: method = Original, efficiency z = 0.5762, y=0.9353
# New best at idx=0: method = Original, efficiency z = 0.5762 and efficiency y = 0.9353
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 0 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       282632.5
#   Best Cost (y):       288359955.5254
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      117.111
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.5764→ cube 0.8376
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9447→ cube 1.0089
#   Efficiency z (srs):  1.173 → 0.576 → 1.1733
#   Efficiency y (srs):  2.125 → 0.935 → 2.1464
#   Alpha:               0.8686493505676608
#   Num changes:         1
#   Design Depth:        1
#   Design Size (|D|):   283
#   Open set size:       8
#
# Progress: 0.0%
# === Best Solution Updated at Iteration 1 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       282712.698
#   Best Cost (y):       302093290.5712
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      117.104
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.5762→ cube 0.8373
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9018→ cube 0.963
#   Efficiency z (srs):  1.173 → 0.576 → 1.173
#   Efficiency y (srs):  2.125 → 0.935 → 2.0489
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        4
#   Design Size (|D|):   289
#   Open set size:       19
#
# Progress: 0.8%
# === Best Solution Updated at Iteration 30 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       264844.881
#   Best Cost (y):       293873512.1009
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      110.04
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6151→ cube 0.8938
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.927→ cube 0.9899
#   Efficiency z (srs):  1.173 → 0.576 → 1.2521
#   Efficiency y (srs):  2.125 → 0.935 → 2.1062
#   Alpha:               0.8057492503609847
#   Num changes:         3
#   Design Depth:        54
#   Design Size (|D|):   389
#   Open set size:       273
#
# Progress: 1.0%
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       253191.475
#   Best Cost (y):       300478763.8721
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      105.293
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6434→ cube 0.9349
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9066→ cube 0.9682
#   Efficiency z (srs):  1.173 → 0.576 → 1.3097
#   Efficiency y (srs):  2.125 → 0.935 → 2.0599
#   Alpha:               0.7173501134569612
#   Num changes:         1
#   Design Depth:        69
#   Design Size (|D|):   419
#   Open set size:       362
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       253027.945
#   Best Cost (y):       308232310.3058
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      105.275
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6438→ cube 0.9356
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.8838→ cube 0.9438
#   Efficiency z (srs):  1.173 → 0.576 → 1.3106
#   Efficiency y (srs):  2.125 → 0.935 → 2.0081
#   Alpha:               0.8994503888573275
#   Num changes:         2
#   Design Depth:        70
#   Design Size (|D|):   421
#   Open set size:       368
#
#
# === Best Solution Updated at Iteration 40 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       252156.784
#   Best Cost (y):       301064149.583
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      104.843
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.646→ cube 0.9388
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9048→ cube 0.9663
#   Efficiency z (srs):  1.173 → 0.576 → 1.3151
#   Efficiency y (srs):  2.125 → 0.935 → 2.0559
#   Alpha:               0.8168846541058679
#   Num changes:         3
#   Design Depth:        71
#   Design Size (|D|):   423
#   Open set size:       369
#
# Progress: 1.2%
# === Best Solution Updated at Iteration 50 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       247287.348
#   Best Cost (y):       304708512.5462
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      102.893
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6587→ cube 0.9573
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.894→ cube 0.9547
#   Efficiency z (srs):  1.173 → 0.576 → 1.341
#   Efficiency y (srs):  2.125 → 0.935 → 2.0313
#   Alpha:               0.8794167201542631
#   Num changes:         3
#   Design Depth:        86
#   Design Size (|D|):   453
#   Open set size:       452
#
# Progress: 1.5%
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       245400.15
#   Best Cost (y):       305876130.4351
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      101.984
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6638→ cube 0.9646
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.8906→ cube 0.9511
#   Efficiency z (srs):  1.173 → 0.576 → 1.3513
#   Efficiency y (srs):  2.125 → 0.935 → 2.0235
#   Alpha:               0.7649649065592784
#   Num changes:         3
#   Design Depth:        103
#   Design Size (|D|):   487
#   Open set size:       546
#
#
# === Best Solution Updated at Iteration 60 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       245072.126
#   Best Cost (y):       313034081.4001
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      101.903
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6647→ cube 0.9659
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.8702→ cube 0.9294
#   Efficiency z (srs):  1.173 → 0.576 → 1.3531
#   Efficiency y (srs):  2.125 → 0.935 → 1.9772
#   Alpha:               0.8932379129596653
#   Num changes:         2
#   Design Depth:        102
#   Design Size (|D|):   485
#   Open set size:       550
#
# Progress: 1.8%
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       242144.675
#   Best Cost (y):       301486418.8923
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      100.691
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6727→ cube 0.9776
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9036→ cube 0.965
#   Efficiency z (srs):  1.173 → 0.576 → 1.3695
#   Efficiency y (srs):  2.125 → 0.935 → 2.053
#   Alpha:               0.7696328480174586
#   Num changes:         3
#   Design Depth:        117
#   Design Size (|D|):   515
#   Open set size:       633
#
#
# === Best Solution Updated at Iteration 70 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       241343.017
#   Best Cost (y):       301527064.5585
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      100.322
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.675→ cube 0.9808
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9034→ cube 0.9648
#   Efficiency z (srs):  1.173 → 0.576 → 1.374
#   Efficiency y (srs):  2.125 → 0.935 → 2.0527
#   Alpha:               0.7232859322833242
#   Num changes:         3
#   Design Depth:        117
#   Design Size (|D|):   515
#   Open set size:       634
#
# Progress: 2.2%
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       236338.528
#   Best Cost (y):       300489106.4408
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      98.407
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6893→ cube 1.0016
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9066→ cube 0.9682
#   Efficiency z (srs):  1.173 → 0.576 → 1.4031
#   Efficiency y (srs):  2.125 → 0.935 → 2.0598
#   Alpha:               0.7515237887843985
#   Num changes:         3
#   Design Depth:        146
#   Design Size (|D|):   573
#   Open set size:       812
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       235512.657
#   Best Cost (y):       300520462.0331
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      98.032
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6917→ cube 1.0051
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9065→ cube 0.9681
#   Efficiency z (srs):  1.173 → 0.576 → 1.408
#   Efficiency y (srs):  2.125 → 0.935 → 2.0596
#   Alpha:               0.716230281345518
#   Num changes:         2
#   Design Depth:        145
#   Design Size (|D|):   571
#   Open set size:       814
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       235486.368
#   Best Cost (y):       299716936.1175
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      98.015
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6918→ cube 1.0052
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9089→ cube 0.9706
#   Efficiency z (srs):  1.173 → 0.576 → 1.4082
#   Efficiency y (srs):  2.125 → 0.935 → 2.0651
#   Alpha:               0.7126981213194923
#   Num changes:         1
#   Design Depth:        144
#   Design Size (|D|):   569
#   Open set size:       815
#
#
# === Best Solution Updated at Iteration 90 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       234769.428
#   Best Cost (y):       301557415.8331
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      97.762
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.6939→ cube 1.0083
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9034→ cube 0.9647
#   Efficiency z (srs):  1.173 → 0.576 → 1.4125
#   Efficiency y (srs):  2.125 → 0.935 → 2.0525
#   Alpha:               0.8395984831825842
#   Num changes:         1
#   Design Depth:        144
#   Design Size (|D|):   569
#   Open set size:       816
#
# Progress: 2.8%
# === Best Solution Updated at Iteration 110 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       224941.813
#   Best Cost (y):       296790525.189
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      93.856
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7242→ cube 1.0524
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9179→ cube 0.9802
#   Efficiency z (srs):  1.173 → 0.576 → 1.4742
#   Efficiency y (srs):  2.125 → 0.935 → 2.0855
#   Alpha:               0.844572769199446
#   Num changes:         1
#   Design Depth:        167
#   Design Size (|D|):   615
#   Open set size:       996
#
# Progress: 3.0%
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       223200.51
#   Best Cost (y):       291103091.3741
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      93.1
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7298→ cube 1.0606
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9358→ cube 0.9994
#   Efficiency z (srs):  1.173 → 0.576 → 1.4857
#   Efficiency y (srs):  2.125 → 0.935 → 2.1262
#   Alpha:               0.7985418881223983
#   Num changes:         1
#   Design Depth:        181
#   Design Size (|D|):   643
#   Open set size:       1081
#
#
# === Best Solution Updated at Iteration 120 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       223138.047
#   Best Cost (y):       292162822.16
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      93.077
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.73→ cube 1.0609
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9324→ cube 0.9957
#   Efficiency z (srs):  1.173 → 0.576 → 1.4861
#   Efficiency y (srs):  2.125 → 0.935 → 2.1185
#   Alpha:               0.8231352807392813
#   Num changes:         1
#   Design Depth:        181
#   Design Size (|D|):   643
#   Open set size:       1084
#
# Progress: 3.5%
# === Best Solution Updated at Iteration 140 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       220843.058
#   Best Cost (y):       295215762.354
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      92.182
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7376→ cube 1.0719
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9228→ cube 0.9854
#   Efficiency z (srs):  1.173 → 0.576 → 1.5016
#   Efficiency y (srs):  2.125 → 0.935 → 2.0966
#   Alpha:               0.8155637170989161
#   Num changes:         1
#   Design Depth:        208
#   Design Size (|D|):   697
#   Open set size:       1268
#
# Progress: 3.8%
# === Best Solution Updated at Iteration 150 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       218993.158
#   Best Cost (y):       293783536.0494
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      91.409
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7439→ cube 1.081
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9273→ cube 0.9903
#   Efficiency z (srs):  1.173 → 0.576 → 1.5142
#   Efficiency y (srs):  2.125 → 0.935 → 2.1068
#   Alpha:               0.7996912649300784
#   Num changes:         1
#   Design Depth:        224
#   Design Size (|D|):   729
#   Open set size:       1351
#
# Progress: 4.0%
# === Best Solution Updated at Iteration 160 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       215735.759
#   Best Cost (y):       293046753.2116
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      90.049
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7551→ cube 1.0973
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9296→ cube 0.9927
#   Efficiency z (srs):  1.173 → 0.576 → 1.5371
#   Efficiency y (srs):  2.125 → 0.935 → 2.1121
#   Alpha:               0.7597832399528021
#   Num changes:         2
#   Design Depth:        239
#   Design Size (|D|):   759
#   Open set size:       1443
#
# Progress: 5.0%
# === Best Solution Updated at Iteration 200 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       212266.685
#   Best Cost (y):       295868324.9067
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      88.862
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7674→ cube 1.1152
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9207→ cube 0.9833
#   Efficiency z (srs):  1.173 → 0.576 → 1.5622
#   Efficiency y (srs):  2.125 → 0.935 → 2.092
#   Alpha:               0.7435599725812166
#   Num changes:         1
#   Design Depth:        290
#   Design Size (|D|):   861
#   Open set size:       1801
#
# Progress: 6.0%
# === Best Solution Updated at Iteration 240 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       209086.764
#   Best Cost (y):       291172016.7414
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      87.638
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7791→ cube 1.1322
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9356→ cube 0.9991
#   Efficiency z (srs):  1.173 → 0.576 → 1.586
#   Efficiency y (srs):  2.125 → 0.935 → 2.1257
#   Alpha:               0.841473802631716
#   Num changes:         2
#   Design Depth:        324
#   Design Size (|D|):   929
#   Open set size:       2170
#
# Progress: 6.2%
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       204184.518
#   Best Cost (y):       291586624.8359
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      85.67
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7978→ cube 1.1593
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9342→ cube 0.9977
#   Efficiency z (srs):  1.173 → 0.576 → 1.6241
#   Efficiency y (srs):  2.125 → 0.935 → 2.1227
#   Alpha:               0.8522489997533208
#   Num changes:         3
#   Design Depth:        344
#   Design Size (|D|):   969
#   Open set size:       2253
#
#
# === Best Solution Updated at Iteration 250 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       203658.377
#   Best Cost (y):       291451579.1802
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      85.477
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.7999→ cube 1.1623
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9347→ cube 0.9982
#   Efficiency z (srs):  1.173 → 0.576 → 1.6283
#   Efficiency y (srs):  2.125 → 0.935 → 2.1237
#   Alpha:               0.7044357230538993
#   Num changes:         2
#   Design Depth:        343
#   Design Size (|D|):   967
#   Open set size:       2256
#
# Progress: 6.8%
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       200498.179
#   Best Cost (y):       285005072.0346
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      84.092
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8125→ cube 1.1807
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9558→ cube 1.0208
#   Efficiency z (srs):  1.173 → 0.576 → 1.6539
#   Efficiency y (srs):  2.125 → 0.935 → 2.1717
#   Alpha:               0.8597033756620914
#   Num changes:         1
#   Design Depth:        377
#   Design Size (|D|):   1035
#   Open set size:       2431
#
#
# === Best Solution Updated at Iteration 270 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       200486.836
#   Best Cost (y):       284886588.4558
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      84.087
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8125→ cube 1.1807
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9562→ cube 1.0212
#   Efficiency z (srs):  1.173 → 0.576 → 1.654
#   Efficiency y (srs):  2.125 → 0.935 → 2.1726
#   Alpha:               0.8297331943671633
#   Num changes:         1
#   Design Depth:        377
#   Design Size (|D|):   1035
#   Open set size:       2435
#
# Progress: 7.0%
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       197814.153
#   Best Cost (y):       288979219.2726
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      83.036
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8235→ cube 1.1967
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9427→ cube 1.0067
#   Efficiency z (srs):  1.173 → 0.576 → 1.6764
#   Efficiency y (srs):  2.125 → 0.935 → 2.1418
#   Alpha:               0.7498100640833374
#   Num changes:         1
#   Design Depth:        390
#   Design Size (|D|):   1061
#   Open set size:       2522
#
#
# === Best Solution Updated at Iteration 280 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       197807.969
#   Best Cost (y):       287713233.1871
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      83.022
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8235→ cube 1.1967
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9468→ cube 1.0111
#   Efficiency z (srs):  1.173 → 0.576 → 1.6764
#   Efficiency y (srs):  2.125 → 0.935 → 2.1513
#   Alpha:               0.7154018695559662
#   Num changes:         3
#   Design Depth:        392
#   Design Size (|D|):   1065
#   Open set size:       2528
#
# Progress: 7.2%
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       196440.375
#   Best Cost (y):       287406337.8402
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      82.457
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8293→ cube 1.2051
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9478→ cube 1.0122
#   Efficiency z (srs):  1.173 → 0.576 → 1.6881
#   Efficiency y (srs):  2.125 → 0.935 → 2.1536
#   Alpha:               0.7323725035529802
#   Num changes:         1
#   Design Depth:        404
#   Design Size (|D|):   1089
#   Open set size:       2615
#
#
# === Best Solution Updated at Iteration 290 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       196429.294
#   Best Cost (y):       287753111.2812
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      82.456
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8293→ cube 1.2051
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9467→ cube 1.011
#   Efficiency z (srs):  1.173 → 0.576 → 1.6882
#   Efficiency y (srs):  2.125 → 0.935 → 2.151
#   Alpha:               0.8104767652412076
#   Num changes:         1
#   Design Depth:        404
#   Design Size (|D|):   1089
#   Open set size:       2617
#
# Progress: 7.5%
# === Best Solution Updated at Iteration 300 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       195891.701
#   Best Cost (y):       288065623.9877
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      82.243
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8316→ cube 1.2084
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9457→ cube 1.0099
#   Efficiency z (srs):  1.173 → 0.576 → 1.6928
#   Efficiency y (srs):  2.125 → 0.935 → 2.1486
#   Alpha:               0.8753138324985825
#   Num changes:         1
#   Design Depth:        415
#   Design Size (|D|):   1111
#   Open set size:       2706
#
# Progress: 10.5%
# === Best Solution Updated at Iteration 420 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       183981.829
#   Best Cost (y):       282145705.0635
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      77.421
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8854→ cube 1.2867
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9655→ cube 1.0311
#   Efficiency z (srs):  1.173 → 0.576 → 1.8024
#   Efficiency y (srs):  2.125 → 0.935 → 2.1937
#   Alpha:               0.7014664613333527
#   Num changes:         1
#   Design Depth:        554
#   Design Size (|D|):   1389
#   Open set size:       3782
#
# Progress: 10.8%
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       182817.351
#   Best Cost (y):       282559631.9803
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      76.935
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8911→ cube 1.2948
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9641→ cube 1.0296
#   Efficiency z (srs):  1.173 → 0.576 → 1.8139
#   Efficiency y (srs):  2.125 → 0.935 → 2.1905
#   Alpha:               0.759857823799548
#   Num changes:         2
#   Design Depth:        576
#   Design Size (|D|):   1433
#   Open set size:       3874
#
#
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       182829.742
#   Best Cost (y):       282259953.3291
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      76.935
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.891→ cube 1.2948
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9651→ cube 1.0307
#   Efficiency z (srs):  1.173 → 0.576 → 1.8138
#   Efficiency y (srs):  2.125 → 0.935 → 2.1928
#   Alpha:               0.7716250474705981
#   Num changes:         1
#   Design Depth:        575
#   Design Size (|D|):   1431
#   Open set size:       3877
#
#
# === Best Solution Updated at Iteration 430 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       182826.219
#   Best Cost (y):       282265470.0707
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      76.931
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.891→ cube 1.2948
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9651→ cube 1.0307
#   Efficiency z (srs):  1.173 → 0.576 → 1.8138
#   Efficiency y (srs):  2.125 → 0.935 → 2.1928
#   Alpha:               0.8870290778400831
#   Num changes:         1
#   Design Depth:        575
#   Design Size (|D|):   1431
#   Open set size:       3880
#
# Progress: 11.0%
# === Best Solution Updated at Iteration 440 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       181947.317
#   Best Cost (y):       281031143.0777
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      76.567
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8953→ cube 1.301
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9693→ cube 1.0352
#   Efficiency z (srs):  1.173 → 0.576 → 1.8226
#   Efficiency y (srs):  2.125 → 0.935 → 2.2024
#   Alpha:               0.8478090286021309
#   Num changes:         3
#   Design Depth:        599
#   Design Size (|D|):   1479
#   Open set size:       3961
#
# Progress: 11.5%
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       181305.178
#   Best Cost (y):       276892468.2492
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      76.333
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8985→ cube 1.3056
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9838→ cube 1.0507
#   Efficiency z (srs):  1.173 → 0.576 → 1.829
#   Efficiency y (srs):  2.125 → 0.935 → 2.2353
#   Alpha:               0.8149609380784462
#   Num changes:         2
#   Design Depth:        627
#   Design Size (|D|):   1535
#   Open set size:       4141
#
#
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       181267.244
#   Best Cost (y):       278491328.1783
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      76.301
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.8987→ cube 1.3059
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9782→ cube 1.0446
#   Efficiency z (srs):  1.173 → 0.576 → 1.8294
#   Efficiency y (srs):  2.125 → 0.935 → 2.2225
#   Alpha:               0.8372355891392937
#   Num changes:         1
#   Design Depth:        626
#   Design Size (|D|):   1533
#   Open set size:       4145
#
#
# === Best Solution Updated at Iteration 460 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       180974.525
#   Best Cost (y):       277086408.528
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      76.17
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9001→ cube 1.308
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9831→ cube 1.0499
#   Efficiency z (srs):  1.173 → 0.576 → 1.8324
#   Efficiency y (srs):  2.125 → 0.935 → 2.2338
#   Alpha:               0.7137333612592042
#   Num changes:         2
#   Design Depth:        627
#   Design Size (|D|):   1535
#   Open set size:       4149
#
# Progress: 11.8%
# === Best Solution Updated at Iteration 470 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       179860.401
#   Best Cost (y):       278191446.8597
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      75.73
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9057→ cube 1.3161
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9792→ cube 1.0458
#   Efficiency z (srs):  1.173 → 0.576 → 1.8437
#   Efficiency y (srs):  2.125 → 0.935 → 2.2249
#   Alpha:               0.832639728571855
#   Num changes:         2
#   Design Depth:        640
#   Design Size (|D|):   1561
#   Open set size:       4236
#
# Progress: 12.5%
# === Best Solution Updated at Iteration 500 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       178198.716
#   Best Cost (y):       275574486.5561
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      75.051
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9141→ cube 1.3284
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9885→ cube 1.0557
#   Efficiency z (srs):  1.173 → 0.576 → 1.8609
#   Efficiency y (srs):  2.125 → 0.935 → 2.246
#   Alpha:               0.8792376672372398
#   Num changes:         3
#   Design Depth:        676
#   Design Size (|D|):   1633
#   Open set size:       4504
#
# Progress: 12.8%
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       176108.693
#   Best Cost (y):       275815540.0567
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      74.172
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.925→ cube 1.3442
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9877→ cube 1.0548
#   Efficiency z (srs):  1.173 → 0.576 → 1.883
#   Efficiency y (srs):  2.125 → 0.935 → 2.2441
#   Alpha:               0.7128656227663704
#   Num changes:         1
#   Design Depth:        691
#   Design Size (|D|):   1663
#   Open set size:       4591
#
#
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       176086.042
#   Best Cost (y):       275869543.9357
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      74.163
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9251→ cube 1.3443
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9875→ cube 1.0546
#   Efficiency z (srs):  1.173 → 0.576 → 1.8832
#   Efficiency y (srs):  2.125 → 0.935 → 2.2436
#   Alpha:               0.7679464066152932
#   Num changes:         1
#   Design Depth:        691
#   Design Size (|D|):   1663
#   Open set size:       4592
#
#
# === Best Solution Updated at Iteration 510 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       176085.408
#   Best Cost (y):       276251653.6393
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      74.159
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9251→ cube 1.3444
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9861→ cube 1.0531
#   Efficiency z (srs):  1.173 → 0.576 → 1.8832
#   Efficiency y (srs):  2.125 → 0.935 → 2.2405
#   Alpha:               0.824266700495631
#   Num changes:         3
#   Design Depth:        693
#   Design Size (|D|):   1667
#   Open set size:       4593
#
# Progress: 13.0%
# === Best Solution Updated at Iteration 520 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       175159.703
#   Best Cost (y):       273673577.1294
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      73.782
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.93→ cube 1.3515
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 0.9954→ cube 1.063
#   Efficiency z (srs):  1.173 → 0.576 → 1.8932
#   Efficiency y (srs):  2.125 → 0.935 → 2.2616
#   Alpha:               0.8860148537516244
#   Num changes:         1
#   Design Depth:        710
#   Design Size (|D|):   1701
#   Open set size:       4684
#
# Progress: 13.8%
# === Best Solution Updated at Iteration 550 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       172556.578
#   Best Cost (y):       272026389.2635
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      72.756
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.944→ cube 1.3718
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0014→ cube 1.0695
#   Efficiency z (srs):  1.173 → 0.576 → 1.9217
#   Efficiency y (srs):  2.125 → 0.935 → 2.2753
#   Alpha:               0.8486518894010473
#   Num changes:         1
#   Design Depth:        750
#   Design Size (|D|):   1781
#   Open set size:       4954
#
# Progress: 14.0%
# === Best Solution Updated at Iteration 560 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       169217.723
#   Best Cost (y):       272118709.0987
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      71.438
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9627→ cube 1.3989
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0011→ cube 1.0691
#   Efficiency z (srs):  1.173 → 0.576 → 1.9597
#   Efficiency y (srs):  2.125 → 0.935 → 2.2745
#   Alpha:               0.8488911151380494
#   Num changes:         2
#   Design Depth:        772
#   Design Size (|D|):   1825
#   Open set size:       5041
#
# Progress: 100.0%
# === Best Solution Updated at Iteration 3999 ===
#   Balancing Method:    origine
#   Real and E(.) z,y:   2508→2508.0, 53151→53151.0
#   Best Cost (z):       168216.368
#   Best Cost (y):       272404646.1622
#   number of new noded: 10
#   rho (z, y):          0.657
#   rho (z_hat, y_hat):  0.478
#   rho (p, y):          0.651
#   Criteria Value:      71.053
#   Efficiency z (0→f):  0.576 → 0.576 → dsd 0.9684→ cube 1.4072
#   Efficiency y (0→f):  0.935 → 0.935 → dsd 1.0→ cube 1.068
#   Efficiency z (srs):  1.173 → 0.576 → 1.9713
#   Efficiency y (srs):  2.125 → 0.935 → 2.2722
#   Alpha:               None
#   Num changes:         None
#   Design Depth:        788
#   Design Size (|D|):   1857
#   Open set size:       36001
#
# Best criteria value: 71.05312631158368
# Iterations run: 4000
# Best criteria value: 71.05312631158368
# Iterations run: 4000

# %%
#print(inclusions)
print("size of init design",len(list(astar.initial_design)))
print("size of best design", len(list(astar.best_design)))
#print(astar.initial_design.criteria_value())
print(astar.criteria(astar.initial_design))
print(astar.criteria(astar.best_design))
for k in range(int(N)):
    size_last = 0
    prob_last = 0
    len_last = 0
    prob_last_second = 0
    prob = 0
    for item in astar.best_design:
        prob += item.probability
        size_last += 1
        len_last += len(item.ids)
        if k in item.ids:
            prob_last += item.probability
            if k+1 in item.ids:
                prob_last_second += item.probability
        #print(item)
    size_ini = 0
    prob_ini = 0
    len_ini = 0
    prob_ini_second = 0
    for item in astar.initial_design:
        len_ini += len(item.ids)
        size_ini += 1
        if k in item.ids:
            prob_ini += item.probability
            if k+1 in item.ids:
                prob_ini_second += item.probability
        #print(item)
    
    if not (len_last%n == 0 and len_ini%n == 0 and 
        np.round(prob_last, 3) == np.round(prob_ini, 3) and 
        np.round(prob_last, 3) == np.round(inclusions[k], 3)):
        print('yes')
print(prob)
# Out:
# size of init design 281
# size of best design 1857
# 117.14400031694026
# 71.05312631158368
# /tmp/ipykernel_852640/1240027416.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   for k in range(int(N)):
# 1.0000000080000004
