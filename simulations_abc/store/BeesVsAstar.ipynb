# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os, sys
print("CWD:", os.getcwd())
print("Python:", sys.executable)
print("First few sys.path entries:")
for p in sys.path[:10]:
    print(" ", p)
# Out:
# CWD: /config/ws/graphical-sampling/vincent
# Python: /config/.venv/bin/python
# First few sys.path entries:
#   /config/ws/graphical-sampling
#   /usr/lib/python312.zip
#   /usr/lib/python3.12
#   /usr/lib/python3.12/lib-dynload
#
#   /config/.venv/lib/python3.12/site-packages

# %%
import os, sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

import graphical_sampling as gs

# %%
import os
import glob
import pandas as pd
import numpy as np
import itertools
from tqdm import tqdm
from package_sampling.utils import inclusion_probabilities

# %% [markdown]
# # Loading and Determining Population

# %%
DATA_DIR = "../populations"
csv_paths = glob.glob(os.path.join(DATA_DIR, "*.csv"))

coords_dict = {}
probs_dict = {}

for fp in csv_paths:
    name = os.path.splitext(os.path.basename(fp))[0]
    data = np.loadtxt(fp, delimiter=",", skiprows=1)
    coords = data[:, :2]
    probs  = data[:, -1]

    coord_name, prob_name, *rest = name.split("_")
    coord_name = 'cluster' if coord_name == 'clust' else coord_name
    prob_name = 'equal' if prob_name == 'eq' else 'unequal'

    coords_dict[coord_name] = coords
    probs_dict[coord_name] = probs_dict.get(coord_name, {})
    probs_dict[coord_name][prob_name] = probs

print(coords_dict.keys())
print(probs_dict.keys())
print(probs_dict['random'].keys())
# Out:
# dict_keys(['AggregatedPop1027', 'meuse', 'RegularPop1000', 'cluster', 'random', 'swiss', 'grid'])
# dict_keys(['AggregatedPop1027', 'meuse', 'RegularPop1000', 'cluster', 'random', 'swiss', 'grid'])
# dict_keys(['unequal', 'equal'])

# %%
n = 4
coords = coords_dict['random']
probs = probs_dict['random']['unequal']
N = len(probs)
modified_probs = inclusion_probabilities(probs, n=n)
pop = gs.Population(coords, modified_probs)

# %%
import matplotlib.pyplot as plt
x = coords[:, 0]
y = coords[:, 1]

plt.figure(figsize=(7,5))
plt.scatter(x, y, s=1000*modified_probs, color = 'red')
plt.show()

# %% [markdown]
# # Building Initial Designs

# %%
orders = [
    # "lexico-yx",
    # "lexico-xy",
    # "random",
    # "angle_0",
    # "distance_0",
    # "projection",
    # "center",
    "spiral",
    # "max",
    # "snake",
    # "hilbert",
]

# %%
initial_designs = []
combines = list(itertools.product(orders, orders))
num_trials = 2
for units_order, zones_order in tqdm(combines, desc="Generating initial designs", total=len(combines), unit="orders"):
    best = None
    best_score = np.inf
    for _ in range(num_trials):
        ks = gs.sampling.KMeansSampler(
            population=pop,
            n=n,
            n_zones=(2, 2),
            zone_builder='sweep',
            units_order=units_order,
            zones_order=zones_order,
            split_size=0.001
        )
        if ks.expected_moran_score() < best_score:
            best = ks
            best_score = ks.expected_moran_score()

    initial_designs.append(gs.NewDesign(best))

    for _ in range(num_trials):
        ks = gs.sampling.KMeansSampler(
            population=pop,
            n=n,
            n_zones=(1, 1),
            zone_builder='sweep',
            units_order=units_order,
            zones_order=zones_order,
            split_size=0.001
        )
        if ks.expected_moran_score() < best_score:
            best = ks
            best_score = ks.expected_moran_score()

    initial_designs.append(gs.NewDesign(best))
# Out:
# Generating initial designs:   0%|          | 0/1 [00:00<?, ?orders/s]
# Generating initial designs: 100%|██████████| 1/1 [00:11<00:00, 11.60s/orders]

# %%
for design in initial_designs:
    print(design.kmeans.all_samples.shape, design.kmeans.expected_moran_score())
# Out:
# (111, 4) -0.2537789679101993
# (111, 4) -0.2537789679101993

# %% [markdown]
# # Run Astar

# %%
moran_criteria = gs.criteria.MoranCriteria()

# %%
astar = gs.search.AStar(
    initial_designs,
    moran_criteria
)
# Out:
# best initial criteria value -0.2537789679101993

# %%
import time

t0 = time.perf_counter()
astar.run(
    max_iterations=200,
    num_new_nodes=10,
    max_open_set_size=1000,
    n_clusters_to_change_order_zone=1,
    n_changes_in_order_of_zones=1,
    n_clusters_to_change_order_units=1,
    n_zones_to_change_order_units=1,
    n_changes_in_order_of_units=1,
    n_jobs=-1,
)
elapsed_astar = time.perf_counter() - t0
print(f"A* time: {elapsed_astar:.2f} seconds")
# Out:
# parent node: -0.2537789679101993
# iteration: 0, child node: -0.23685969853630665
# iteration: 0, child node: -0.2378951115313428
# iteration: 0, child node: -0.22413421436470735
# iteration: 0, child node: -0.22906130981124326
# iteration: 0, child node: -0.228805424005936
# iteration: 0, child node: -0.2565888911029081
#
# ==============================================
# iteration: 0, New best criteria value: -0.2565888911029081
#
# iteration: 0, child node: -0.2511423777740839
# iteration: 0, child node: -0.20934931537564258
#
# parent node: -0.2565888911029081
# iteration: 1, child node: -0.228120537385907
# iteration: 1, child node: -0.2560905219745363
# iteration: 1, child node: -0.24764001627089632
# iteration: 1, child node: -0.2186183380318508
# iteration: 1, child node: -0.2559242031076839
# iteration: 1, child node: -0.2286857012854792
# iteration: 1, child node: -0.22286935474450825
# iteration: 1, child node: -0.24034193894308162
# iteration: 1, child node: -0.23164668281056439
#
# parent node: -0.2560905219745363
# iteration: 2, child node: -0.24935516852401599
# iteration: 2, child node: -0.2618820243254756
#
# ==============================================
# iteration: 2, New best criteria value: -0.2618820243254756
#
# iteration: 2, child node: -0.25463123668575005
# iteration: 2, child node: -0.24723542558760775
# iteration: 2, child node: -0.21976344860353766
# iteration: 2, child node: -0.2534679566092055
# iteration: 2, child node: -0.23271527089255492
# iteration: 2, child node: -0.23892649055788207
# iteration: 2, child node: -0.2468218433349598
# iteration: 2, child node: -0.23496489385381694
#
# parent node: -0.2618820243254756
# iteration: 3, child node: -0.2554502161113944
# iteration: 3, child node: -0.2619330800408032
#
# ==============================================
# iteration: 3, New best criteria value: -0.2619330800408032
#
# iteration: 3, child node: -0.2624710033397376
#
# ==============================================
# iteration: 3, New best criteria value: -0.2624710033397376
#
# iteration: 3, child node: -0.21348564502536166
# iteration: 3, child node: -0.25998272403475853
# iteration: 3, child node: -0.2812871448152655
#
# ==============================================
# iteration: 3, New best criteria value: -0.2812871448152655
#
# iteration: 3, child node: -0.24235658465253654
# iteration: 3, child node: -0.2338827576325201
# iteration: 3, child node: -0.22931448365401955
# iteration: 3, child node: -0.23690826977185292
#
# parent node: -0.2812871448152655
# iteration: 4, child node: -0.2863845688161176
#
# ==============================================
# iteration: 4, New best criteria value: -0.2863845688161176
#
# iteration: 4, child node: -0.2538485342937721
# iteration: 4, child node: -0.21605927364186675
# iteration: 4, child node: -0.22979317701920746
# iteration: 4, child node: -0.26176695274115364
# iteration: 4, child node: -0.2162618475096741
# iteration: 4, child node: -0.2711176437384785
# iteration: 4, child node: -0.25463676480289876
# iteration: 4, child node: -0.28186941341618527
#
# parent node: -0.2863845688161176
# iteration: 5, child node: -0.269617208747913
# iteration: 5, child node: -0.24649741510685644
# iteration: 5, child node: -0.265508380104532
# iteration: 5, child node: -0.29410270863375365
#
# ==============================================
# iteration: 5, New best criteria value: -0.29410270863375365
#
# iteration: 5, child node: -0.303737668679778
#
# ==============================================
# iteration: 5, New best criteria value: -0.303737668679778
#
# iteration: 5, child node: -0.2821566594733612
# iteration: 5, child node: -0.27908877421546613
# iteration: 5, child node: -0.2863845688161176
# iteration: 5, child node: -0.29139951172946793
# iteration: 5, child node: -0.26669289702786847
#
# parent node: -0.303737668679778
# iteration: 6, child node: -0.3028800411676622
# iteration: 6, child node: -0.24571335207632963
# iteration: 6, child node: -0.2846343500012596
# iteration: 6, child node: -0.25967091548655563
# iteration: 6, child node: -0.27645532467921674
# iteration: 6, child node: -0.2923987544958108
# iteration: 6, child node: -0.26030093880539035
# iteration: 6, child node: -0.2477770734627781
# iteration: 6, child node: -0.2998104935163081
# iteration: 6, child node: -0.257877569617917
#
# parent node: -0.3028800411676622
# iteration: 7, child node: -0.2805661088805768
# iteration: 7, child node: -0.24184983944045813
# iteration: 7, child node: -0.2551714847196222
# iteration: 7, child node: -0.2723493689421759
# iteration: 7, child node: -0.30110596692494285
# iteration: 7, child node: -0.2798772238921064
# iteration: 7, child node: -0.27777815113669624
# iteration: 7, child node: -0.25649212414646
# iteration: 7, child node: -0.30286981805100366
# iteration: 7, child node: -0.2988994730257787
#
# parent node: -0.30286981805100366
# iteration: 8, child node: -0.28007058886683145
# iteration: 8, child node: -0.296353186954734
# iteration: 8, child node: -0.30094524587150673
# iteration: 8, child node: -0.2986825912928517
# iteration: 8, child node: -0.24105769562900262
# iteration: 8, child node: -0.24453164035638986
# iteration: 8, child node: -0.30026155498679274
# iteration: 8, child node: -0.23663345358714977
# iteration: 8, child node: -0.2935202682753705
#
# parent node: -0.30110596692494285
# iteration: 9, child node: -0.2757839110026352
# iteration: 9, child node: -0.25475390972408946
# iteration: 9, child node: -0.2757794707953252
# iteration: 9, child node: -0.21512417315895913
# iteration: 9, child node: -0.3020100316482095
# iteration: 9, child node: -0.2830283740301955
# iteration: 9, child node: -0.2997282724904341
# iteration: 9, child node: -0.32171487792416054
#
# ==============================================
# iteration: 9, New best criteria value: -0.32171487792416054
#
# iteration: 9, child node: -0.26627597685826465
# iteration: 9, child node: -0.23983630651571305
#
# parent node: -0.32171487792416054
# iteration: 10, child node: -0.2573013043961516
# iteration: 10, child node: -0.2561574072579216
# iteration: 10, child node: -0.2942205218951839
# iteration: 10, child node: -0.28090119073290337
# iteration: 10, child node: -0.2952115720899462
# iteration: 10, child node: -0.32172734436450645
#
# ==============================================
# iteration: 10, New best criteria value: -0.32172734436450645
#
# iteration: 10, child node: -0.29725672277439713
# iteration: 10, child node: -0.2809968240942819
# iteration: 10, child node: -0.2359934491607831
# iteration: 10, child node: -0.29919504277390524
#
# parent node: -0.32172734436450645
# iteration: 11, child node: -0.2935436070438856
# iteration: 11, child node: -0.32224111898922403
#
# ==============================================
# iteration: 11, New best criteria value: -0.32224111898922403
#
# iteration: 11, child node: -0.28055917509050066
# iteration: 11, child node: -0.2945025688037719
# iteration: 11, child node: -0.24696077861206758
# iteration: 11, child node: -0.2613630839026865
# iteration: 11, child node: -0.2804718857828544
# iteration: 11, child node: -0.2923139065290874
# iteration: 11, child node: -0.2545994729472769
# iteration: 11, child node: -0.2748299492383473
#
# parent node: -0.32224111898922403
# iteration: 12, child node: -0.2947467629602475
# iteration: 12, child node: -0.2729621849274521
# iteration: 12, child node: -0.2618022957648282
# iteration: 12, child node: -0.26511607050618347
# iteration: 12, child node: -0.29567557487967844
# iteration: 12, child node: -0.29078642011293493
# iteration: 12, child node: -0.3011912906440165
# iteration: 12, child node: -0.2913198052469812
# iteration: 12, child node: -0.2949378844049002
# iteration: 12, child node: -0.3073827501210812
#
# parent node: -0.3073827501210812
# iteration: 13, child node: -0.23179151959301375
# iteration: 13, child node: -0.25980763657808714
# iteration: 13, child node: -0.3038025796503449
# iteration: 13, child node: -0.3042076594999866
# iteration: 13, child node: -0.2894225756713388
# iteration: 13, child node: -0.3082626277667176
# iteration: 13, child node: -0.2545832877804962
# iteration: 13, child node: -0.21979501469784807
#
# parent node: -0.3082626277667176
# iteration: 14, child node: -0.291076872177461
# iteration: 14, child node: -0.2986888083567171
# iteration: 14, child node: -0.263254149222072
# iteration: 14, child node: -0.28331150305307884
# iteration: 14, child node: -0.2699483125448824
# iteration: 14, child node: -0.292090551914024
# iteration: 14, child node: -0.22114044192802096
# iteration: 14, child node: -0.30251260200428465
# iteration: 14, child node: -0.2554631654261327
# iteration: 14, child node: -0.26016941671332855
#
# parent node: -0.3042076594999866
# iteration: 15, child node: -0.2874087698747616
# iteration: 15, child node: -0.2538090020052107
# iteration: 15, child node: -0.2509581391170383
# iteration: 15, child node: -0.2788924194761332
# iteration: 15, child node: -0.3026351200078926
# iteration: 15, child node: -0.2513710597326455
# iteration: 15, child node: -0.2882286861869445
# iteration: 15, child node: -0.3025558352621618
# iteration: 15, child node: -0.2578870499362558
# iteration: 15, child node: -0.3050875371456231
#
# parent node: -0.3050875371456231
# iteration: 16, child node: -0.3051664766056111
# iteration: 16, child node: -0.301276070574802
# iteration: 16, child node: -0.26008602828243554
# iteration: 16, child node: -0.30422782809372895
# iteration: 16, child node: -0.29855041596870424
# iteration: 16, child node: -0.2945016088926903
# iteration: 16, child node: -0.23130533453676858
# iteration: 16, child node: -0.27448147369720693
#
# parent node: -0.3051664766056111
# iteration: 17, child node: -0.29488091760779656
# iteration: 17, child node: -0.2781933527882494
# iteration: 17, child node: -0.28798072101635447
# iteration: 17, child node: -0.3017741846630122
# iteration: 17, child node: -0.2913782028463136
# iteration: 17, child node: -0.2810420880096467
# iteration: 17, child node: -0.29488091760779656
# iteration: 17, child node: -0.28865774629447055
#
# parent node: -0.30422782809372895
# iteration: 18, child node: -0.27140062256228004
# iteration: 18, child node: -0.27911316154135934
# iteration: 18, child node: -0.253782477496408
# iteration: 18, child node: -0.2975583773996847
# iteration: 18, child node: -0.22238801691065893
# iteration: 18, child node: -0.30228676550852385
# iteration: 18, child node: -0.2556838309536645
# iteration: 18, child node: -0.2885802613764973
# iteration: 18, child node: -0.28162982284265203
#
# parent node: -0.3038025796503449
# iteration: 19, child node: -0.3045300213993656
# iteration: 19, child node: -0.26151487760720676
# iteration: 19, child node: -0.2877434446414573
# iteration: 19, child node: -0.30479632343686636
# iteration: 19, child node: -0.2233126735370424
# iteration: 19, child node: -0.24896425813094739
# iteration: 19, child node: -0.25755390942978806
# iteration: 19, child node: -0.2911061860234394
# iteration: 19, child node: -0.2515837512083654
# iteration: 19, child node: -0.26337415526170055
#
# parent node: -0.30479632343686636
# iteration: 20, child node: -0.2593031127111646
# iteration: 20, child node: -0.26614870999629137
# iteration: 20, child node: -0.223374539933959
# iteration: 20, child node: -0.2534291638662866
# iteration: 20, child node: -0.22268188230680344
# iteration: 20, child node: -0.304838149380518
# iteration: 20, child node: -0.264870086813942
# iteration: 20, child node: -0.21781580828799874
# iteration: 20, child node: -0.25932760733236493
# iteration: 20, child node: -0.30278758129592587
#
# parent node: -0.304838149380518
# iteration: 21, child node: -0.26007998240349905
# iteration: 21, child node: -0.29878897929712944
# iteration: 21, child node: -0.2928605925682539
# iteration: 21, child node: -0.26806655878713126
# iteration: 21, child node: -0.291222363219553
# iteration: 21, child node: -0.25828578751942366
# iteration: 21, child node: -0.2964607602327973
# iteration: 21, child node: -0.2572557460094753
# iteration: 21, child node: -0.30544251544735207
# iteration: 21, child node: -0.30661222362323737
#
# parent node: -0.30661222362323737
# iteration: 22, child node: -0.2778377779901594
# iteration: 22, child node: -0.2775477878780927
# iteration: 22, child node: -0.2717751957452306
# iteration: 22, child node: -0.29459489387019533
# iteration: 22, child node: -0.2993624015253685
# iteration: 22, child node: -0.3074764010747849
# iteration: 22, child node: -0.2999299696036938
# iteration: 22, child node: -0.2986055814142097
# iteration: 22, child node: -0.2777405846863037
#
# parent node: -0.3074764010747849
# iteration: 23, child node: -0.25877754903521594
# iteration: 23, child node: -0.3023881527940767
# iteration: 23, child node: -0.25620267981843925
# iteration: 23, child node: -0.2572338601944777
# iteration: 23, child node: -0.30080240903499184
# iteration: 23, child node: -0.22056359656165847
# iteration: 23, child node: -0.30376115836311723
# iteration: 23, child node: -0.29448085096263327
# iteration: 23, child node: -0.3214336207540264
#
# parent node: -0.3214336207540264
# iteration: 24, child node: -0.32377799407798613
#
# ==============================================
# iteration: 24, New best criteria value: -0.32377799407798613
#
# iteration: 24, child node: -0.2815430417086715
# iteration: 24, child node: -0.25202128916749156
# iteration: 24, child node: -0.26875197550611013
# iteration: 24, child node: -0.32154718434329654
# iteration: 24, child node: -0.3206040012162482
# iteration: 24, child node: -0.2529615313974462
# iteration: 24, child node: -0.31435107130296325
# iteration: 24, child node: -0.2978980334292578
#
# parent node: -0.32377799407798613
# iteration: 25, child node: -0.32313258798851313
# iteration: 25, child node: -0.2529921398260013
# iteration: 25, child node: -0.27378896464887337
# iteration: 25, child node: -0.3221927541923283
# iteration: 25, child node: -0.2484082377903037
# iteration: 25, child node: -0.267636078095581
# iteration: 25, child node: -0.25379081436645057
# iteration: 25, child node: -0.2686345133665422
# iteration: 25, child node: -0.30070690760843155
# iteration: 25, child node: -0.2686345133665422
#
# parent node: -0.32313258798851313
# iteration: 26, child node: -0.23638693227747976
# iteration: 26, child node: -0.2488399067388083
# iteration: 26, child node: -0.2946481341377488
# iteration: 26, child node: -0.29376320218123153
# iteration: 26, child node: -0.2477628317008307
# iteration: 26, child node: -0.28752709326906833
# iteration: 26, child node: -0.28402880228217625
# iteration: 26, child node: -0.25426106453014485
# iteration: 26, child node: -0.26191201116202034
# iteration: 26, child node: -0.30283169808827026
#
# parent node: -0.3221927541923283
# iteration: 27, child node: -0.2707391438234529
# iteration: 27, child node: -0.3217795101704384
# iteration: 27, child node: -0.292906675943562
# iteration: 27, child node: -0.2651264038368223
# iteration: 27, child node: -0.2703836554489374
# iteration: 27, child node: -0.2726200910753831
# iteration: 27, child node: -0.32245678830148305
# iteration: 27, child node: -0.27229681855281485
# iteration: 27, child node: -0.32153884244831643
# iteration: 27, child node: -0.29480172326146037
#
# parent node: -0.32245678830148305
# iteration: 28, child node: -0.298898551937296
# iteration: 28, child node: -0.25191023812182034
# iteration: 28, child node: -0.3180768739342051
# iteration: 28, child node: -0.2721901737656221
# iteration: 28, child node: -0.26525556466450295
# iteration: 28, child node: -0.2838193047676354
# iteration: 28, child node: -0.3203848156956691
# iteration: 28, child node: -0.3147700820699503
# iteration: 28, child node: -0.3225528853644976
# iteration: 28, child node: -0.2929466481760798
#
# parent node: -0.3225528853644976
# iteration: 29, child node: -0.2802618371717656
# iteration: 29, child node: -0.30242202454965406
# iteration: 29, child node: -0.29658971240411613
# iteration: 29, child node: -0.23385973489863718
# iteration: 29, child node: -0.24895770003160406
# iteration: 29, child node: -0.258630951835187
# iteration: 29, child node: -0.266028287967687
# iteration: 29, child node: -0.2715730674827249
# iteration: 29, child node: -0.25508217482748147
#
# parent node: -0.3217795101704384
# iteration: 30, child node: -0.27995468545581614
# iteration: 30, child node: -0.27324847971365357
# iteration: 30, child node: -0.3236669225662673
# iteration: 30, child node: -0.29211975567369064
# iteration: 30, child node: -0.2837296576350099
# iteration: 30, child node: -0.26637176024141396
# iteration: 30, child node: -0.3075302959877659
# iteration: 30, child node: -0.2504202766349305
# iteration: 30, child node: -0.30613766180775726
#
# parent node: -0.3236669225662673
# iteration: 31, child node: -0.2527225607585347
# iteration: 31, child node: -0.2678358751671837
# iteration: 31, child node: -0.2885577073169536
# iteration: 31, child node: -0.31974164584280756
# iteration: 31, child node: -0.321799687751429
# iteration: 31, child node: -0.2939245500689451
# iteration: 31, child node: -0.2645330607547467
# iteration: 31, child node: -0.25147608373374675
# iteration: 31, child node: -0.31603836204623237
#
# parent node: -0.321799687751429
# iteration: 32, child node: -0.28259390907368126
# iteration: 32, child node: -0.2893388858352136
# iteration: 32, child node: -0.28517716832814455
# iteration: 32, child node: -0.28209114399458646
# iteration: 32, child node: -0.2873883041822885
# iteration: 32, child node: -0.284298133536601
# iteration: 32, child node: -0.29783369016419314
# iteration: 32, child node: -0.30300359428542084
# iteration: 32, child node: -0.26681858660987806
# iteration: 32, child node: -0.2663083959355337
#
# parent node: -0.32154718434329654
# iteration: 33, child node: -0.3192321062211706
# iteration: 33, child node: -0.31149808221116115
# iteration: 33, child node: -0.30234745169199817
# iteration: 33, child node: -0.29064677643022313
# iteration: 33, child node: -0.26992006280429215
# iteration: 33, child node: -0.29162013850638085
# iteration: 33, child node: -0.24669864056831267
# iteration: 33, child node: -0.2864825587138595
# iteration: 33, child node: -0.29873786078230047
# iteration: 33, child node: -0.2951182400780522
#
# parent node: -0.32153884244831643
# iteration: 34, child node: -0.3216316955182407
# iteration: 34, child node: -0.3153335702416606
# iteration: 34, child node: -0.2696668215072726
# iteration: 34, child node: -0.30612714217873016
# iteration: 34, child node: -0.2985103659214381
# iteration: 34, child node: -0.29471533203672884
# iteration: 34, child node: -0.24935776003021126
# iteration: 34, child node: -0.27150951998211803
# iteration: 34, child node: -0.29427013141709923
#
# parent node: -0.3216316955182407
# iteration: 35, child node: -0.2918186860475258
# iteration: 35, child node: -0.2648236072931597
# iteration: 35, child node: -0.27001169134272424
# iteration: 35, child node: -0.3075259388522192
# iteration: 35, child node: -0.2997312428913144
# iteration: 35, child node: -0.29258580763872255
# iteration: 35, child node: -0.28405817536485967
# iteration: 35, child node: -0.25219984008250595
# iteration: 35, child node: -0.3197375865174675
# iteration: 35, child node: -0.2836954629073579
#
# parent node: -0.3206040012162482
# iteration: 36, child node: -0.2998099532490218
# iteration: 36, child node: -0.24833307464048243
# iteration: 36, child node: -0.2587999870480395
# iteration: 36, child node: -0.3007495600222169
# iteration: 36, child node: -0.2922649045368619
# iteration: 36, child node: -0.2527231359190041
# iteration: 36, child node: -0.2819622096856726
# iteration: 36, child node: -0.236866209287532
#
# parent node: -0.3203848156956691
# iteration: 37, child node: -0.2955363919183854
# iteration: 37, child node: -0.31961761062387295
# iteration: 37, child node: -0.2965469874017175
# iteration: 37, child node: -0.29368952397991077
# iteration: 37, child node: -0.30630493085221683
# iteration: 37, child node: -0.26576197496350096
# iteration: 37, child node: -0.2893918935983737
# iteration: 37, child node: -0.27260004871462007
# iteration: 37, child node: -0.28416132799265437
# iteration: 37, child node: -0.31267662762267856
#
# parent node: -0.31974164584280756
# iteration: 38, child node: -0.3060462883740246
# iteration: 38, child node: -0.2958646403167942
# iteration: 38, child node: -0.2987617141579619
# iteration: 38, child node: -0.30960103205012957
# iteration: 38, child node: -0.26462859343462153
# iteration: 38, child node: -0.2515447358485598
# iteration: 38, child node: -0.29036029437021726
#
# parent node: -0.3197375865174675
# iteration: 39, child node: -0.32124222323089513
# iteration: 39, child node: -0.2472385613503464
# iteration: 39, child node: -0.319503818197734
# iteration: 39, child node: -0.3148863016778375
# iteration: 39, child node: -0.3203426263101421
# iteration: 39, child node: -0.31210882699122844
# iteration: 39, child node: -0.31974352116451943
# iteration: 39, child node: -0.30057291508739076
# iteration: 39, child node: -0.3195078237472644
# iteration: 39, child node: -0.27021138277894363
#
# parent node: -0.32124222323089513
# iteration: 40, child node: -0.29022106894002747
# iteration: 40, child node: -0.3217876521708157
# iteration: 40, child node: -0.2885062925857516
# iteration: 40, child node: -0.2537715126938791
# iteration: 40, child node: -0.3182018939613291
# iteration: 40, child node: -0.316975823405807
# iteration: 40, child node: -0.2883621166023239
# iteration: 40, child node: -0.30141666670352424
# iteration: 40, child node: -0.29003253212492086
#
# parent node: -0.3217876521708157
# iteration: 41, child node: -0.24884263369969167
# iteration: 41, child node: -0.2843825142273417
# iteration: 41, child node: -0.2753975563023551
# iteration: 41, child node: -0.26406075521360867
# iteration: 41, child node: -0.25080962956852376
# iteration: 41, child node: -0.27572464210365755
# iteration: 41, child node: -0.25920471024833913
# iteration: 41, child node: -0.32127785622417504
#
# parent node: -0.32127785622417504
# iteration: 42, child node: -0.2889462156744706
# iteration: 42, child node: -0.32060191733578436
# iteration: 42, child node: -0.3204874187764537
# iteration: 42, child node: -0.2946851570641027
# iteration: 42, child node: -0.3197030832904844
# iteration: 42, child node: -0.2686259425959657
# iteration: 42, child node: -0.2827609022464135
# iteration: 42, child node: -0.28325289951002214
# iteration: 42, child node: -0.31364909669793595
# iteration: 42, child node: -0.29813796199329556
#
# parent node: -0.32060191733578436
# iteration: 43, child node: -0.2931073837570754
# iteration: 43, child node: -0.3019572884396371
# iteration: 43, child node: -0.3185614501186219
# iteration: 43, child node: -0.27365929315717374
# iteration: 43, child node: -0.29642186600550624
# iteration: 43, child node: -0.29949733558958874
# iteration: 43, child node: -0.30185579053002903
# iteration: 43, child node: -0.2911603015216017
# iteration: 43, child node: -0.31223746022587284
# iteration: 43, child node: -0.31259971988496993
#
# parent node: -0.3204874187764537
# iteration: 44, child node: -0.3189739190559925
# iteration: 44, child node: -0.29315346153952954
# iteration: 44, child node: -0.32083805788970177
# iteration: 44, child node: -0.3173173165440103
# iteration: 44, child node: -0.32065544129995616
# iteration: 44, child node: -0.275376728346832
# iteration: 44, child node: -0.3205320947323751
# iteration: 44, child node: -0.3187726964602542
# iteration: 44, child node: -0.23992294615528892
#
# parent node: -0.32083805788970177
# iteration: 45, child node: -0.3009368980101425
# iteration: 45, child node: -0.25679948030440586
# iteration: 45, child node: -0.3207073351464056
# iteration: 45, child node: -0.28771497605609303
# iteration: 45, child node: -0.25682422258412607
# iteration: 45, child node: -0.2680726417055807
# iteration: 45, child node: -0.2929403960255881
# iteration: 45, child node: -0.25262347352423054
# iteration: 45, child node: -0.2962592867051347
# iteration: 45, child node: -0.2933684502892132
#
# parent node: -0.3207073351464056

# %%
astar.best_criteria_value
# Out:
# -0.33484336531315556

# %%
astar.best_design.kmeans.score_summary_df()
# Out:
#                expected       std
# measure
# density       -0.091280  0.224392
# moran         -0.334843  0.097481
# local_balance  0.732705  1.814465
# voronoi        0.126583  0.081862

# %%
np.mean(np.abs(astar.best_design.kmeans.fips - modified_probs))
# Out:
# np.float64(4.3071099529827517e-13)

# %%
astar.best_design.kmeans.all_samples_probs.sum()
# Out:
# np.float64(0.999999999995)

# %% [markdown]
# # Run Bees

# %%
bee = gs.search.Bees(
    initial_designs,
    gs.criteria.MoranCriteria(),
    colony_size=20,
    limit=200,
)
# Out:
# Evaluating initial designs...
# ABC initialized - Best initial criteria value: -0.2537789679101993

# %%
bee.run(
    max_iterations = 1_000,

    n_clusters_to_change_order_zone = 1,
    n_changes_in_order_of_zones = 1,

    n_clusters_to_change_order_units = 1,
    n_zones_to_change_order_units = 1,
    n_changes_in_order_of_units = 1,

    n_jobs=-1,

    max_time_seconds=elapsed_astar * 100
)
# Out:
# Starting ABC with 20 food sources
# Colony size: 20, Limit: 200
#
# Iteration 1/1000
#   Best: -0.278789, Avg: -0.241094
#
# Iteration 2/1000
#   Best: -0.278789, Avg: -0.241880
#
# Iteration 3/1000
#   Best: -0.278789, Avg: -0.244117
#
# Iteration 4/1000
#   Best: -0.278789, Avg: -0.248979
#
# Iteration 5/1000
#   Best: -0.278789, Avg: -0.252294
#
# Iteration 6/1000
# ============================================================
# NEW BEST at iteration 6
# Criteria value: -0.28410084
# ============================================================
#   Best: -0.284101, Avg: -0.256115
#
# Iteration 7/1000
#   Best: -0.284101, Avg: -0.257480
#
# Iteration 8/1000
#   Best: -0.284101, Avg: -0.258527
#
# Iteration 9/1000
#   Best: -0.284101, Avg: -0.259141
#
# Iteration 10/1000
#   Best: -0.284101, Avg: -0.261690
#
# Iteration 11/1000
# ============================================================
# NEW BEST at iteration 11
# Criteria value: -0.28580093
# ============================================================
#   Best: -0.285801, Avg: -0.263104
#
# Iteration 12/1000
#   Best: -0.285801, Avg: -0.263982
#
# Iteration 13/1000
# ============================================================
# NEW BEST at iteration 13
# Criteria value: -0.30553091
# ============================================================
#   Best: -0.305531, Avg: -0.266603
#
# Iteration 14/1000
#   Best: -0.305531, Avg: -0.268802
#
# Iteration 15/1000
# ============================================================
# NEW BEST at iteration 15
# Criteria value: -0.30604603
# ============================================================
#   Best: -0.306046, Avg: -0.270323
#
# Iteration 16/1000
#   Best: -0.306046, Avg: -0.271616
#
# Iteration 17/1000
#   Best: -0.306046, Avg: -0.272407
#
# Iteration 18/1000
#   Best: -0.306046, Avg: -0.274141
#
# Iteration 19/1000
#   Best: -0.306046, Avg: -0.274722
#
# Iteration 20/1000
#   Best: -0.306046, Avg: -0.274926
#
# Iteration 21/1000
#   Best: -0.306046, Avg: -0.275046
#
# Iteration 22/1000
#   Best: -0.306046, Avg: -0.277539
#
# Iteration 23/1000
#   Best: -0.306046, Avg: -0.277627
#
# Iteration 24/1000
# ============================================================
# NEW BEST at iteration 24
# Criteria value: -0.30606303
# ============================================================
#   Best: -0.306063, Avg: -0.278114
#
# Iteration 25/1000
# ============================================================
# NEW BEST at iteration 25
# Criteria value: -0.30976733
# ============================================================
#   Best: -0.309767, Avg: -0.278440
#
# Iteration 26/1000
#   Best: -0.309767, Avg: -0.279191
#
# Iteration 27/1000
# ============================================================
# NEW BEST at iteration 27
# Criteria value: -0.31405104
# ============================================================
#   Best: -0.314051, Avg: -0.280230
#
# Iteration 28/1000
#   Best: -0.314051, Avg: -0.280628
#
# Iteration 29/1000
# ============================================================
# NEW BEST at iteration 29
# Criteria value: -0.31429038
# ============================================================
#   Best: -0.314290, Avg: -0.281583
#
# Iteration 30/1000
#   Best: -0.314290, Avg: -0.283188
#
# Iteration 31/1000
# ============================================================
# NEW BEST at iteration 31
# Criteria value: -0.32147319
# ============================================================
#   Best: -0.321473, Avg: -0.283635
#
# Iteration 32/1000
#   Best: -0.321473, Avg: -0.285047
#
# Iteration 33/1000
#   Best: -0.321473, Avg: -0.285075
#
# Iteration 34/1000
# ============================================================
# NEW BEST at iteration 34
# Criteria value: -0.32267282
# ============================================================
#   Best: -0.322673, Avg: -0.285453
#
# Iteration 35/1000
#   Best: -0.322673, Avg: -0.286071
#
# Iteration 36/1000
#   Best: -0.322673, Avg: -0.287211
#
# Iteration 37/1000
# ============================================================
# NEW BEST at iteration 37
# Criteria value: -0.32389921
# ============================================================
#   Best: -0.323899, Avg: -0.287385
#
# Iteration 38/1000
#   Best: -0.323899, Avg: -0.287966
#
# Iteration 39/1000
#   Best: -0.323899, Avg: -0.289166
#
# Iteration 40/1000
# ============================================================
# NEW BEST at iteration 40
# Criteria value: -0.32418539
# ============================================================
#   Best: -0.324185, Avg: -0.289209
#
# Iteration 41/1000
#   Best: -0.324185, Avg: -0.289973
#
# Iteration 42/1000
#   Best: -0.324185, Avg: -0.293072
#
# Iteration 43/1000
#   Best: -0.324185, Avg: -0.294243
#
# Iteration 44/1000
#   Best: -0.324185, Avg: -0.294550
#
# Iteration 45/1000
#   Best: -0.324185, Avg: -0.294925
#
# Iteration 46/1000
#   Best: -0.324185, Avg: -0.295317
#
# Iteration 47/1000
#   Best: -0.324185, Avg: -0.295607
#
# Iteration 48/1000
#   Best: -0.324185, Avg: -0.295972
#
# Iteration 49/1000
#   Best: -0.324185, Avg: -0.296229
#
# Iteration 50/1000
#   Best: -0.324185, Avg: -0.296469
#
# Iteration 51/1000
#   Best: -0.324185, Avg: -0.296964
#
# Iteration 52/1000
#   Best: -0.324185, Avg: -0.297742
#
# Iteration 53/1000
#   Best: -0.324185, Avg: -0.297742
#
# Iteration 54/1000
#   Best: -0.324185, Avg: -0.297861
#
# Iteration 55/1000
#   Best: -0.324185, Avg: -0.297910
#
# Iteration 56/1000
#   Best: -0.324185, Avg: -0.298363
#
# Iteration 57/1000
#   Best: -0.324185, Avg: -0.298428
#
# Iteration 58/1000
# ============================================================
# NEW BEST at iteration 58
# Criteria value: -0.32584440
# ============================================================
#   Best: -0.325844, Avg: -0.298605
#
# Iteration 59/1000
#   Best: -0.325844, Avg: -0.298670
#
# Iteration 60/1000
# ============================================================
# NEW BEST at iteration 60
# Criteria value: -0.32670058
# ============================================================
#   Best: -0.326701, Avg: -0.298733
#
# Iteration 61/1000
#   Best: -0.326701, Avg: -0.298836
#
# Iteration 62/1000
#   Best: -0.326701, Avg: -0.298967
#
# Iteration 63/1000
#   Best: -0.326701, Avg: -0.300120
#
# Iteration 64/1000
#   Best: -0.326701, Avg: -0.300165
#
# Iteration 65/1000
#   Best: -0.326701, Avg: -0.300897
#
# Iteration 66/1000
#   Best: -0.326701, Avg: -0.301073
#
# Iteration 67/1000
# ============================================================
# NEW BEST at iteration 67
# Criteria value: -0.32672988
# ============================================================
#   Best: -0.326730, Avg: -0.301248
#
# Iteration 68/1000
# ============================================================
# NEW BEST at iteration 68
# Criteria value: -0.32697678
# ============================================================
#   Best: -0.326977, Avg: -0.301260
#
# Iteration 69/1000
#   Best: -0.326977, Avg: -0.302334
#
# Iteration 70/1000
#   Best: -0.326977, Avg: -0.302508
#
# Iteration 71/1000
#   Best: -0.326977, Avg: -0.303468
#
# Iteration 72/1000
#   Best: -0.326977, Avg: -0.304082
#
# Iteration 73/1000
#   Best: -0.326977, Avg: -0.304264
#
# Iteration 74/1000
#   Best: -0.326977, Avg: -0.304305
#
# Iteration 75/1000
#   Best: -0.326977, Avg: -0.304974
#
# Iteration 76/1000
#   Best: -0.326977, Avg: -0.305113
#
# Iteration 77/1000
#   Best: -0.326977, Avg: -0.305113
#
# Iteration 78/1000
#   Best: -0.326977, Avg: -0.305211
#
# Iteration 79/1000
# ============================================================
# NEW BEST at iteration 79
# Criteria value: -0.32804792
# ============================================================
#   Best: -0.328048, Avg: -0.305606
#
# Iteration 80/1000
#   Best: -0.328048, Avg: -0.305809
#
# Iteration 81/1000
#   Best: -0.328048, Avg: -0.306103
#
# Iteration 82/1000
#   Best: -0.328048, Avg: -0.306139
#
# Iteration 83/1000
#   Best: -0.328048, Avg: -0.306139
#
# Iteration 84/1000
#   Best: -0.328048, Avg: -0.306161
#
# Iteration 85/1000
# ============================================================
# NEW BEST at iteration 85
# Criteria value: -0.32814059
# ============================================================
#   Best: -0.328141, Avg: -0.306213
#
# Iteration 86/1000
#   Best: -0.328141, Avg: -0.306288
#
# Iteration 87/1000
# ============================================================
# NEW BEST at iteration 87
# Criteria value: -0.32862570
# ============================================================
#   Best: -0.328626, Avg: -0.306341
#
# Iteration 88/1000
#   Best: -0.328626, Avg: -0.306343
#
# Iteration 89/1000
#   Best: -0.328626, Avg: -0.306504
#
# Iteration 90/1000
#   Best: -0.328626, Avg: -0.306651
#
# Iteration 91/1000
#   Best: -0.328626, Avg: -0.306829
#
# Iteration 92/1000
# ============================================================
# NEW BEST at iteration 92
# Criteria value: -0.32873001
# ============================================================
#   Best: -0.328730, Avg: -0.307189
#
# Iteration 93/1000
#   Best: -0.328730, Avg: -0.307228
#
# Iteration 94/1000
#   Best: -0.328730, Avg: -0.307231
#
# Iteration 95/1000
#   Best: -0.328730, Avg: -0.307355
#
# Iteration 96/1000
#   Best: -0.328730, Avg: -0.307435
#
# Iteration 97/1000
# ============================================================
# NEW BEST at iteration 97
# Criteria value: -0.33019808
# ============================================================
#   Best: -0.330198, Avg: -0.307543
#
# Iteration 98/1000
#   Best: -0.330198, Avg: -0.307565
#
# Iteration 99/1000
#   Best: -0.330198, Avg: -0.307620
#
# Iteration 100/1000
#   Best: -0.330198, Avg: -0.307800
#
# Iteration 101/1000
#   Best: -0.330198, Avg: -0.307884
#
# Iteration 102/1000
#   Best: -0.330198, Avg: -0.307888
#
# Iteration 103/1000
#   Best: -0.330198, Avg: -0.307889
#
# Iteration 104/1000
#   Best: -0.330198, Avg: -0.307914
#
# Iteration 105/1000
#   Best: -0.330198, Avg: -0.308203
#
# Iteration 106/1000
#   Best: -0.330198, Avg: -0.308259
#
# Iteration 107/1000
#   Best: -0.330198, Avg: -0.308492
#
# Iteration 108/1000
#   Best: -0.330198, Avg: -0.308666
#
# Iteration 109/1000
# ============================================================
# NEW BEST at iteration 109
# Criteria value: -0.33255755
# ============================================================
#   Best: -0.332558, Avg: -0.308803
#
# Iteration 110/1000
#   Best: -0.332558, Avg: -0.308803
#
# Iteration 111/1000
#   Best: -0.332558, Avg: -0.308854
#
# Iteration 112/1000
#   Best: -0.332558, Avg: -0.308874
#
# Iteration 113/1000
#   Best: -0.332558, Avg: -0.308884
#
# Iteration 114/1000
#   Best: -0.332558, Avg: -0.308885
#
# Iteration 115/1000
#   Best: -0.332558, Avg: -0.309068
#
# Iteration 116/1000
#   Best: -0.332558, Avg: -0.309094
#
# Iteration 117/1000
#   Best: -0.332558, Avg: -0.309239
#
# Iteration 118/1000
#   Best: -0.332558, Avg: -0.309239
#
# Iteration 119/1000
#   Best: -0.332558, Avg: -0.309244
#
# Iteration 120/1000
#   Best: -0.332558, Avg: -0.309377
#
# Iteration 121/1000
#   Best: -0.332558, Avg: -0.309377
#
# Iteration 122/1000
#   Best: -0.332558, Avg: -0.309563
#
# Iteration 123/1000
#   Best: -0.332558, Avg: -0.309728
#
# Iteration 124/1000
#   Best: -0.332558, Avg: -0.309774
#
# Iteration 125/1000
# ============================================================
# NEW BEST at iteration 125
# Criteria value: -0.33402963
# ============================================================
#   Best: -0.334030, Avg: -0.309848
#
# Iteration 126/1000
#   Best: -0.334030, Avg: -0.309859
#
# Iteration 127/1000
#   Best: -0.334030, Avg: -0.309881
#
# Iteration 128/1000
#   Best: -0.334030, Avg: -0.309923
#
# Iteration 129/1000
#   Best: -0.334030, Avg: -0.309952
#
# Iteration 130/1000
#   Best: -0.334030, Avg: -0.309978
#
# Iteration 131/1000
#   Best: -0.334030, Avg: -0.309987
#
# Iteration 132/1000
#   Best: -0.334030, Avg: -0.310020
#
# Iteration 133/1000
#   Best: -0.334030, Avg: -0.310143
#
# Iteration 134/1000
#   Best: -0.334030, Avg: -0.310143
#
# Iteration 135/1000
#   Best: -0.334030, Avg: -0.310224
#
# Iteration 136/1000
#   Best: -0.334030, Avg: -0.310325
#
# Iteration 137/1000
#   Best: -0.334030, Avg: -0.310469
#
# Iteration 138/1000
#   Best: -0.334030, Avg: -0.310754
#
# Iteration 139/1000
#   Best: -0.334030, Avg: -0.310900
#
# Iteration 140/1000
#   Best: -0.334030, Avg: -0.310933
#
# Iteration 141/1000
#   Best: -0.334030, Avg: -0.310960
#
# Iteration 142/1000
#   Best: -0.334030, Avg: -0.310960
#
# Iteration 143/1000
#   Best: -0.334030, Avg: -0.310960
#
# Iteration 144/1000
#   Best: -0.334030, Avg: -0.310960
#
# Iteration 145/1000
#   Best: -0.334030, Avg: -0.311134
#
# Iteration 146/1000
#   Best: -0.334030, Avg: -0.311245
#
# Iteration 147/1000
#   Best: -0.334030, Avg: -0.311250
#
# Iteration 148/1000
#   Best: -0.334030, Avg: -0.311397
#
# Iteration 149/1000
#   Best: -0.334030, Avg: -0.311535
#
# Iteration 150/1000
#   Best: -0.334030, Avg: -0.311557
#
# Iteration 151/1000
#   Best: -0.334030, Avg: -0.311557
#
# Iteration 152/1000
# ============================================================
# NEW BEST at iteration 152
# Criteria value: -0.33404574
# ============================================================
#   Best: -0.334046, Avg: -0.311558
#
# Iteration 153/1000
# ============================================================
# NEW BEST at iteration 153
# Criteria value: -0.33475104
# ============================================================
#   Best: -0.334751, Avg: -0.311662
#
# Iteration 154/1000
#   Best: -0.334751, Avg: -0.311687
#
# Iteration 155/1000
#   Best: -0.334751, Avg: -0.311687
#
# Iteration 156/1000
#   Best: -0.334751, Avg: -0.311694
#
# Iteration 157/1000
# ============================================================
# NEW BEST at iteration 157
# Criteria value: -0.33479210
# ============================================================
#   Best: -0.334792, Avg: -0.311722
#
# Iteration 158/1000
#   Best: -0.334792, Avg: -0.311722
#
# Iteration 159/1000
#   Best: -0.334792, Avg: -0.311722
#
# Iteration 160/1000
#   Best: -0.334792, Avg: -0.311736
#
# Iteration 161/1000
#   Best: -0.334792, Avg: -0.311787
#
# Iteration 162/1000
#   Best: -0.334792, Avg: -0.311820
#
# Iteration 163/1000
#   Best: -0.334792, Avg: -0.311903
#
# Iteration 164/1000
#   Best: -0.334792, Avg: -0.311936
#
# Iteration 165/1000
#   Best: -0.334792, Avg: -0.312095
#
# Iteration 166/1000
#   Best: -0.334792, Avg: -0.312095
#
# Iteration 167/1000
#   Best: -0.334792, Avg: -0.312191
#
# Iteration 168/1000
#   Best: -0.334792, Avg: -0.312275
#
# Iteration 169/1000
#   Best: -0.334792, Avg: -0.312300
#
# Iteration 170/1000
# ============================================================
# NEW BEST at iteration 170
# Criteria value: -0.33637129
# ============================================================
#   Best: -0.336371, Avg: -0.312462
#
# Iteration 171/1000
# ============================================================
# NEW BEST at iteration 171
# Criteria value: -0.33657986
# ============================================================
#   Best: -0.336580, Avg: -0.312689
#
# Iteration 172/1000
#   Best: -0.336580, Avg: -0.312904
#
# Iteration 173/1000
#   Best: -0.336580, Avg: -0.313023
#
# Iteration 174/1000
#   Best: -0.336580, Avg: -0.313092
#
# Iteration 175/1000
#   Best: -0.336580, Avg: -0.313092
#
# Iteration 176/1000
#   Best: -0.336580, Avg: -0.313092
#
# Iteration 177/1000
#   Best: -0.336580, Avg: -0.313093
#
# Iteration 178/1000
#   Best: -0.336580, Avg: -0.313200
#
# Iteration 179/1000
#   Best: -0.336580, Avg: -0.313241
#
# Iteration 180/1000
#   Best: -0.336580, Avg: -0.313241
#
# Iteration 181/1000
#   Best: -0.336580, Avg: -0.313245
#
# Iteration 182/1000
#   Best: -0.336580, Avg: -0.313253
#
# Iteration 183/1000
#   Best: -0.336580, Avg: -0.313367
#
# Iteration 184/1000
#   Best: -0.336580, Avg: -0.313440
#
# Iteration 185/1000
#   Best: -0.336580, Avg: -0.313455
#
# Iteration 186/1000
#   Best: -0.336580, Avg: -0.313534
#
# Iteration 187/1000
#   Best: -0.336580, Avg: -0.313690
#
# Iteration 188/1000
# ============================================================
# NEW BEST at iteration 188
# Criteria value: -0.33682644
# ============================================================
#   Best: -0.336826, Avg: -0.313828
#
# Iteration 189/1000
#   Best: -0.336826, Avg: -0.313829
#
# Iteration 190/1000
#   Best: -0.336826, Avg: -0.313908
#
# Iteration 191/1000
#   Best: -0.336826, Avg: -0.314074
#
# Iteration 192/1000
#   Best: -0.336826, Avg: -0.314074
#
# Iteration 193/1000
#   Best: -0.336826, Avg: -0.314186
#
# Iteration 194/1000
#   Best: -0.336826, Avg: -0.314186
#
# Iteration 195/1000
#   Best: -0.336826, Avg: -0.314302
#
# Iteration 196/1000
#   Best: -0.336826, Avg: -0.314302
#
# Iteration 197/1000
#   Best: -0.336826, Avg: -0.314308
#
# Iteration 198/1000
#   Best: -0.336826, Avg: -0.314327
#
# Iteration 199/1000
#   Best: -0.336826, Avg: -0.314344
#
# Iteration 200/1000
#   Best: -0.336826, Avg: -0.314344
#
# Iteration 201/1000
#   Best: -0.336826, Avg: -0.314344
#
# Iteration 202/1000
#   Best: -0.336826, Avg: -0.314349
#
# Iteration 203/1000
#   Best: -0.336826, Avg: -0.314384
#
# Iteration 204/1000
#   Best: -0.336826, Avg: -0.314453
#
# Iteration 205/1000
#   Best: -0.336826, Avg: -0.314496
#
# Iteration 206/1000
#   Best: -0.336826, Avg: -0.314501
#
# Iteration 207/1000
#   Best: -0.336826, Avg: -0.314520
#
# Iteration 208/1000
#   Best: -0.336826, Avg: -0.314535
#
# Iteration 209/1000
#   Best: -0.336826, Avg: -0.314535
#
# Iteration 210/1000
#   Best: -0.336826, Avg: -0.314611
#
# Iteration 211/1000
#   Best: -0.336826, Avg: -0.314756
#
# Iteration 212/1000
#   Best: -0.336826, Avg: -0.314756
#
# Iteration 213/1000
#   Best: -0.336826, Avg: -0.314756
#
# Iteration 214/1000
#   Best: -0.336826, Avg: -0.314771
#
# Iteration 215/1000
#   Best: -0.336826, Avg: -0.314782
#
# Iteration 216/1000
# ============================================================
# NEW BEST at iteration 216
# Criteria value: -0.33688351
# ============================================================
#   Best: -0.336884, Avg: -0.314814
#
# Iteration 217/1000
#   Best: -0.336884, Avg: -0.314851
#
# Iteration 218/1000
#   Best: -0.336884, Avg: -0.314851
#
# Iteration 219/1000
#   Best: -0.336884, Avg: -0.314851
#
# Iteration 220/1000
#   Best: -0.336884, Avg: -0.314883
#
# Iteration 221/1000
#   Best: -0.336884, Avg: -0.314945
#
# Iteration 222/1000
#   Best: -0.336884, Avg: -0.314950
#
# Iteration 223/1000
#   Best: -0.336884, Avg: -0.314992
#
# Iteration 224/1000
#   Best: -0.336884, Avg: -0.314996
#
# Iteration 225/1000
#   Best: -0.336884, Avg: -0.315037
#
# Iteration 226/1000
#   Best: -0.336884, Avg: -0.315107
#
# Iteration 227/1000
#   Best: -0.336884, Avg: -0.315240
#
# Iteration 228/1000
#   Best: -0.336884, Avg: -0.315248
#
# Iteration 229/1000
# ============================================================
# NEW BEST at iteration 229
# Criteria value: -0.33729740
# ============================================================
#   Best: -0.337297, Avg: -0.315274
#
# Iteration 230/1000
#   Best: -0.337297, Avg: -0.315274
#
# Iteration 231/1000
#   Best: -0.337297, Avg: -0.315329
#
# Iteration 232/1000
#   Best: -0.337297, Avg: -0.315458
#
# Iteration 233/1000
#   Best: -0.337297, Avg: -0.315598
#
# Iteration 234/1000
#   Best: -0.337297, Avg: -0.315598
#
# Iteration 235/1000
#   Best: -0.337297, Avg: -0.315620
#
# Iteration 236/1000
#   Best: -0.337297, Avg: -0.315620
#
# Iteration 237/1000
#   Best: -0.337297, Avg: -0.315680
#
# Iteration 238/1000
#   Best: -0.337297, Avg: -0.315811
#
# Iteration 239/1000
#   Best: -0.337297, Avg: -0.315883
#
# Iteration 240/1000
#   Best: -0.337297, Avg: -0.315942
#
# Iteration 241/1000
#   Best: -0.337297, Avg: -0.316071
#
# Iteration 242/1000
#   Best: -0.337297, Avg: -0.316078
#
# Iteration 243/1000
#   Best: -0.337297, Avg: -0.316100
#
# Iteration 244/1000
#   Best: -0.337297, Avg: -0.316101
#
# Iteration 245/1000
#   Best: -0.337297, Avg: -0.316101
#
# Iteration 246/1000
#   Best: -0.337297, Avg: -0.316101
#
# Iteration 247/1000
#   Best: -0.337297, Avg: -0.316101
#
# Iteration 248/1000
#   Best: -0.337297, Avg: -0.316109
#
# Iteration 249/1000
#   Best: -0.337297, Avg: -0.316187
#
# Iteration 250/1000
#   Best: -0.337297, Avg: -0.316188
#
# Iteration 251/1000
#   Best: -0.337297, Avg: -0.316188
#
# Iteration 252/1000
#   Best: -0.337297, Avg: -0.316194
#
# Iteration 253/1000
# ============================================================
# NEW BEST at iteration 253
# Criteria value: -0.33732972
# ============================================================
#   Best: -0.337330, Avg: -0.316195
#
# Iteration 254/1000
#   Best: -0.337330, Avg: -0.316195
#
# Iteration 255/1000
#   Best: -0.337330, Avg: -0.316216
#
# Iteration 256/1000
#   Best: -0.337330, Avg: -0.316216
#
# Iteration 257/1000
#   Best: -0.337330, Avg: -0.316258
#
# Iteration 258/1000
#   Best: -0.337330, Avg: -0.316306
#
# Iteration 259/1000
#   Best: -0.337330, Avg: -0.316419
#
# Iteration 260/1000
#   Best: -0.337330, Avg: -0.316419
#
# Iteration 261/1000
#   Best: -0.337330, Avg: -0.316419
#
# Iteration 262/1000
#   Best: -0.337330, Avg: -0.316448
#
# Iteration 263/1000
#   Best: -0.337330, Avg: -0.316511
#
# Iteration 264/1000
#   Best: -0.337330, Avg: -0.316511
#
# Iteration 265/1000
#   Best: -0.337330, Avg: -0.316511
#
# Iteration 266/1000
#   Best: -0.337330, Avg: -0.316511
#
# Iteration 267/1000
#   Best: -0.337330, Avg: -0.316514
#
# Iteration 268/1000
#   Best: -0.337330, Avg: -0.316749
#
# Iteration 269/1000
#   Best: -0.337330, Avg: -0.316948
#
# Iteration 270/1000
#   Best: -0.337330, Avg: -0.316987
#
# Iteration 271/1000
#   Best: -0.337330, Avg: -0.316997
#
# Iteration 272/1000
# ============================================================
# NEW BEST at iteration 272
# Criteria value: -0.33818013
# ============================================================
#   Best: -0.338180, Avg: -0.317078
#
# Iteration 273/1000
#   Best: -0.338180, Avg: -0.317656
#
# Iteration 274/1000
#   Best: -0.338180, Avg: -0.317736
#
# Iteration 275/1000
#   Best: -0.338180, Avg: -0.317739
#
# Iteration 276/1000
#   Best: -0.338180, Avg: -0.317753
#
# Iteration 277/1000
#   Best: -0.338180, Avg: -0.317753
#
# Iteration 278/1000
#   Best: -0.338180, Avg: -0.317765
#
# Iteration 279/1000
#   Best: -0.338180, Avg: -0.317770
#
# Iteration 280/1000
#   Best: -0.338180, Avg: -0.317788
#
# Iteration 281/1000
#   Best: -0.338180, Avg: -0.317829
#
# Iteration 282/1000
#   Best: -0.338180, Avg: -0.317871
#
# Iteration 283/1000
#   Best: -0.338180, Avg: -0.317875
#
# Iteration 284/1000
#   Best: -0.338180, Avg: -0.317914
#
# Iteration 285/1000
#   Best: -0.338180, Avg: -0.317914
#
# Iteration 286/1000
#   Best: -0.338180, Avg: -0.317914
#
# Iteration 287/1000
#   Best: -0.338180, Avg: -0.317914
#
# Iteration 288/1000
#   Best: -0.338180, Avg: -0.317914
#
# Iteration 289/1000
# ============================================================
# NEW BEST at iteration 289
# Criteria value: -0.33919630
# ============================================================
#   Best: -0.339196, Avg: -0.317969
#
# Iteration 290/1000
#   Best: -0.339196, Avg: -0.317972
#
# Iteration 291/1000
#   Best: -0.339196, Avg: -0.317972
#
# Iteration 292/1000
#   Best: -0.339196, Avg: -0.317972
#
# Iteration 293/1000
#   Best: -0.339196, Avg: -0.317990
#
# Iteration 294/1000
#   Best: -0.339196, Avg: -0.318001
#
# Iteration 295/1000
#   Best: -0.339196, Avg: -0.318001
#
# Iteration 296/1000
#   Best: -0.339196, Avg: -0.318002
#
# Iteration 297/1000
#   Best: -0.339196, Avg: -0.318003
#
# Iteration 298/1000
#   Best: -0.339196, Avg: -0.318003
#
# Iteration 299/1000
#   Best: -0.339196, Avg: -0.318003
#
# Iteration 300/1000
#   Best: -0.339196, Avg: -0.318003
#
# Iteration 301/1000
#   Best: -0.339196, Avg: -0.318055
#
# Iteration 302/1000
#   Best: -0.339196, Avg: -0.318055
#
# Iteration 303/1000
#   Best: -0.339196, Avg: -0.318082
#
# Iteration 304/1000
#   Best: -0.339196, Avg: -0.318134
#
# Iteration 305/1000
#   Best: -0.339196, Avg: -0.318147
#
# Iteration 306/1000
#   Best: -0.339196, Avg: -0.318178
#
# Iteration 307/1000
#   Best: -0.339196, Avg: -0.318181
#
# Iteration 308/1000
#   Best: -0.339196, Avg: -0.318181
#
# Iteration 309/1000
# ============================================================
# NEW BEST at iteration 309
# Criteria value: -0.33926327
# ============================================================
#   Best: -0.339263, Avg: -0.318190
#
# Iteration 310/1000
#   Best: -0.339263, Avg: -0.318202
#
# Iteration 311/1000
#   Best: -0.339263, Avg: -0.318202
#
# Iteration 312/1000
#   Best: -0.339263, Avg: -0.318202
#
# Iteration 313/1000
#   Best: -0.339263, Avg: -0.318202
#
# Iteration 314/1000
#   Best: -0.339263, Avg: -0.318211
#
# Iteration 315/1000
#   Best: -0.339263, Avg: -0.318357
#
# Iteration 316/1000
#   Best: -0.339263, Avg: -0.318473
#
# Iteration 317/1000
#   Best: -0.339263, Avg: -0.318530
#
# Iteration 318/1000
#   Best: -0.339263, Avg: -0.318530
#
# Iteration 319/1000
#   Best: -0.339263, Avg: -0.318654
#
# Iteration 320/1000
#   Best: -0.339263, Avg: -0.318751
#
# Iteration 321/1000
#   Best: -0.339263, Avg: -0.318751
#
# Iteration 322/1000
#   Best: -0.339263, Avg: -0.318751
#
# Iteration 323/1000
#   Best: -0.339263, Avg: -0.318751
#
# Iteration 324/1000
#   Best: -0.339263, Avg: -0.318753
#
# Iteration 325/1000
#   Best: -0.339263, Avg: -0.318753
#
# Iteration 326/1000
#   Best: -0.339263, Avg: -0.318800
#
# Iteration 327/1000
#   Best: -0.339263, Avg: -0.318800
#
# Iteration 328/1000
#   Best: -0.339263, Avg: -0.319195
#
# Iteration 329/1000
#   Best: -0.339263, Avg: -0.319236
#
# Iteration 330/1000
# ============================================================
# NEW BEST at iteration 330
# Criteria value: -0.34098982
# ============================================================
#   Best: -0.340990, Avg: -0.319323
#
# Iteration 331/1000
#   Best: -0.340990, Avg: -0.319323
#
# Iteration 332/1000
#   Best: -0.340990, Avg: -0.319337
#
# Iteration 333/1000
#   Best: -0.340990, Avg: -0.319351
#
# Iteration 334/1000
#   Best: -0.340990, Avg: -0.319351
#
# Iteration 335/1000
#   Best: -0.340990, Avg: -0.319351
#
# Iteration 336/1000
#   Best: -0.340990, Avg: -0.319351
#
# Iteration 337/1000
#   Best: -0.340990, Avg: -0.319351
#
# Iteration 338/1000
#   Best: -0.340990, Avg: -0.319351
#
# Iteration 339/1000
#   Best: -0.340990, Avg: -0.319434
#
# Iteration 340/1000
#   Best: -0.340990, Avg: -0.319494
#
# Iteration 341/1000
#   Best: -0.340990, Avg: -0.319499
#
# Iteration 342/1000
#   Best: -0.340990, Avg: -0.319511
#
# Iteration 343/1000
#   Best: -0.340990, Avg: -0.319558
#
# Iteration 344/1000
#   Best: -0.340990, Avg: -0.319573
#
# Iteration 345/1000
#   Best: -0.340990, Avg: -0.319573
#
# Iteration 346/1000
#   Best: -0.340990, Avg: -0.319573
#
# Iteration 347/1000
# ============================================================
# NEW BEST at iteration 347
# Criteria value: -0.34131429
# ============================================================
#   Best: -0.341314, Avg: -0.319589
#
# Iteration 348/1000
#   Best: -0.341314, Avg: -0.319589
#
# Iteration 349/1000
#   Best: -0.341314, Avg: -0.319600
#
# Iteration 350/1000
#   Best: -0.341314, Avg: -0.319613
#
# Iteration 351/1000
#   Best: -0.341314, Avg: -0.319618
#
# Iteration 352/1000
#   Best: -0.341314, Avg: -0.319618
#
# Iteration 353/1000
#   Best: -0.341314, Avg: -0.319646
#
# Iteration 354/1000
#   Best: -0.341314, Avg: -0.319651
#
# Iteration 355/1000
#   Best: -0.341314, Avg: -0.319716
#
# Iteration 356/1000
#   Best: -0.341314, Avg: -0.319742
#
# Iteration 357/1000
#   Best: -0.341314, Avg: -0.319742
#
# Iteration 358/1000
#   Best: -0.341314, Avg: -0.319742
#
# Iteration 359/1000
#   Best: -0.341314, Avg: -0.319762
#
# Iteration 360/1000
# ============================================================
# NEW BEST at iteration 360
# Criteria value: -0.34209366
# ============================================================
#   Best: -0.342094, Avg: -0.319801
#
# Iteration 361/1000
#   Best: -0.342094, Avg: -0.319896
#
# Iteration 362/1000
#   Best: -0.342094, Avg: -0.319896
#
# Iteration 363/1000
#   Best: -0.342094, Avg: -0.319907
#
# Iteration 364/1000
# ============================================================
# NEW BEST at iteration 364
# Criteria value: -0.34322036
# ============================================================
#   Best: -0.343220, Avg: -0.319964
#
# Iteration 365/1000
#   Best: -0.343220, Avg: -0.320007
#
# Iteration 366/1000
#   Best: -0.343220, Avg: -0.320007
#
# Iteration 367/1000
#   Best: -0.343220, Avg: -0.320035
#
# Iteration 368/1000
# ============================================================
# NEW BEST at iteration 368
# Criteria value: -0.34333084
# ============================================================
#   Best: -0.343331, Avg: -0.320089
#
# Iteration 369/1000
#   Best: -0.343331, Avg: -0.320118
#
# Iteration 370/1000
#   Best: -0.343331, Avg: -0.320153
#
# Iteration 371/1000
#   Best: -0.343331, Avg: -0.320153
#
# Iteration 372/1000
#   Best: -0.343331, Avg: -0.320241
#
# Iteration 373/1000
#   Best: -0.343331, Avg: -0.320256
#
# Iteration 374/1000
# ============================================================
# NEW BEST at iteration 374
# Criteria value: -0.34337491
# ============================================================
#   Best: -0.343375, Avg: -0.320266
#
# Iteration 375/1000
#   Best: -0.343375, Avg: -0.320268
#
# Iteration 376/1000
#   Best: -0.343375, Avg: -0.320268
#
# Iteration 377/1000
#   Best: -0.343375, Avg: -0.320270
#
# Iteration 378/1000
#   Best: -0.343375, Avg: -0.320272
#
# Iteration 379/1000
#   Best: -0.343375, Avg: -0.320335
#
# Iteration 380/1000
#   Best: -0.343375, Avg: -0.320375
#
# Iteration 381/1000
#   Best: -0.343375, Avg: -0.320375
#
# Iteration 382/1000
#   Best: -0.343375, Avg: -0.320375
#
# Iteration 383/1000
#   Best: -0.343375, Avg: -0.320429
#
# Iteration 384/1000
#   Best: -0.343375, Avg: -0.320444
#
# Iteration 385/1000
#   Best: -0.343375, Avg: -0.320444
#
# Iteration 386/1000
#   Best: -0.343375, Avg: -0.320444
#
# Iteration 387/1000
# ============================================================
# NEW BEST at iteration 387
# Criteria value: -0.34359669
# ============================================================
#   Best: -0.343597, Avg: -0.320455
#
# Iteration 388/1000
#   Best: -0.343597, Avg: -0.320455
#
# Iteration 389/1000
#   Best: -0.343597, Avg: -0.320455
#
# Iteration 390/1000
#   Best: -0.343597, Avg: -0.320455
#
# Iteration 391/1000
#   Best: -0.343597, Avg: -0.320503
#
# Iteration 392/1000
#   Best: -0.343597, Avg: -0.320553
#
# Iteration 393/1000
#   Best: -0.343597, Avg: -0.320615
#
# Iteration 394/1000
#   Best: -0.343597, Avg: -0.320661
#
# Iteration 395/1000
#   Best: -0.343597, Avg: -0.320663
#
# Iteration 396/1000
#   Best: -0.343597, Avg: -0.320663
#
# Iteration 397/1000
#   Best: -0.343597, Avg: -0.320663
#
# Iteration 398/1000
#   Best: -0.343597, Avg: -0.320663
#
# Iteration 399/1000
#   Best: -0.343597, Avg: -0.320663
#
# Iteration 400/1000
#   Best: -0.343597, Avg: -0.320778
#
# Iteration 401/1000
#   Best: -0.343597, Avg: -0.320778
#
# Iteration 402/1000
#   Best: -0.343597, Avg: -0.320778
#
# Iteration 403/1000
#   Best: -0.343597, Avg: -0.320778
#
# Iteration 404/1000
#   Best: -0.343597, Avg: -0.320778
#
# Iteration 405/1000
#   Best: -0.343597, Avg: -0.320900
#
# Iteration 406/1000
#   Best: -0.343597, Avg: -0.320917
#
# Iteration 407/1000
#   Best: -0.343597, Avg: -0.320917
#
# Iteration 408/1000
#   Best: -0.343597, Avg: -0.320919
#
# Iteration 409/1000
#   Best: -0.343597, Avg: -0.320971
#
# Iteration 410/1000
#   Best: -0.343597, Avg: -0.320971
#
# Iteration 411/1000
#   Best: -0.343597, Avg: -0.320971
#
# Iteration 412/1000
#   Best: -0.343597, Avg: -0.320971
#
# Iteration 413/1000
#   Best: -0.343597, Avg: -0.320971
#
# Iteration 414/1000
#   Best: -0.343597, Avg: -0.320971
#
# Iteration 415/1000
#   Best: -0.343597, Avg: -0.320971
#
# Iteration 416/1000
#   Best: -0.343597, Avg: -0.320971
#
# Iteration 417/1000
#   Best: -0.343597, Avg: -0.320997
#
# Iteration 418/1000
#   Best: -0.343597, Avg: -0.321085
#
# Iteration 419/1000
#   Best: -0.343597, Avg: -0.321119
#
# Iteration 420/1000
#   Best: -0.343597, Avg: -0.321119
#
# Iteration 421/1000
#   Best: -0.343597, Avg: -0.321137
#
# Iteration 422/1000
#   Best: -0.343597, Avg: -0.321137
#
# Iteration 423/1000
# ============================================================
# NEW BEST at iteration 423
# Criteria value: -0.34360351
# ============================================================
#   Best: -0.343604, Avg: -0.321153
#
# Iteration 424/1000
#   Best: -0.343604, Avg: -0.321153
#
# Iteration 425/1000
#   Best: -0.343604, Avg: -0.321153
#
# Iteration 426/1000
#   Best: -0.343604, Avg: -0.321257
#
# Iteration 427/1000
#   Best: -0.343604, Avg: -0.321260
#
# Iteration 428/1000
#   Best: -0.343604, Avg: -0.321260
#
# Iteration 429/1000
#   Best: -0.343604, Avg: -0.321260
#
# Iteration 430/1000
#   Best: -0.343604, Avg: -0.321260
#
# Iteration 431/1000
#   Best: -0.343604, Avg: -0.321262
#
# Iteration 432/1000
#   Best: -0.343604, Avg: -0.321262
#
# Iteration 433/1000
#   Best: -0.343604, Avg: -0.321269
#
# Iteration 434/1000
#   Best: -0.343604, Avg: -0.321272
#
# Iteration 435/1000
#   Scout: Abandoned and found new source with criteria -0.207179
#   Best: -0.343604, Avg: -0.315125
#
# Iteration 436/1000
#   Best: -0.343604, Avg: -0.315127
#
# Iteration 437/1000
#   Best: -0.343604, Avg: -0.316139
#
# Iteration 438/1000
#   Best: -0.343604, Avg: -0.316145
#
# Iteration 439/1000
#   Best: -0.343604, Avg: -0.316518
#
# Iteration 440/1000
#   Best: -0.343604, Avg: -0.316518
#
# Iteration 441/1000
#   Best: -0.343604, Avg: -0.316522
#
# Iteration 442/1000
#   Best: -0.343604, Avg: -0.316522
#
# Iteration 443/1000
#   Best: -0.343604, Avg: -0.317456
#
# Iteration 444/1000
#   Best: -0.343604, Avg: -0.317456
#
# Iteration 445/1000
#   Best: -0.343604, Avg: -0.317519
#
# Iteration 446/1000
#   Best: -0.343604, Avg: -0.317522
#
# Iteration 447/1000
#   Best: -0.343604, Avg: -0.317524
#
# Iteration 448/1000
#   Best: -0.343604, Avg: -0.318019
#
# Iteration 449/1000
#   Best: -0.343604, Avg: -0.318131
#
# Iteration 450/1000
#   Best: -0.343604, Avg: -0.318141
#
# Iteration 451/1000
#   Best: -0.343604, Avg: -0.318141
#
# Iteration 452/1000
#   Best: -0.343604, Avg: -0.318141
#
# Iteration 453/1000
#   Best: -0.343604, Avg: -0.318175
#
# Iteration 454/1000
#   Best: -0.343604, Avg: -0.318295
#
# Iteration 455/1000
#   Best: -0.343604, Avg: -0.318778
#
# Iteration 456/1000
# ============================================================
# NEW BEST at iteration 456
# Criteria value: -0.34420189
# ============================================================
#   Best: -0.344202, Avg: -0.318808
#
# Iteration 457/1000
#   Best: -0.344202, Avg: -0.318808
#
# Iteration 458/1000
#   Best: -0.344202, Avg: -0.318808
#
# Iteration 459/1000
#   Best: -0.344202, Avg: -0.318808
#
# Iteration 460/1000
#   Best: -0.344202, Avg: -0.318829
#
# Iteration 461/1000
#   Best: -0.344202, Avg: -0.318846
#
# Iteration 462/1000
#   Best: -0.344202, Avg: -0.318899
#
# Iteration 463/1000
#   Best: -0.344202, Avg: -0.318899
#
# Iteration 464/1000
#   Best: -0.344202, Avg: -0.318899
#
# Iteration 465/1000
#   Best: -0.344202, Avg: -0.318912
#
# Iteration 466/1000
#   Best: -0.344202, Avg: -0.318912
#
# Iteration 467/1000
#   Best: -0.344202, Avg: -0.318924
#
# Iteration 468/1000
#   Best: -0.344202, Avg: -0.319041
#
# Iteration 469/1000
#   Best: -0.344202, Avg: -0.319041
#
# Iteration 470/1000
#   Best: -0.344202, Avg: -0.319105
#
# Iteration 471/1000
#   Best: -0.344202, Avg: -0.319638
#
# Iteration 472/1000
#   Best: -0.344202, Avg: -0.319638
#
# Iteration 473/1000
#   Best: -0.344202, Avg: -0.319638
#
# Iteration 474/1000
#   Best: -0.344202, Avg: -0.319649
#
# Iteration 475/1000
#   Best: -0.344202, Avg: -0.319674
#
# Iteration 476/1000
#   Best: -0.344202, Avg: -0.319674
#
# Iteration 477/1000
#   Best: -0.344202, Avg: -0.319674
#
# Iteration 478/1000
#   Best: -0.344202, Avg: -0.319676
#
# Iteration 479/1000
#   Best: -0.344202, Avg: -0.319709
#
# Iteration 480/1000
#   Best: -0.344202, Avg: -0.319709
#
# Iteration 481/1000
#   Best: -0.344202, Avg: -0.319709
#
# Iteration 482/1000
#   Best: -0.344202, Avg: -0.319715
#
# Iteration 483/1000
#   Best: -0.344202, Avg: -0.319715
#
# Iteration 484/1000
#   Best: -0.344202, Avg: -0.319772
#
# Iteration 485/1000
#   Best: -0.344202, Avg: -0.319772
#
# Iteration 486/1000
#   Best: -0.344202, Avg: -0.319772
#
# Iteration 487/1000
#   Best: -0.344202, Avg: -0.319772
#
# Iteration 488/1000
#   Best: -0.344202, Avg: -0.319808
#
# Iteration 489/1000
#   Best: -0.344202, Avg: -0.319808
#
# Iteration 490/1000
#   Best: -0.344202, Avg: -0.319818
#
# Iteration 491/1000
#   Best: -0.344202, Avg: -0.319824
#
# Iteration 492/1000
#   Best: -0.344202, Avg: -0.319851
#
# Iteration 493/1000
#   Best: -0.344202, Avg: -0.319852
#
# Iteration 494/1000
#   Best: -0.344202, Avg: -0.319852
#
# Iteration 495/1000
# ============================================================
# NEW BEST at iteration 495
# Criteria value: -0.34433458
# ============================================================
#   Best: -0.344335, Avg: -0.320036
#
# Iteration 496/1000
#   Best: -0.344335, Avg: -0.320036
#
# Iteration 497/1000
#   Best: -0.344335, Avg: -0.320036
#
# Iteration 498/1000
#   Best: -0.344335, Avg: -0.320054
#
# Iteration 499/1000
#   Scout: Abandoned and found new source with criteria -0.206112
#   Best: -0.344335, Avg: -0.315638
#
# Iteration 500/1000
#   Best: -0.344335, Avg: -0.315726
#
# Iteration 501/1000
#   Best: -0.344335, Avg: -0.315924
#
# Iteration 502/1000
#   Best: -0.344335, Avg: -0.317293
#
# Iteration 503/1000
# ============================================================
# NEW BEST at iteration 503
# Criteria value: -0.34433460
# ============================================================
#   Best: -0.344335, Avg: -0.317864
#
# Iteration 504/1000
#   Best: -0.344335, Avg: -0.317864
#
# Iteration 505/1000
#   Best: -0.344335, Avg: -0.318243
#
# Iteration 506/1000
#   Best: -0.344335, Avg: -0.318257
#
# Iteration 507/1000
# ============================================================
# NEW BEST at iteration 507
# Criteria value: -0.34445142
# ============================================================
#   Best: -0.344451, Avg: -0.318263
#
# Iteration 508/1000
#   Best: -0.344451, Avg: -0.319259
#
# Iteration 509/1000
#   Best: -0.344451, Avg: -0.319274
#
# Iteration 510/1000
#   Best: -0.344451, Avg: -0.319287
#
# Iteration 511/1000
#   Best: -0.344451, Avg: -0.319287
#
# Iteration 512/1000
#   Best: -0.344451, Avg: -0.319287
#
# Iteration 513/1000
#   Best: -0.344451, Avg: -0.319287
#
# Iteration 514/1000
#   Best: -0.344451, Avg: -0.319287
#
# Iteration 515/1000
#   Best: -0.344451, Avg: -0.319327
#
# Iteration 516/1000
#   Best: -0.344451, Avg: -0.319527
#
# Iteration 517/1000
#   Best: -0.344451, Avg: -0.319592
#
# Iteration 518/1000
#   Best: -0.344451, Avg: -0.319595
#
# Iteration 519/1000
#   Best: -0.344451, Avg: -0.319597
#
# Iteration 520/1000
#   Best: -0.344451, Avg: -0.319597
#
# Iteration 521/1000
#   Best: -0.344451, Avg: -0.319597
#
# Iteration 522/1000
#   Best: -0.344451, Avg: -0.319631
#
# Iteration 523/1000
#   Best: -0.344451, Avg: -0.319889
#
# Iteration 524/1000
#   Best: -0.344451, Avg: -0.319905
#
# Iteration 525/1000
#   Best: -0.344451, Avg: -0.319905
#
# Iteration 526/1000
#   Best: -0.344451, Avg: -0.320062
#
# Iteration 527/1000
#   Best: -0.344451, Avg: -0.320247
#
# Iteration 528/1000
#   Best: -0.344451, Avg: -0.320284
#
# Iteration 529/1000
#   Best: -0.344451, Avg: -0.320492
#
# Iteration 530/1000
#   Best: -0.344451, Avg: -0.320508
#
# Iteration 531/1000
#   Best: -0.344451, Avg: -0.320541
#
# Iteration 532/1000
#   Best: -0.344451, Avg: -0.320572
#
# Iteration 533/1000
#   Best: -0.344451, Avg: -0.320573
#
# Iteration 534/1000
#   Best: -0.344451, Avg: -0.320612
#
# Iteration 535/1000
#   Best: -0.344451, Avg: -0.320612
#
# Iteration 536/1000
#   Best: -0.344451, Avg: -0.320612
#
# Iteration 537/1000
#   Best: -0.344451, Avg: -0.320636
#
# Iteration 538/1000
# ============================================================
# NEW BEST at iteration 538
# Criteria value: -0.34461691
# ============================================================
#   Best: -0.344617, Avg: -0.320645
#
# Iteration 539/1000
#   Best: -0.344617, Avg: -0.320655
#
# Iteration 540/1000
#   Best: -0.344617, Avg: -0.320655
#
# Iteration 541/1000
#   Best: -0.344617, Avg: -0.320682
#
# Iteration 542/1000
#   Best: -0.344617, Avg: -0.320879
#
# Iteration 543/1000
#   Best: -0.344617, Avg: -0.320893
#
# Iteration 544/1000
#   Best: -0.344617, Avg: -0.320893
#
# Iteration 545/1000
#   Best: -0.344617, Avg: -0.320893
#
# Iteration 546/1000
#   Best: -0.344617, Avg: -0.320903
#
# Iteration 547/1000
# ============================================================
# NEW BEST at iteration 547
# Criteria value: -0.34477663
# ============================================================
#   Best: -0.344777, Avg: -0.320942
#
# Iteration 548/1000
#   Best: -0.344777, Avg: -0.320942
#
# Iteration 549/1000
#   Best: -0.344777, Avg: -0.320942
#
# Iteration 550/1000
#   Best: -0.344777, Avg: -0.321160
#
# Iteration 551/1000
#   Best: -0.344777, Avg: -0.321164
#
# Iteration 552/1000
#   Best: -0.344777, Avg: -0.321164
#
# Iteration 553/1000
#   Best: -0.344777, Avg: -0.321164
#
# Iteration 554/1000
#   Best: -0.344777, Avg: -0.321164
#
# Iteration 555/1000
#   Best: -0.344777, Avg: -0.321164
#
# Iteration 556/1000
#   Best: -0.344777, Avg: -0.321164
#
# Iteration 557/1000
#   Best: -0.344777, Avg: -0.321167
#
# Iteration 558/1000
#   Best: -0.344777, Avg: -0.321167
#
# Iteration 559/1000
#   Best: -0.344777, Avg: -0.321169
#
# Iteration 560/1000
#   Best: -0.344777, Avg: -0.321357
#
# Iteration 561/1000
#   Best: -0.344777, Avg: -0.321357
#
# Iteration 562/1000
#   Best: -0.344777, Avg: -0.321357
#
# Iteration 563/1000
#   Best: -0.344777, Avg: -0.321357
#
# Iteration 564/1000
#   Best: -0.344777, Avg: -0.321372
#
# Iteration 565/1000
#   Scout: Abandoned and found new source with criteria -0.224404
#   Best: -0.344777, Avg: -0.315480
#
# Iteration 566/1000
#   Best: -0.344777, Avg: -0.315513
#
# Iteration 567/1000
#   Best: -0.344777, Avg: -0.315513
#
# Iteration 568/1000
#   Best: -0.344777, Avg: -0.315513
#
# Iteration 569/1000
#   Best: -0.344777, Avg: -0.316139
#
# Iteration 570/1000
#   Best: -0.344777, Avg: -0.316623
#
# Iteration 571/1000
#   Best: -0.344777, Avg: -0.318043
#
# Iteration 572/1000
#   Best: -0.344777, Avg: -0.318043
#
# Iteration 573/1000
#   Best: -0.344777, Avg: -0.318110
#
# Iteration 574/1000
#   Best: -0.344777, Avg: -0.318110
#
# Iteration 575/1000
#   Best: -0.344777, Avg: -0.318222
#
# Iteration 576/1000
#   Best: -0.344777, Avg: -0.318222
#
# Iteration 577/1000
#   Best: -0.344777, Avg: -0.318222
#
# Iteration 578/1000
#   Best: -0.344777, Avg: -0.318222
#
# Iteration 579/1000
#   Best: -0.344777, Avg: -0.318222
#
# Iteration 580/1000
#   Best: -0.344777, Avg: -0.318317
#
# Iteration 581/1000
#   Best: -0.344777, Avg: -0.318319
#
# Iteration 582/1000
#   Best: -0.344777, Avg: -0.318319
#
# Iteration 583/1000
#   Best: -0.344777, Avg: -0.318321
#
# Iteration 584/1000
#   Best: -0.344777, Avg: -0.318424
#
# Iteration 585/1000
#   Best: -0.344777, Avg: -0.318430
#
# Iteration 586/1000
#   Best: -0.344777, Avg: -0.318489
#
# Iteration 587/1000
#   Best: -0.344777, Avg: -0.318489
#
# Iteration 588/1000
#   Best: -0.344777, Avg: -0.318622
#
# Iteration 589/1000
#   Best: -0.344777, Avg: -0.318978
#
# Iteration 590/1000
#   Best: -0.344777, Avg: -0.318987
#
# Iteration 591/1000
#   Best: -0.344777, Avg: -0.318987
#
# Iteration 592/1000
#   Best: -0.344777, Avg: -0.318987
#
# Iteration 593/1000
#   Best: -0.344777, Avg: -0.318987
#
# Iteration 594/1000
#   Best: -0.344777, Avg: -0.318987
#
# Iteration 595/1000
#   Best: -0.344777, Avg: -0.318987
#
# Iteration 596/1000
#   Best: -0.344777, Avg: -0.319012
#
# Iteration 597/1000
#   Best: -0.344777, Avg: -0.319063
#
# Iteration 598/1000
#   Best: -0.344777, Avg: -0.319063
#
# Iteration 599/1000
# ============================================================
# NEW BEST at iteration 599
# Criteria value: -0.34667626
# ============================================================
#   Best: -0.346676, Avg: -0.319184
#
# Iteration 600/1000
#   Best: -0.346676, Avg: -0.319184
#
# Iteration 601/1000
#   Best: -0.346676, Avg: -0.319184
#
# Iteration 602/1000
#   Best: -0.346676, Avg: -0.319184
#
# Iteration 603/1000
#   Best: -0.346676, Avg: -0.319192
#
# Iteration 604/1000
#   Best: -0.346676, Avg: -0.319192
#
# Iteration 605/1000
#   Best: -0.346676, Avg: -0.319192
#
# Iteration 606/1000
# ============================================================
# NEW BEST at iteration 606
# Criteria value: -0.34670248
# ============================================================
#   Best: -0.346702, Avg: -0.319277
#
# Iteration 607/1000
#   Best: -0.346702, Avg: -0.319854
#
# Iteration 608/1000
#   Best: -0.346702, Avg: -0.319887
#
# Iteration 609/1000
#   Best: -0.346702, Avg: -0.319887
#
# Iteration 610/1000
#   Best: -0.346702, Avg: -0.319889
#
# Iteration 611/1000
#   Best: -0.346702, Avg: -0.319909
#
# Iteration 612/1000
# ============================================================
# NEW BEST at iteration 612
# Criteria value: -0.34682694
# ============================================================
#   Best: -0.346827, Avg: -0.319915
#
# Iteration 613/1000
#   Best: -0.346827, Avg: -0.319915
#
# Iteration 614/1000
#   Best: -0.346827, Avg: -0.319915
#
# Iteration 615/1000
#   Best: -0.346827, Avg: -0.319915
#
# Iteration 616/1000
#   Best: -0.346827, Avg: -0.319938
#
# Iteration 617/1000
#   Best: -0.346827, Avg: -0.319938
#
# Iteration 618/1000
#   Best: -0.346827, Avg: -0.319938
#
# Iteration 619/1000
#   Best: -0.346827, Avg: -0.319959
#
# Iteration 620/1000
#   Best: -0.346827, Avg: -0.319980
#
# Iteration 621/1000
#   Best: -0.346827, Avg: -0.319980
#
# Iteration 622/1000
#   Scout: Abandoned and found new source with criteria -0.223083
#   Best: -0.346827, Avg: -0.314781
#
# Iteration 623/1000
#   Best: -0.346827, Avg: -0.315234
#
# Iteration 624/1000
#   Best: -0.346827, Avg: -0.315382
#
# Iteration 625/1000
#   Best: -0.346827, Avg: -0.315392
#
# Iteration 626/1000
#   Best: -0.346827, Avg: -0.315392
#
# Iteration 627/1000
#   Best: -0.346827, Avg: -0.315400
#
# Iteration 628/1000
#   Scout: Abandoned and found new source with criteria -0.198421
#   Best: -0.346827, Avg: -0.310102
#
# Iteration 629/1000
#   Best: -0.346827, Avg: -0.311657
#
# Iteration 630/1000
#   Best: -0.346827, Avg: -0.311661
#
# Iteration 631/1000
#   Best: -0.346827, Avg: -0.311665
#
# Iteration 632/1000
#   Scout: Abandoned and found new source with criteria -0.178100
#   Best: -0.346827, Avg: -0.304243
#
# Iteration 633/1000
#   Best: -0.346827, Avg: -0.306422
#
# Iteration 634/1000
#   Best: -0.346827, Avg: -0.308056
#
# Iteration 635/1000
#   Best: -0.346827, Avg: -0.309586
#
# Iteration 636/1000
#   Best: -0.346827, Avg: -0.310844
#
# Iteration 637/1000
#   Best: -0.346827, Avg: -0.310918
#
# Iteration 638/1000
#   Best: -0.346827, Avg: -0.310920
#
# Iteration 639/1000
#   Best: -0.346827, Avg: -0.311906
#
# Iteration 640/1000
#   Best: -0.346827, Avg: -0.311906
#
# Iteration 641/1000
#   Best: -0.346827, Avg: -0.312283
#
# Iteration 642/1000
#   Best: -0.346827, Avg: -0.312310
#
# Iteration 643/1000
#   Best: -0.346827, Avg: -0.312409
#
# Iteration 644/1000
#   Best: -0.346827, Avg: -0.312409
#
# Iteration 645/1000
#   Best: -0.346827, Avg: -0.312432
#
# Iteration 646/1000
#   Best: -0.346827, Avg: -0.313031
#
# Iteration 647/1000
#   Best: -0.346827, Avg: -0.313806
#
# Iteration 648/1000
#   Best: -0.346827, Avg: -0.313806
#
# Iteration 649/1000
#   Best: -0.346827, Avg: -0.313807
#
# Iteration 650/1000
#   Best: -0.346827, Avg: -0.313807
#
# Iteration 651/1000
#   Best: -0.346827, Avg: -0.314004
#
# Iteration 652/1000
#   Best: -0.346827, Avg: -0.314061
#
# Iteration 653/1000
#   Best: -0.346827, Avg: -0.314067
#
# Iteration 654/1000
#   Best: -0.346827, Avg: -0.314076
#
# Iteration 655/1000
#   Best: -0.346827, Avg: -0.314305
#
# Iteration 656/1000
#   Best: -0.346827, Avg: -0.314305
#
# Iteration 657/1000
#   Best: -0.346827, Avg: -0.315095
#
# Iteration 658/1000
#   Best: -0.346827, Avg: -0.315095
#
# Iteration 659/1000
#   Best: -0.346827, Avg: -0.315175
#
# Iteration 660/1000
#   Best: -0.346827, Avg: -0.315530
#
# Iteration 661/1000
#   Best: -0.346827, Avg: -0.315530
#
# Iteration 662/1000
#   Scout: Abandoned and found new source with criteria -0.228269
#   Best: -0.346827, Avg: -0.310677
#
# Iteration 663/1000
#   Best: -0.346827, Avg: -0.311719
#
# Iteration 664/1000
#   Best: -0.346827, Avg: -0.311721
#
# Iteration 665/1000
#   Best: -0.346827, Avg: -0.311880
#
# Iteration 666/1000
#   Best: -0.346827, Avg: -0.311901
#
# Iteration 667/1000
#   Best: -0.346827, Avg: -0.311941
#
# Iteration 668/1000
#   Best: -0.346827, Avg: -0.313868
#
# Iteration 669/1000
#   Best: -0.346827, Avg: -0.313882
#
# Iteration 670/1000
#   Best: -0.346827, Avg: -0.313882
#
# Iteration 671/1000
#   Best: -0.346827, Avg: -0.313976
#
# Iteration 672/1000
#   Best: -0.346827, Avg: -0.313976
#
# Iteration 673/1000
#   Best: -0.346827, Avg: -0.313976
#
# Iteration 674/1000
#   Best: -0.346827, Avg: -0.314180
#
# Iteration 675/1000
#   Best: -0.346827, Avg: -0.314531
#
# Iteration 676/1000
#   Best: -0.346827, Avg: -0.314914
#
# Iteration 677/1000
# ============================================================
# NEW BEST at iteration 677
# Criteria value: -0.34758561
# ============================================================
#   Best: -0.347586, Avg: -0.314973
#
# Iteration 678/1000
#   Best: -0.347586, Avg: -0.315162
#
# Iteration 679/1000
#   Best: -0.347586, Avg: -0.315167
#
# Iteration 680/1000
#   Best: -0.347586, Avg: -0.315170
#
# Iteration 681/1000
#   Best: -0.347586, Avg: -0.315275
#
# Iteration 682/1000
#   Best: -0.347586, Avg: -0.315434
#
# Iteration 683/1000
#   Best: -0.347586, Avg: -0.315434
#
# Iteration 684/1000
#   Best: -0.347586, Avg: -0.315474
#
# Iteration 685/1000
#   Best: -0.347586, Avg: -0.315474
#
# Iteration 686/1000
#   Best: -0.347586, Avg: -0.315731
#
# Iteration 687/1000
#   Best: -0.347586, Avg: -0.315731
#
# Iteration 688/1000
#   Best: -0.347586, Avg: -0.315747
#
# Iteration 689/1000
#   Best: -0.347586, Avg: -0.316012
#
# Iteration 690/1000
#   Best: -0.347586, Avg: -0.316086
#
# Iteration 691/1000
#   Best: -0.347586, Avg: -0.316139
#
# Iteration 692/1000
#   Best: -0.347586, Avg: -0.316193
#
# Iteration 693/1000
#   Best: -0.347586, Avg: -0.316206
#
# Iteration 694/1000
#   Best: -0.347586, Avg: -0.316372
#
# Iteration 695/1000
#   Best: -0.347586, Avg: -0.316502
#
# Iteration 696/1000
#   Best: -0.347586, Avg: -0.316525
#
# Iteration 697/1000
#   Best: -0.347586, Avg: -0.316525
#
# Iteration 698/1000
#   Best: -0.347586, Avg: -0.316525
#
# Iteration 699/1000
#   Best: -0.347586, Avg: -0.316658
#
# Iteration 700/1000
#   Best: -0.347586, Avg: -0.316726
#
# Iteration 701/1000
#   Best: -0.347586, Avg: -0.316782
#
# Iteration 702/1000
#   Best: -0.347586, Avg: -0.316788
#
# Iteration 703/1000
#   Best: -0.347586, Avg: -0.316819
#
# Iteration 704/1000
#   Best: -0.347586, Avg: -0.316819
#
# Iteration 705/1000
#   Best: -0.347586, Avg: -0.316885
#
# Iteration 706/1000
#   Best: -0.347586, Avg: -0.316890
#
# Iteration 707/1000
#   Best: -0.347586, Avg: -0.316912
#
# Iteration 708/1000
#   Best: -0.347586, Avg: -0.316994
#
# Iteration 709/1000
#   Best: -0.347586, Avg: -0.316995
#
# ...
#   Best: -0.347586, Avg: -0.317943
#
# Iteration 727/1000
#   Best: -0.347586, Avg: -0.317950
#
# Iteration 728/1000
#   Best: -0.347586, Avg: -0.317986
#
# Iteration 729/1000
#   Best: -0.347586, Avg: -0.318056
#
# Iteration 730/1000
#   Best: -0.347586, Avg: -0.319065
#
# Iteration 731/1000
#   Best: -0.347586, Avg: -0.319067
#
# Iteration 732/1000
#   Best: -0.347586, Avg: -0.319153
#
# Iteration 733/1000
#   Best: -0.347586, Avg: -0.319204
#
# Iteration 734/1000
#   Best: -0.347586, Avg: -0.319317
#
# Iteration 735/1000
#   Best: -0.347586, Avg: -0.319555
#
# Iteration 736/1000
#   Best: -0.347586, Avg: -0.319586
#
# Iteration 737/1000
#   Best: -0.347586, Avg: -0.319605
#
# Iteration 738/1000
#   Best: -0.347586, Avg: -0.319637
#
# Iteration 739/1000
#   Best: -0.347586, Avg: -0.320080
#
# Iteration 740/1000
#   Best: -0.347586, Avg: -0.320080
#
# Iteration 741/1000
#   Best: -0.347586, Avg: -0.320080
#
# Iteration 742/1000
#   Best: -0.347586, Avg: -0.320282
#
# Iteration 743/1000
#   Best: -0.347586, Avg: -0.320285
#
# Iteration 744/1000
#   Best: -0.347586, Avg: -0.320285
#
# Iteration 745/1000
#   Best: -0.347586, Avg: -0.320288
#
# Iteration 746/1000
#   Best: -0.347586, Avg: -0.320288
#
# Iteration 747/1000
#   Best: -0.347586, Avg: -0.320288
#
# Iteration 748/1000
#   Best: -0.347586, Avg: -0.320342
#
# Iteration 749/1000
#   Best: -0.347586, Avg: -0.320372
#
# Iteration 750/1000
#   Best: -0.347586, Avg: -0.320372
#
# Iteration 751/1000
#   Best: -0.347586, Avg: -0.320376
#
# Iteration 752/1000
#   Best: -0.347586, Avg: -0.320376
#
# Iteration 753/1000
#   Best: -0.347586, Avg: -0.320376
#
# Iteration 754/1000
#   Best: -0.347586, Avg: -0.320376
#
# Iteration 755/1000
#   Best: -0.347586, Avg: -0.320376
#
# Iteration 756/1000
#   Best: -0.347586, Avg: -0.320376
#
# Iteration 757/1000
# ============================================================
# NEW BEST at iteration 757
# Criteria value: -0.34786161
# ============================================================
#   Best: -0.347862, Avg: -0.320423
#
# Iteration 758/1000
#   Best: -0.347862, Avg: -0.320451
#
# Iteration 759/1000
#   Best: -0.347862, Avg: -0.320451
#
# Iteration 760/1000
#   Best: -0.347862, Avg: -0.320650
#
# Iteration 761/1000
#   Best: -0.347862, Avg: -0.320650
#
# Iteration 762/1000
#   Best: -0.347862, Avg: -0.320651
#
# Iteration 763/1000
#   Best: -0.347862, Avg: -0.320653
#
# Iteration 764/1000
#   Best: -0.347862, Avg: -0.320674
#
# Iteration 765/1000
#   Best: -0.347862, Avg: -0.320723
#
# Iteration 766/1000
#   Best: -0.347862, Avg: -0.320723
#
# Iteration 767/1000
#   Best: -0.347862, Avg: -0.320728
#
# Iteration 768/1000
#   Best: -0.347862, Avg: -0.320728
#
# Iteration 769/1000
#   Best: -0.347862, Avg: -0.320728
#
# Iteration 770/1000
#   Best: -0.347862, Avg: -0.320797
#
# Iteration 771/1000
#   Best: -0.347862, Avg: -0.320825
#
# Iteration 772/1000
#   Best: -0.347862, Avg: -0.320825
#
# Iteration 773/1000
#   Best: -0.347862, Avg: -0.320846
#
# Iteration 774/1000
#   Scout: Abandoned and found new source with criteria -0.213228
#   Best: -0.347862, Avg: -0.314170
#
# Iteration 775/1000
#   Best: -0.347862, Avg: -0.315373
#
# Iteration 776/1000
#   Best: -0.347862, Avg: -0.315385
#
# Iteration 777/1000
#   Best: -0.347862, Avg: -0.315385
#
# Iteration 778/1000
#   Best: -0.347862, Avg: -0.315610
#
# Iteration 779/1000
#   Best: -0.347862, Avg: -0.315658
#
# Iteration 780/1000
#   Best: -0.347862, Avg: -0.315754
#
# Iteration 781/1000
#   Best: -0.347862, Avg: -0.317339
#
# Iteration 782/1000
#   Best: -0.347862, Avg: -0.317352
#
# Iteration 783/1000
#   Best: -0.347862, Avg: -0.317352
#
# Iteration 784/1000
#   Best: -0.347862, Avg: -0.317352
#
# Iteration 785/1000
#   Best: -0.347862, Avg: -0.317352
#
# Iteration 786/1000
#   Best: -0.347862, Avg: -0.317523
#
# Iteration 787/1000
#   Scout: Abandoned and found new source with criteria -0.206120
#   Best: -0.347862, Avg: -0.313059
#
# Iteration 788/1000
#   Best: -0.347862, Avg: -0.313059
#
# Iteration 789/1000
#   Best: -0.347862, Avg: -0.313059
#
# Iteration 790/1000
#   Best: -0.347862, Avg: -0.313059
#
# Iteration 791/1000
#   Best: -0.347862, Avg: -0.314116
#
# Iteration 792/1000
#   Best: -0.347862, Avg: -0.314176
#
# Iteration 793/1000
#   Best: -0.347862, Avg: -0.315832
#
# Iteration 794/1000
#   Best: -0.347862, Avg: -0.315844
#
# Iteration 795/1000
#   Best: -0.347862, Avg: -0.315894
#
# Iteration 796/1000
#   Best: -0.347862, Avg: -0.316029
#
# Iteration 797/1000
#   Best: -0.347862, Avg: -0.316069
#
# Iteration 798/1000
#   Best: -0.347862, Avg: -0.316260
#
# Iteration 799/1000
#   Best: -0.347862, Avg: -0.317026
#
# Iteration 800/1000
#   Best: -0.347862, Avg: -0.317033
#
# Iteration 801/1000
#   Best: -0.347862, Avg: -0.317417
#
# Iteration 802/1000
#   Best: -0.347862, Avg: -0.317419
#
# Iteration 803/1000
#   Best: -0.347862, Avg: -0.317449
#
# Iteration 804/1000
#   Best: -0.347862, Avg: -0.317449
#
# Iteration 805/1000
#   Best: -0.347862, Avg: -0.317450
#
# Iteration 806/1000
#   Best: -0.347862, Avg: -0.317502
#
# Iteration 807/1000
#   Best: -0.347862, Avg: -0.317731
#
# Iteration 808/1000
#   Best: -0.347862, Avg: -0.317849
#
# Iteration 809/1000
#   Best: -0.347862, Avg: -0.317849
#
# Iteration 810/1000
#   Best: -0.347862, Avg: -0.317849
#
# Iteration 811/1000
#   Best: -0.347862, Avg: -0.318051
#
# Iteration 812/1000
#   Best: -0.347862, Avg: -0.318233
#
# Iteration 813/1000
#   Best: -0.347862, Avg: -0.318233
#
# Iteration 814/1000
#   Best: -0.347862, Avg: -0.318276
#
# Iteration 815/1000
#   Best: -0.347862, Avg: -0.318278
#
# Iteration 816/1000
#   Best: -0.347862, Avg: -0.318339
#
# Iteration 817/1000
#   Best: -0.347862, Avg: -0.318483
#
# Iteration 818/1000
#   Best: -0.347862, Avg: -0.318519
#
# Iteration 819/1000
#   Best: -0.347862, Avg: -0.318619
#
# Iteration 820/1000
#   Best: -0.347862, Avg: -0.318620
#
# Iteration 821/1000
#   Best: -0.347862, Avg: -0.318620
#
# Iteration 822/1000
#   Best: -0.347862, Avg: -0.318620
#
# Iteration 823/1000
#   Best: -0.347862, Avg: -0.318646
#
# Iteration 824/1000
#   Best: -0.347862, Avg: -0.318677
#
# Iteration 825/1000
#   Best: -0.347862, Avg: -0.318677
#
# Iteration 826/1000
#   Best: -0.347862, Avg: -0.318677
#
# Iteration 827/1000
#   Best: -0.347862, Avg: -0.318711
#
# Iteration 828/1000
#   Best: -0.347862, Avg: -0.318771
#
# Iteration 829/1000
#   Best: -0.347862, Avg: -0.318771
#
# Iteration 830/1000
#   Best: -0.347862, Avg: -0.318811
#
# Iteration 831/1000
#   Best: -0.347862, Avg: -0.318819
#
# Iteration 832/1000
#   Best: -0.347862, Avg: -0.318819
#
# Iteration 833/1000
#   Best: -0.347862, Avg: -0.318819
#
# Iteration 834/1000
#   Best: -0.347862, Avg: -0.318819
#
# Iteration 835/1000
#   Best: -0.347862, Avg: -0.318819
#
# Iteration 836/1000
#   Best: -0.347862, Avg: -0.318819
#
# Iteration 837/1000
#   Best: -0.347862, Avg: -0.318919
#
# Iteration 838/1000
#   Best: -0.347862, Avg: -0.318943
#
# Iteration 839/1000
#   Best: -0.347862, Avg: -0.318975
#
# Iteration 840/1000
#   Best: -0.347862, Avg: -0.318996
#
# Iteration 841/1000
#   Best: -0.347862, Avg: -0.319084
#
# Iteration 842/1000
#   Best: -0.347862, Avg: -0.319084
#
# Iteration 843/1000
#   Best: -0.347862, Avg: -0.319084
#
# Iteration 844/1000
#   Best: -0.347862, Avg: -0.319084
#
# Iteration 845/1000
#   Best: -0.347862, Avg: -0.319157
#
# Iteration 846/1000
#   Best: -0.347862, Avg: -0.319172
#
# Iteration 847/1000
#   Scout: Abandoned and found new source with criteria -0.249317
#   Best: -0.347862, Avg: -0.314469
#
# Iteration 848/1000
#   Best: -0.347862, Avg: -0.315552
#
# Iteration 849/1000
#   Best: -0.347862, Avg: -0.315634
#
# Iteration 850/1000
#   Best: -0.347862, Avg: -0.315634
#
# Iteration 851/1000
#   Best: -0.347862, Avg: -0.315740
#
# Iteration 852/1000
#   Best: -0.347862, Avg: -0.315740
#
# Iteration 853/1000
#   Best: -0.347862, Avg: -0.315741
#
# Iteration 854/1000
#   Best: -0.347862, Avg: -0.315744
#
# Iteration 855/1000
#   Best: -0.347862, Avg: -0.315806
#
# Iteration 856/1000
#   Best: -0.347862, Avg: -0.315825
#
# Iteration 857/1000
#   Best: -0.347862, Avg: -0.315825
#
# Iteration 858/1000
#   Best: -0.347862, Avg: -0.315830
#
# Iteration 859/1000
#   Best: -0.347862, Avg: -0.316032
#
# Iteration 860/1000
#   Best: -0.347862, Avg: -0.316032
#
# Iteration 861/1000
#   Best: -0.347862, Avg: -0.316044
#
# Iteration 862/1000
#   Best: -0.347862, Avg: -0.316057
#
# Iteration 863/1000
#   Scout: Abandoned and found new source with criteria -0.203425
#   Best: -0.347862, Avg: -0.308842
#
# Iteration 864/1000
#   Best: -0.347862, Avg: -0.308842
#
# Iteration 865/1000
#   Best: -0.347862, Avg: -0.309106
#
# Iteration 866/1000
#   Best: -0.347862, Avg: -0.309911
#
# Iteration 867/1000
#   Best: -0.347862, Avg: -0.309996
#
# Iteration 868/1000
#   Best: -0.347862, Avg: -0.310041
#
# Iteration 869/1000
#   Best: -0.347862, Avg: -0.310870
#
# Iteration 870/1000
#   Best: -0.347862, Avg: -0.311555
#
# Iteration 871/1000
#   Best: -0.347862, Avg: -0.311607
#
# Iteration 872/1000
#   Best: -0.347862, Avg: -0.311609
#
# Iteration 873/1000
#   Best: -0.347862, Avg: -0.311611
#
# Iteration 874/1000
#   Best: -0.347862, Avg: -0.311611
#
# Iteration 875/1000
#   Best: -0.347862, Avg: -0.311653
#
# Iteration 876/1000
#   Best: -0.347862, Avg: -0.311689
#
# Iteration 877/1000
#   Best: -0.347862, Avg: -0.312427
#
# Iteration 878/1000
#   Best: -0.347862, Avg: -0.312475
#
# Iteration 879/1000
#   Best: -0.347862, Avg: -0.312891
#
# Iteration 880/1000
#   Best: -0.347862, Avg: -0.312891
#
# Iteration 881/1000
#   Best: -0.347862, Avg: -0.312949
#
# Iteration 882/1000
#   Best: -0.347862, Avg: -0.313246
#
# Iteration 883/1000
#   Best: -0.347862, Avg: -0.313479
#
# Iteration 884/1000
#   Best: -0.347862, Avg: -0.313480
#
# Iteration 885/1000
#   Best: -0.347862, Avg: -0.313534
#
# Iteration 886/1000
#   Best: -0.347862, Avg: -0.313534
#
# Iteration 887/1000
#   Best: -0.347862, Avg: -0.313596
#
# Iteration 888/1000
#   Best: -0.347862, Avg: -0.313596
#
# Iteration 889/1000
#   Best: -0.347862, Avg: -0.313596
#
# Iteration 890/1000
#   Best: -0.347862, Avg: -0.313596
#
# Iteration 891/1000
#   Best: -0.347862, Avg: -0.313596
#
# Iteration 892/1000
#   Best: -0.347862, Avg: -0.313603
#
# Iteration 893/1000
#   Best: -0.347862, Avg: -0.313603
#
# Iteration 894/1000
#   Best: -0.347862, Avg: -0.313633
#
# Iteration 895/1000
#   Best: -0.347862, Avg: -0.313633
#
# Iteration 896/1000
#   Scout: Abandoned and found new source with criteria -0.212742
#   Best: -0.347862, Avg: -0.308971
#
# Iteration 897/1000
#   Best: -0.347862, Avg: -0.309189
#
# Iteration 898/1000
#   Best: -0.347862, Avg: -0.309207
#
# Iteration 899/1000
#   Scout: Abandoned and found new source with criteria -0.222083
#   Best: -0.347862, Avg: -0.303350
#
# Iteration 900/1000
#   Best: -0.347862, Avg: -0.304104
#
# Iteration 901/1000
#   Best: -0.347862, Avg: -0.304142
#
# Iteration 902/1000
# ============================================================
# NEW BEST at iteration 902
# Criteria value: -0.34788710
# ============================================================
#   Best: -0.347887, Avg: -0.304779
#
# Iteration 903/1000
#   Best: -0.347887, Avg: -0.305602
#
# Iteration 904/1000
#   Best: -0.347887, Avg: -0.305859
#
# Iteration 905/1000
#   Best: -0.347887, Avg: -0.305931
#
# Iteration 906/1000
#   Best: -0.347887, Avg: -0.307201
#
# Iteration 907/1000
#   Best: -0.347887, Avg: -0.309023
#
# Iteration 908/1000
#   Best: -0.347887, Avg: -0.309023
#
# Iteration 909/1000
#   Best: -0.347887, Avg: -0.309023
#
# Iteration 910/1000
#   Best: -0.347887, Avg: -0.309221
#
# Iteration 911/1000
#   Best: -0.347887, Avg: -0.311479
#
# Iteration 912/1000
#   Best: -0.347887, Avg: -0.311496
#
# Iteration 913/1000
#   Best: -0.347887, Avg: -0.311496
#
# Iteration 914/1000
#   Best: -0.347887, Avg: -0.311766
#
# Iteration 915/1000
#   Best: -0.347887, Avg: -0.311766
#
# Iteration 916/1000
#   Best: -0.347887, Avg: -0.312102
#
# Iteration 917/1000
#   Best: -0.347887, Avg: -0.312142
#
# Iteration 918/1000
#   Best: -0.347887, Avg: -0.312214
#
# Iteration 919/1000
#   Best: -0.347887, Avg: -0.312219
#
# Iteration 920/1000
#   Best: -0.347887, Avg: -0.312306
#
# Iteration 921/1000
#   Best: -0.347887, Avg: -0.312443
#
# Iteration 922/1000
#   Best: -0.347887, Avg: -0.312487
#
# Iteration 923/1000
#   Best: -0.347887, Avg: -0.312514
#
# Iteration 924/1000
#   Best: -0.347887, Avg: -0.312514
#
# Iteration 925/1000
#   Best: -0.347887, Avg: -0.313358
#
# Iteration 926/1000
#   Best: -0.347887, Avg: -0.313376
#
# Iteration 927/1000
#   Best: -0.347887, Avg: -0.313377
#
# Iteration 928/1000
#   Best: -0.347887, Avg: -0.313388
#
# Iteration 929/1000
#   Best: -0.347887, Avg: -0.313454
#
# Iteration 930/1000
#   Best: -0.347887, Avg: -0.313640
#
# Iteration 931/1000
#   Best: -0.347887, Avg: -0.313640
#
# Iteration 932/1000
#   Best: -0.347887, Avg: -0.313643
#
# Iteration 933/1000
#   Best: -0.347887, Avg: -0.313649
#
# Iteration 934/1000
#   Best: -0.347887, Avg: -0.313649
#
# Iteration 935/1000
#   Best: -0.347887, Avg: -0.313697
#
# Iteration 936/1000
#   Best: -0.347887, Avg: -0.313772
#
# Iteration 937/1000
#   Best: -0.347887, Avg: -0.313835
#
# Iteration 938/1000
#   Best: -0.347887, Avg: -0.313882
#
# Iteration 939/1000
#   Best: -0.347887, Avg: -0.313919
#
# Iteration 940/1000
#   Best: -0.347887, Avg: -0.314051
#
# Iteration 941/1000
#   Best: -0.347887, Avg: -0.314942
#
# Iteration 942/1000
#   Best: -0.347887, Avg: -0.314942
#
# Iteration 943/1000
#   Best: -0.347887, Avg: -0.314969
#
# Iteration 944/1000
#   Best: -0.347887, Avg: -0.314969
#
# Iteration 945/1000
#   Best: -0.347887, Avg: -0.314969
#
# Iteration 946/1000
#   Best: -0.347887, Avg: -0.314969
#
# Iteration 947/1000
#   Best: -0.347887, Avg: -0.315053
#
# Iteration 948/1000
#   Best: -0.347887, Avg: -0.315076
#
# Iteration 949/1000
#   Best: -0.347887, Avg: -0.315076
#
# Iteration 950/1000
#   Best: -0.347887, Avg: -0.315092
#
# Iteration 951/1000
#   Best: -0.347887, Avg: -0.315255
#
# Iteration 952/1000
#   Best: -0.347887, Avg: -0.315255
#
# Iteration 953/1000
#   Best: -0.347887, Avg: -0.315255
#
# Iteration 954/1000
#   Best: -0.347887, Avg: -0.315255
#
# Iteration 955/1000
#   Best: -0.347887, Avg: -0.315255
#
# Iteration 956/1000
#   Best: -0.347887, Avg: -0.315398
#
# Iteration 957/1000
#   Best: -0.347887, Avg: -0.315476
#
# Iteration 958/1000
#   Best: -0.347887, Avg: -0.315476
#
# Iteration 959/1000
#   Best: -0.347887, Avg: -0.315547
#
# Iteration 960/1000
#   Best: -0.347887, Avg: -0.315608
#
# Iteration 961/1000
#   Best: -0.347887, Avg: -0.315796
#
# Iteration 962/1000
#   Best: -0.347887, Avg: -0.315806
#
# Iteration 963/1000
#   Best: -0.347887, Avg: -0.315812
#
# Iteration 964/1000
#   Best: -0.347887, Avg: -0.315812
#
# Iteration 965/1000
#   Best: -0.347887, Avg: -0.316112
#
# Iteration 966/1000
#   Best: -0.347887, Avg: -0.316284
#
# Iteration 967/1000
#   Best: -0.347887, Avg: -0.316284
#
# Iteration 968/1000
#   Best: -0.347887, Avg: -0.316286
#
# Iteration 969/1000
#   Best: -0.347887, Avg: -0.316311
#
# Iteration 970/1000
#   Best: -0.347887, Avg: -0.316322
#
# Iteration 971/1000
#   Best: -0.347887, Avg: -0.316327
#
# Iteration 972/1000
#   Best: -0.347887, Avg: -0.316327
#
# Iteration 973/1000
#   Best: -0.347887, Avg: -0.316410
#
# Iteration 974/1000
#   Best: -0.347887, Avg: -0.316413
#
# Iteration 975/1000
#   Best: -0.347887, Avg: -0.316416
#
# Iteration 976/1000
# ============================================================
# NEW BEST at iteration 976
# Criteria value: -0.34867345
# ============================================================
#   Best: -0.348673, Avg: -0.316549
#
# Iteration 977/1000
#   Best: -0.348673, Avg: -0.316604
#
# Iteration 978/1000
#   Best: -0.348673, Avg: -0.316757
#
# Iteration 979/1000
#   Best: -0.348673, Avg: -0.316762
#
# Iteration 980/1000
#   Best: -0.348673, Avg: -0.316770
#
# Iteration 981/1000
#   Best: -0.348673, Avg: -0.316926
#
# Iteration 982/1000
#   Best: -0.348673, Avg: -0.316986
#
# Iteration 983/1000
#   Best: -0.348673, Avg: -0.317019
#
# Iteration 984/1000
#   Best: -0.348673, Avg: -0.317076
#
# Iteration 985/1000
#   Scout: Abandoned and found new source with criteria -0.235131
#   Best: -0.348673, Avg: -0.313435
#
# Iteration 986/1000
#   Best: -0.348673, Avg: -0.313588
#
# Iteration 987/1000
#   Best: -0.348673, Avg: -0.313620
#
# Iteration 988/1000
#   Best: -0.348673, Avg: -0.313620
#
# Iteration 989/1000
#   Best: -0.348673, Avg: -0.313749
#
# Iteration 990/1000
#   Best: -0.348673, Avg: -0.313951
#
# Iteration 991/1000
#   Best: -0.348673, Avg: -0.313963
#
# Iteration 992/1000
#   Best: -0.348673, Avg: -0.313974
#
# Iteration 993/1000
#   Best: -0.348673, Avg: -0.313974
#
# Iteration 994/1000
#   Best: -0.348673, Avg: -0.314107
#
# Iteration 995/1000
#   Best: -0.348673, Avg: -0.314110
#
# Iteration 996/1000
#   Best: -0.348673, Avg: -0.314155
#
# Iteration 997/1000
#   Best: -0.348673, Avg: -0.314428
#
# Iteration 998/1000
#   Best: -0.348673, Avg: -0.314994
#
# Iteration 999/1000
#   Best: -0.348673, Avg: -0.314994
#
# Iteration 1000/1000
#   Best: -0.348673, Avg: -0.315006
#
# ============================================================
# ABC completed!
# Best criteria: -0.34867345
# Found at iteration: 976
# ============================================================
# 975
